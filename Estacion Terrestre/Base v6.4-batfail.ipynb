# %%
# =========================
# [1] IMPORTS Y CONSTANTES
# =========================
import tkinter as tk
from tkinter import ttk, messagebox, scrolledtext, filedialog
import serial
import serial.tools.list_ports
import threading
import time
import json
import pickle
from math import inf
import math
import tkintermapview
from geographiclib.geodesic import Geodesic
import uuid
from PIL import Image, ImageTk

# Protocolo de comunicación
HEADER_OUT = "GS#"    # lo que ENVÍA la base
HEADER_IN  = "UAV#"   # lo que RECIBE la base
FOOTER     = "#END"

# Serial
SERIAL_PORT = None
SERIAL_BAUDRATE = 115200
ser = None
is_connected = False

# ACK
ACK_TIMEOUT = 1.5        # segundos para esperar ACK
MAX_RETRIES = 3          # reintentos máximos
pending_acks = {}        # { id: {"frame": str, "timestamp": float, "retries": int} }
ack_lock = threading.Lock()

# Estado
last_telemetry_pos = None

# Edición de mapa
EDIT_MODE = 'polygon'  # 'move', 'delete', 'home', 'polygon'

# =========================
# [2] ESTRUCTURAS DE DATOS
# =========================
class MissionData:
    def __init__(self):
        self.polygon_points = []   # [(lat, lon), ...]
        self.home_position = None  # (lat, lon) o None
        self.altitude = 3         # Altitud de misión (m)
        self.spacing = 5          # Ancho entre pasadas (m)
        self.detect_spacing = 5 

    def to_dict(self):
        """Convierte a diccionario compacto para LoRa"""
        return {
            "p": [[round(lat, 6), round(lon, 6)] for lat, lon in self.polygon_points],
            "h": [round(self.home_position[0], 6), round(self.home_position[1], 6)] if self.home_position else None,
            "a": self.altitude,
            "s": self.spacing,
            "ds": self.detect_spacing,
        }

    def from_dict(self, data):
        """Carga desde diccionario"""
        self.polygon_points = [tuple(point) for point in data.get("p", [])]
        self.home_position = tuple(data["h"]) if data.get("h") else None
        self.altitude = data.get("a", 3)
        self.spacing = data.get("s", 5)
        self.detect_spacing = data.get("ds", 5)

# =========================
# [3] VARIABLES GLOBALES GUI
# =========================
# Mapa y marcadores
polygon_markers = []
polygon_path = None
home_marker = None
home_line = None
mission_path = None
waypoint_markers = []
waypoint_status = []
fire_markers = []
person_markers = []
current_target_marker = None
mission_tracking_enabled = False
battery_fail_marker = None
battery_low_alert_shown = False
esp_wp_chunks = []
esp_wp_total = 0
esp_mission_path = None
esp_wp_markers = []


# Controles / widgets
btn_disarm = None
btn_mission = None
btn_return = None
btn_arm = None
start_mission_btn = None

event_action_var = None
port_var = None
spacing_var = None
altitude_var = None
detect_spacing_var = None   
status_message = None
home_position_var = None
progress_var = None
progress_bar = None
battery_low_alert_shown = False
mission_sent = False
home_set = False
polygon_set = False
drone_armed = False


# Gripper
gripper_state_var = None

# Vistas
root = None
mapa = None
telemetry_text = None
log_text = None

#iconos
active_wp_marker = None      # marcador del waypoint actual
waypoint_list = []           # coordenadas de cada waypoint enviadas por el dron
waypoint_total = 0

flight_track = []     # lista de puntos reales recorridos
flight_path = None    # path verde en el mapa

def safe_delete(obj):
    try:
        root.after_idle(lambda: obj.delete())
    except:
        pass

# =========================
# [4] UTILIDADES GEODÉSICAS
# =========================
def calculate_distance(lat1, lon1, lat2, lon2):
    """Distancia en metros entre dos puntos"""
    return Geodesic.WGS84.Inverse(lat1, lon1, lat2, lon2)['s12']

def calculate_bearing(lat1, lon1, lat2, lon2):
    """Rumbo en grados entre dos puntos"""
    return Geodesic.WGS84.Inverse(lat1, lon1, lat2, lon2)['azi1']

def get_point_at_distance(lat1, lon1, bearing, distance):
    """Punto desde (lat1, lon1) a distancia (m) y rumbo (°)"""
    result = Geodesic.WGS84.Direct(lat1, lon1, bearing, distance)
    return (result['lat2'], result['lon2'])

# =============================================
# [4B] GENERACIÓN DE PATRÓN LAWNMOWER EN LA GS
# =============================================

def rotate_point(lat, lon, origin_lat, origin_lon, angle_deg):
    """
    Convierte (lat, lon) a coordenadas locales en METROS respecto al origen
    y las rota angle_deg grados. Devuelve (x_rot, y_rot) en metros.
    """
    # 1) Pasar de lat/lon a sistema local (x,y) en metros
    dx = calculate_distance(origin_lat, origin_lon, origin_lat, lon)
    if lon < origin_lon:
        dx = -dx

    dy = calculate_distance(origin_lat, origin_lon, lat, origin_lon)
    if lat < origin_lat:
        dy = -dy

    # 2) Rotar en el plano local
    angle = math.radians(angle_deg)
    xr = dx * math.cos(angle) - dy * math.sin(angle)
    yr = dx * math.sin(angle) + dy * math.cos(angle)

    # 3) OJO: acá NO volvemos a lat/lon.
    #     Devolvemos coordenadas locales rotadas en METROS.
    return xr, yr


def rotate_polygon(points, origin, angle_deg):
    return [rotate_point(p[0], p[1], origin[0], origin[1], angle_deg) for p in points]

def local_to_latlon(x, y, origin_lat, origin_lon, angle_deg):
    """
    Convierte coordenadas locales (x,y) EN METROS, rotadas, 
    nuevamente a coordenadas geográficas (lat/lon).
    angle_deg = ángulo original del polígono respecto al norte.
    """
    # Rotar de vuelta al sistema global
    angle = math.radians(angle_deg)
    xr = x * math.cos(angle) - y * math.sin(angle)
    yr = x * math.sin(angle) + y * math.cos(angle)

    # Convertir valores locales (xr, yr) de metros a lat/lon reales
    lat = get_point_at_distance(origin_lat, origin_lon, 0, yr)[0]
    lon = get_point_at_distance(origin_lat, origin_lon, 90, xr)[1]

    return lat, lon


def generate_lawnmower_path(polygon, spacing, ds, home=None):
    """
    Genera el patrón lawnmower COMPLETO para mostrar en GS.
    polygon: lista [(lat, lon), ...]
    spacing: separación entre pasadas (en metros)
    ds: distancia entre puntos de detección (en metros)
    """
    if len(polygon) < 3:
        return []

    # -------------------------
    # 1. Encontrar lado mayor
    # -------------------------
    max_len = -1
    pA, pB = polygon[0], polygon[1]
    for i in range(len(polygon)):
        for j in range(i+1, len(polygon)):
            d = calculate_distance(polygon[i][0], polygon[i][1],
                                   polygon[j][0], polygon[j][1])
            if d > max_len:
                max_len = d
                pA, pB = polygon[i], polygon[j]

    # rumbo del lado mayor
    bearing = calculate_bearing(pA[0], pA[1], pB[0], pB[1])

    # -------------------------
    # 2. Rotar polígono para que lado mayor quede horizontal
    # -------------------------
    origin = pA
    polygon_rot = rotate_polygon(polygon, origin, -bearing)

    # -------------------------
    # 3. Encontrar Y min y Y max
    # -------------------------
    ys = [pt[1] for pt in polygon_rot]
    min_y, max_y = min(ys), max(ys)

    # -------------------------
    # 4. Generar pasadas a intervalos "spacing"
    # -------------------------
    path = []
    y = min_y
    direction = 1

    while y <= max_y:
        # Intersecciones de borde con esta línea horizontal "y"
        intersections = []
        for i in range(len(polygon_rot)):
            x1, y1 = polygon_rot[i]
            x2, y2 = polygon_rot[(i + 1) % len(polygon_rot)]

            # chequear si cruza
            if (y1 <= y <= y2) or (y2 <= y <= y1):
                if y1 == y2:
                    continue  # borde horizontal, ignorar
                t = (y - y1) / (y2 - y1)
                x = x1 + t * (x2 - x1)
                intersections.append(x)

        intersections.sort()

        if len(intersections) >= 2:
            x_start, x_end = intersections[0], intersections[-1]

            # ----------------------------
            # Crear puntos cada "ds" metros
            # ----------------------------
            segment_length = abs(x_end - x_start)
            n_points = max(2, int(segment_length / ds))

            if direction == 1:
                xs = [x_start + (segment_length * i / (n_points - 1))
                      for i in range(n_points)]
            else:
                xs = [x_end - (segment_length * i / (n_points - 1))
                      for i in range(n_points)]

            # ----------------------------
            # Convertir x,y rotado → lat/lon real
            # ----------------------------
            for x in xs:
                lat, lon = local_to_latlon(x, y, origin[0], origin[1], bearing)
                path.append((lat, lon))

        direction *= -1
        y += spacing
    

    return path


def draw_esp_mission_path(coords):
    """
    Dibuja el trazado enviado por el ESP.
    Se fuerza visualización con:
    - Marcadores en TODOS los puntos
    - Auto-zoom al centro
    - Path celeste robusto
    """

    global esp_mission_path, esp_wp_markers

    # ---------------------------------------------------------
    # BORRAR ANTERIORES
    # ---------------------------------------------------------
    if esp_mission_path:
        try: safe_delete(esp_mission_path)
        except: pass
        esp_mission_path = None

    for m in esp_wp_markers:
        try: safe_delete(m)
        except: pass
    esp_wp_markers.clear()

    # ---------------------------------------------------------
    # VALIDACIÓN
    # ---------------------------------------------------------
    if not coords:
        log_message("⚠️ draw_esp_mission_path: coords vacío")
        return

    log_message(f"📌 {len(coords)} waypoints recibidos del ESP")

    # ---------------------------------------------------------
    # LOGUEAR TODOS LOS PUNTOS (debug)
    # ---------------------------------------------------------
    for i, (lat, lon) in enumerate(coords):
        log_message(f"   [{i}] {lat:.7f}, {lon:.7f}")

    # ---------------------------------------------------------
    # AUTO-ZOOM
    # ---------------------------------------------------------
    try:
        lats = [c[0] for c in coords]
        lons = [c[1] for c in coords]
        mid_lat = (min(lats) + max(lats)) / 2
        mid_lon = (min(lons) + max(lons)) / 2

        map_widget.set_position(mid_lat, mid_lon)
        map_widget.set_zoom(19)
        log_message("🔍 Auto-zoom centrado en ruta ESP")
    except Exception as e:
        log_message(f"⚠️ Error auto-zoom: {e}")

    # ---------------------------------------------------------
    # MARCADORES: TODOS LOS PUNTOS
    # ---------------------------------------------------------
    for i, (lat, lon) in enumerate(coords):
        try:
            marker = map_widget.set_marker(lat, lon, text=f"{i}")
            esp_wp_markers.append(marker)
        except Exception as e:
            log_message(f"⚠️ Error dibujando marker {i}: {e}")

    # ---------------------------------------------------------
    # PATH CELESTE
    # ---------------------------------------------------------
    try:
        # Forzamos formato correcto
        path_coords = [(float(lat), float(lon)) for lat, lon in coords]

        esp_mission_path = map_widget.set_path(
            path_coords,
            color="#00CFFF",
            width=3
        )
        log_message("🧭 Path ESP dibujado correctamente (celeste)")
    except Exception as e:
        log_message(f"❌ Error dibujando path ESP: {e}")



def update_buttons_state():
    # Seguridad: si los botones aún no están creados, no hacer nada
    if 'send_mission_btn' not in globals() or send_mission_btn is None:
        return
    if 'start_mission_btn' not in globals() or start_mission_btn is None:
        return

    # --- botón ENVIAR MISIÓN ---
    if home_set and polygon_set:
        send_mission_btn.config(state="normal")
    else:
        send_mission_btn.config(state="disabled")

    # --- botón COMENZAR MISIÓN ---
    if mission_sent and drone_armed:
        start_mission_btn.config(state="normal")
    else:
        start_mission_btn.config(state="disabled")

# =========================================================
# [5] LOG Y TELEMETRÍA (SEGUROS PARA LLAMAR DESDE HILOS)
# =========================================================
def log_message(message):
    """Agrega texto al log de manera segura desde cualquier hilo."""
    try:
        timestamp = time.strftime('%H:%M:%S')
        full_msg = f"{timestamp} - {message}\n"

        if 'log_text' not in globals() or not log_text:
            print(full_msg.strip())  # fallback si GUI aún no existe
            return

        def update_log():
            log_text.config(state="normal")
            log_text.insert("end", full_msg)
            log_text.see("end")
            log_text.config(state="disabled")

        root.after(0, update_log)
    except Exception as e:
        print(f"[Log Error] {e} :: {message}")

def update_telemetry(data):
    if not root:
        return

    def update_gui():
        global last_telemetry_pos, battery_low_alert_shown, battery_fail_marker

        telemetry_text.config(state="normal")
        telemetry_text.delete(1.0, "end")

        voltage = data.get('voltage', 'N/A')
        battery_pct = data.get('battery', 'N/A')
        batt_warn = data.get('batt_warn', False)

        telemetry_str = f"Latitud: {data.get('lat', 'N/A')}\n"
        telemetry_str += f"Longitud: {data.get('lon', 'N/A')}\n"
        telemetry_str += f"Altitud: {data.get('alt', 'N/A')} m\n"
        telemetry_str += f"Velocidad: {data.get('speed', 'N/A')} km/h\n"
        telemetry_str += f"Rumbo: {data.get('heading', 'N/A')}°\n"
        telemetry_str += f"Batería: {battery_pct}%\n"
        telemetry_str += f"Voltaje: {voltage} V\n"
        telemetry_str += f"Estado: {data.get('status', 'N/A')}\n"
        telemetry_str += f"Waypoint actual: {data.get('current_wp', 'N/A')}\n"
        telemetry_str += f"Waypoints totales: {data.get('total_wp', 'N/A')}\n"

        telemetry_text.insert("end", telemetry_str)
        telemetry_text.config(state="disabled")

        # ========= 🔥 EVENTO: BATERIA BAJA =========
        if batt_warn and not battery_low_alert_shown:

            battery_low_alert_shown = True

            # Popup visual
            if voltage != "N/A":
                show_battery_popup(float(voltage))

            # Colocar marcador en mapa
            if 'lat' in data and 'lon' in data and data['lat'] != 'N/A' and data['lon'] != 'N/A':
                place_battery_fail_marker(data['lat'], data['lon'])
                log_message("📍 Marcador de batería baja colocado en el mapa")

        # ==========================================

        # Marcador del dron y ruta
        if 'lat' in data and 'lon' in data and data['lat'] != 'N/A' and data['lon'] != 'N/A':
            lat = data['lat']
            lon = data['lon']
            last_telemetry_pos = (lat, lon)
            update_drone_position(lat, lon)
            update_flight_track(lat, lon)

    root.after(0, update_gui)



def show_battery_popup(voltage):
    message = f"⚠️ BATERÍA BAJA\n\nVoltaje: {voltage:.2f} V\nEl dron está en riesgo."
    messagebox.showerror("⚠️ BATERÍA BAJA", message)

def place_battery_fail_marker(lat, lon):
    global battery_fail_marker

    if map_widget is None:
        return

    battery_fail_marker = map_widget.set_marker(
        lat, lon,
        text="Batería baja",
        marker_color_circle="red",
        marker_color_outside="darkred"
    )


def update_drone_position(lat, lon):
    """Dibuja/actualiza el marcador del dron en el mapa."""
    if hasattr(update_drone_position, "marker") and update_drone_position.marker:
        update_drone_position.marker.delete()

    update_drone_position.marker = mapa.set_marker(
        lat, lon, text="DRON",
        marker_color_circle="red", marker_color_outside="red",
        text_color="red", font=("Helvetica", 12, "bold")
    )

    current_center = mapa.get_position()
    if calculate_distance(current_center[0], current_center[1], lat, lon) > 5000:
        mapa.set_position(lat, lon)
        mapa.set_zoom(15)
        
def update_flight_track(lat, lon):
    global flight_track, flight_path, mission_tracking_enabled

    # 🚫 No trazar si la misión no está activa
    if not mission_tracking_enabled:
        return

    # 🚫 Anti-jitter: no trazar puntos que no representen desplazamiento real
    if flight_track:
        last_lat, last_lon = flight_track[-1]
        d = calculate_distance(last_lat, last_lon, lat, lon)
        if d < 0.8:     # menos de 80 cm → jitter
            return

    # Agregar punto válido
    flight_track.append((lat, lon))

    # Borrar visualización previa
    if flight_path:
        try:
             safe_delete(flight_path)
        except:
            pass

    # Dibujar trayecto actualizado
    if len(flight_track) > 1:
        flight_path = mapa.set_path(flight_track, color="red", width=3)


def create_active_wp_marker(lat, lon, wp_id):
    return mapa.set_marker(
        lat, lon,
        text=f"WP{wp_id}",
        marker_color_circle="#FFD000",   # amarillo fuerte
        marker_color_outside="#A67C00",  # borde marrón oscuro
        text_color="black",
        font=("Helvetica", 11, "bold")
    )
def update_active_waypoint(lat, lon, wp_id):
    global active_wp_marker

    # borrar anterior
    if active_wp_marker:
        safe_delete(active_wp_marker)

    # crear el nuevo
    active_wp_marker = create_active_wp_marker(lat, lon, wp_id)

def handle_wp_chunk(data):
    """
    Reconstruye los fragmentos de waypoints enviados por el ESP (WP_CHUNK)
    y, cuando están todos, dibuja el trazado en celeste en el mapa.
    """
    global esp_wp_chunks, esp_wp_total

    idx = data.get("i")
    total = data.get("n")
    chunk = data.get("chunk", "")

    if idx is None or total is None:
        log_message(f"⚠️ WP_CHUNK inválido: {data}")
        return

    # Inicializar buffer SOLO si cambió el total o si está vacío
    if esp_wp_total != total or len(esp_wp_chunks) != total:
        esp_wp_total = total
        esp_wp_chunks = [""] * total
        log_message(f"🧩 Iniciando recepción de {total} fragmentos de waypoints")

    # Insertar chunk
    if 0 <= idx < esp_wp_total:
        esp_wp_chunks[idx] = chunk
    else:
        log_message(f"⚠️ Índice fuera de rango: i={idx}, total={esp_wp_total}")
        return

    # Si ya están todos los fragmentos → reconstruir cadena completa
    if all(esp_wp_chunks):
        big_str = "".join(esp_wp_chunks)

        # Parsear: "lat,lon;lat,lon;..."
        pairs = [p for p in big_str.strip().split(";") if p.strip()]
        coords = []

        for p in pairs:
            try:
                lat_s, lon_s = p.split(",")
                coords.append((float(lat_s), float(lon_s)))
            except Exception as e:
                log_message(f"⚠️ Error parseando par '{p}': {e}")

        log_message(f"🧭 {len(coords)} waypoints reconstruidos desde ESP")

        draw_esp_mission_path(coords)



# =====================================
# [6] COMUNICACIÓN: CONEXIÓN / ENVÍOS
# =====================================
def connect_serial():
    """Conecta el puerto serial y lanza los hilos de recepción y ACK."""
    global ser, is_connected, SERIAL_PORT

    is_connected = False
    SERIAL_PORT = port_var.get()

    if not SERIAL_PORT:
        messagebox.showerror("Error", "Selecciona un puerto serial primero")
        return False

    try:
        ser = serial.Serial(SERIAL_PORT, SERIAL_BAUDRATE, timeout=1)
        ser.reset_input_buffer()
        ser.reset_output_buffer()

        is_connected = True
        print(f"[SERIAL] ✅ Conectado a {SERIAL_PORT} @ {SERIAL_BAUDRATE} bps")
        status_label.config(text=f"Conectado: {SERIAL_PORT}", fg="green")
        log_message(f"✅ Conectado correctamente a {SERIAL_PORT} a {SERIAL_BAUDRATE} bps")

        if 'root' in globals() and root:
            print("[SERIAL] 🚀 Lanzando hilos: recepción y ack_manager")
            threading.Thread(target=receive_data, daemon=True).start()
            threading.Thread(target=ack_manager, daemon=True).start()
        else:
            print("[SERIAL] ⚠️ GUI no inicializada aún, no se lanzan hilos")

        return True

    except Exception as e:
        is_connected = False
        print(f"[SERIAL] ❌ Error conectando a {SERIAL_PORT}: {e}")
        log_message(f"❌ Error conectando al puerto {SERIAL_PORT}: {e}")
        messagebox.showerror("Error", f"No se pudo conectar: {str(e)}")
        return False

def disconnect_serial():
    """Desconecta el puerto serial de forma segura y limpia."""
    global ser, is_connected

    if not is_connected:
        print("[SERIAL] ⚠️ No hay conexión activa para cerrar.")
        log_message("⚠️ No hay conexión activa para cerrar.")
        return

    try:
        is_connected = False
        time.sleep(0.2)  # permitir que terminen hilos
        if ser and ser.is_open:
            ser.close()
        status_label.config(text="Desconectado", fg="red")
        log_message("🔌 Puerto serial cerrado correctamente")
        print("[SERIAL] ✅ Puerto cerrado correctamente")
    except Exception as e:
        log_message(f"⚠️ Error al cerrar el puerto serial: {e}")
        print(f"[SERIAL] ⚠️ Error al cerrar puerto: {e}")
    finally:
        ser = None

def send_command(command_type, data=None, require_ack=True):
    """Forma el frame GS#...#END, envía y registra para ACK si corresponde."""
    if not is_connected:
        messagebox.showwarning("Error", "No hay conexión serial")
        return

    # ID único del paquete
    packet_id = str(uuid.uuid4())[:8]

    message = {
        "t": command_type,
        "d": data if data else {},
        "ts": int(time.time() * 1000),
        "id": packet_id
    }

    payload = json.dumps(message, separators=(",", ":"))
    frame   = f"{HEADER_OUT}{payload}{FOOTER}"

    try:
        # 🟦 Print de envío completo
        print(f"[TX → LoRa/send_command] Frame enviado → {frame}")
        
        ser.write(frame.encode())
        log_message(f"Enviado: {frame}")

        if require_ack and command_type != "TELEMETRY":
            with ack_lock:
                pending_acks[packet_id] = {
                    "frame": frame,
                    "timestamp": time.time(),
                    "retries": 0
                }

    except Exception as e:
        log_message(f"Error enviando: {str(e)}")

def request_esp_waypoints():
    send_command("REQ_WP_DEBUG", {})
    log_message("📡 Solicitado trazado del dron…")


# ========================================
# [7] COMUNICACIÓN: RECEPCIÓN Y ACKs
# ========================================
def ack_manager():
    """Reintenta envíos sin ACK dentro del timeout."""
    while is_connected:
        time.sleep(0.2)
        now = time.time()

        with ack_lock:
            to_delete = []
            for pid, info in list(pending_acks.items()):
                if now - info["timestamp"] > ACK_TIMEOUT:
                    if info["retries"] < MAX_RETRIES:
                        try:
                            ser.write(info["frame"].encode())
                            pending_acks[pid]["timestamp"] = now
                            pending_acks[pid]["retries"] += 1
                            print(f"[ACK MANAGER → LoRa] 🔄 Reintentando ID={pid} (reintento {info['retries']})")
                            log_message(f"🔄 Reintentando envío ID={pid}")
                        except Exception as e:
                            print(f"[ACK MANAGER] ⚠️ Error reintentando ID={pid}: {e}")
                            log_message(f"Error reintentando ID={pid}: {e}")
                    else:
                        log_message(f"❌ No se recibió ACK para ID={pid}")
                        print(f"[ACK MANAGER] ❌ ACK no recibido tras {MAX_RETRIES} intentos → ID={pid}")
                        to_delete.append(pid)

            for pid in to_delete:
                del pending_acks[pid]

def receive_data():
    """Lee y procesa frames UAV#...#END desde el serial."""
    global is_connected
    buffer = ""

    while is_connected:
        if not ser or not ser.is_open:
            break
        try:
            if ser.in_waiting > 0:
                chunk = ser.read(ser.in_waiting).decode(errors="ignore")
                buffer += chunk

                while True:
                    h = buffer.find(HEADER_IN)
                    if h < 0:
                        if len(buffer) > 4096:
                            buffer = buffer[-512:]
                        break

                    f = buffer.find(FOOTER, h)
                    if f < 0:
                        if h > 0: buffer = buffer[h:]
                        break

                    payload = buffer[h + len(HEADER_IN):f].strip()
                    buffer = buffer[f + len(FOOTER):]

                    # 🟩 Print de recepción de paquete completo
                    print(f"[RX ← LoRa/receive_data] Frame recibido ← UAV#{payload}#END")

                    try:
                        msg = json.loads(payload)
                        process_received_message(msg)
                    except Exception as e:
                        log_message(f"❌ Mensaje inválido: {payload[:80]} ({e})")

            time.sleep(0.01)
        except Exception as e:
            log_message(f"Error recibiendo datos: {e}")
            time.sleep(0.1)

    log_message("📴 Hilo de recepción terminado")

def process_received_message(message):
    """
    Procesa cualquier JSON recibido desde el dron (UAV).
    Envía ACK automáticos cuando corresponde (manteniendo framing GS#/UAV# y #END).
    """

    msg_type = message.get("t", "")
    data = message.get("d", message)   # <— CORRECTO Y BIEN INDENTADO
    packet_id = message.get("id", data.get("id", None))

    print(f"[RX ← LoRa/process_received_message] Mensaje recibido tipo '{msg_type}' → {message}")

    if not msg_type:
        log_message(f"⚠️ Mensaje sin tipo: {message}")
        return

    # =====================================================================================
    # ACK entrante desde UAV
    # =====================================================================================
    if msg_type == "ACK":
        print(f"[ACK IN ← LoRa/process_received_message] {message}")
        ack_id = None

        if "id" in message:
            ack_id = message["id"]
        elif isinstance(message.get("d"), dict) and "id" in message["d"]:
            ack_id = message["d"]["id"]

        if ack_id:
            with ack_lock:
                if ack_id in pending_acks:
                    del pending_acks[ack_id]
                    log_message(f"✅ ACK recibido para ID={ack_id}")
                else:
                    log_message(f"⚠️ ACK recibido con ID desconocido: {ack_id}")
        else:
            log_message("⚠️ ACK recibido sin ID válido")

        return

    # =====================================================================================
    # TELEMETRY
    # =====================================================================================
    if msg_type == "TELEMETRY":
        update_telemetry(data)
        return

    # =====================================================================================
    # STATUS
    # =====================================================================================
    elif msg_type == "STATUS":
        # Ejemplo:
        # {"t":"STATUS","state":3,"state_name":"NAVIGATE"}
        print(f"[STATUS ← LoRa] Data: {data}")
    
        # Tomamos nombre del estado
        name = (
            data.get("state_name")
            or data.get("message")
            or str(data.get("state", "DESCONOCIDO"))
        )
    
        # ================================
        # 🔥 FIX: activar/desactivar trazado
        # ================================
        global mission_tracking_enabled
    
        if name in ("NAVIGATE", "STABILIZE", "WAIT_ANALYSIS", "RETURN_HOME", "TAKEOFF"):
            mission_tracking_enabled = True
    
        elif name in ("IDLE", "COMPLETE", "LAND"):
            mission_tracking_enabled = False
            # Si querés limpiar track en el mapa:
            # clear_track_line()
    
        # =================================
    
        log_message(f"Estado FSM: {name}")
        status_message.set(f"Estado FSM: {name}")
        return
    
    # =====================================================================================
    # WAYPOINTS_INFO
    # =====================================================================================
    elif msg_type == "WAYPOINTS_INFO":
        global waypoint_total, waypoint_list
    
        total = data.get("total", 0)
    
        initialize_waypoint_tracking(total)
    
        waypoint_total = total       # ← ahora sí actualiza la global
        waypoint_list.clear()
        
        # Crear lista vacía del tamaño adecuado
        for _ in range(total):
            waypoint_list.append((None, None))   # Placeholder seguro
        
        update_active_waypoint(None, None, 0)  # marcador vacío opcional

    
        log_message(f"Total de waypoints: {total}")
        progress_bar["value"] = 0
        return

    # =====================================================================================
    # WAYPOINT_REACHED
    # =====================================================================================
    elif msg_type == "WAYPOINT_REACHED":
        wp = data.get("wp", -1)
    
        log_message(f"Waypoint alcanzado: {wp}")
        waypoint_reached(wp)  # ← ACTUALIZA barra y texto
    
        # manejo del marcador amarillo
        global active_wp_marker
    
        # último waypoint → borrar marcador
        if wp + 1 >= waypoint_total:
            if active_wp_marker:
                safe_delete(active_wp_marker)
                active_wp_marker = None
            return
    
        # si tenemos la lista (por ahora quizás solo wp0)
        if wp + 1 < len(waypoint_list):
            lat, lon = waypoint_list[wp + 1]
            update_active_waypoint(lat, lon, wp + 1)
    
        return
    
    # =====================================================================================
    # WP_UPDATE (nuevo, enviado por el dron)
    # =====================================================================================
    elif msg_type == "WP_UPDATE":
    
        wp = data.get("wp", -1)
        lat = data.get("lat")
        lon = data.get("lon")
    
        if lat is None or lon is None:
            return
    
        update_active_waypoint(lat, lon, wp)
    
        # Guardar en lista por si querés usarlo luego
        if wp < len(waypoint_list):
            waypoint_list[wp] = (lat, lon)
        else:
            waypoint_list.append((lat, lon))
    
        return

    # =====================================================================================
    # WP_CHUNK (debug de waypoints enviados por el dron para comparación)
    # =====================================================================================
    elif msg_type == "WP_CHUNK":
        handle_wp_chunk(data)
        return


    # =====================================================================================
    # DEBUG
    # =====================================================================================
    elif msg_type == "DEBUG":
        print(f"[DEBUG ← LoRa] Data: {data}")
        log_message(f"🪲 DEBUG: {data.get('message', '')}")
        return

    # =====================================================================================
    # FIRE
    # =====================================================================================
    elif msg_type == "FIRE":
        confidence = data.get("confidence", None)

        print(f"[FIRE ← LoRa] Data: {data}")

        if confidence is not None:
            try:
                confidence = float(confidence)
                if confidence > 1:
                    confidence /= 100.0
            except:
                confidence = None

            log_message(f"🔥 Evento FIRE detectado (confianza={confidence*100:.1f}%)")
        else:
            log_message("🔥 Evento FIRE detectado (sin dato de confianza)")

        add_fire_marker(data)
        return

    # =====================================================================================
    # PERSON
    # =====================================================================================
    elif msg_type == "PERSON":
        confidence = data.get("confidence", None)

        print(f"[PERSON ← LoRa] Data: {data}")

        if confidence is not None:
            try:
                confidence = float(confidence)
                if confidence > 1:
                    confidence /= 100.0
            except:
                confidence = None

            log_message(f"🧍 Evento PERSON detectado (confianza={confidence*100:.1f}%)")
        else:
            log_message("🧍 Evento PERSON detectado (sin dato de confianza)")

        add_person_marker(data)
        return

# ======================================
# [8] GESTIÓN DE MISIÓN (ENVÍOS, ESTADO)
# ======================================
def update_mission_parameters():
    current_mission.altitude = altitude_var.get()
    current_mission.spacing = spacing_var.get()
    current_mission.detect_spacing = detect_spacing_var.get()
    log_message("Parámetros de misión actualizados")

def send_compact_mission():
    if len(current_mission.polygon_points) < 4:
        messagebox.showwarning("Error", "Definí al menos 4 punto en el mapa")
        return

    if not current_mission.home_position:
        messagebox.showwarning("Error", "Establece una posición HOME primero")
        return
    update_mission_parameters()
    mission_dict = current_mission.to_dict()
    mission_dict["event_action"] = event_action_var.get()

    # Generar path para visualizar
    path = generate_lawnmower_path(
        current_mission.polygon_points,
        current_mission.spacing,
        detect_spacing_var.get(),
        home=current_mission.home_position
    )

    draw_mission_path(path)
    mission_sent = True
    
    send_command("MISSION_COMPACT", mission_dict)
    print(f"[TX → LoRa/send_compact_mission] Datos misión compacta → {mission_dict}")
    log_message(f"Misión enviada (formato compacto) con acción tras evento: {event_action_var.get()}")

def start_mission():
    global waypoint_status, waypoint_total, mission_tracking_enabled

    btn_return.config(state="normal", bg="orange")
    mission_tracking_enabled = True

    path = generate_lawnmower_path(
        current_mission.polygon_points,
        current_mission.spacing,
        current_mission.detect_spacing
    )

    waypoint_total = len(path)
    waypoint_status = ["pending"] * waypoint_total
    update_waypoint_display()

    send_compact_mission()

def start_flight():
    send_command("START_FLIGHT", {})
    log_message("🚁 Comenzar misión enviado")



def return_home():
   # btn_disarm.config(state="normal", bg="red")
    btn_mission.config(state="disabled", bg="lightgrey")
    #btn_return.config(state="disabled", bg="lightgrey")
    send_command("RETURN")
    print("[TX → LoRa/return_home] Enviando comando RETURN")

def arm_drone():
    if not last_telemetry_pos:
        log_message("⚠️ No hay datos de telemetría para fijar HOME")
        return
    send_command("ARM")
    log_message("🚁 Drone ARMADO")
    print("[TX → LoRa/arm_drone] Enviando comando ARM")
   # btn_disarm.config(state="disabled", bg="lightgrey")
    btn_mission.config(state="normal", bg="green", fg="white")
    global drone_armed
    drone_armed = True
    update_buttons_state()

def disarm_drone():
    global home_marker, home_line
    if home_marker:
        safe_delete(home_marker); 
    if home_line:
        safe_delete(home_line)
    home_marker = None
    home_line = None
    current_mission.home_position = None
    home_position_var.set("")
    send_command("DISARM")
    print("[TX → LoRa/disarm_drone] Enviando comando DISARM")
    log_message("🛑 Drone DESARMADO")
    btn_mission.config(state="disabled", bg="lightgray", fg="black")
    btn_return.config(state="disabled", bg="lightgrey", fg="black")
    global drone_armed, mission_sent
    drone_armed = False
    mission_sent = False
    update_buttons_state()

# Stubs para evitar errores si se usan en el futuro
def at_home(): return True
def not_mission_started(): return True

def show_target_waypoint(lat, lon):
    global current_target_marker

    # borrar marcador anterior
    if current_target_marker is not None:
        safe_delete(current_target_marker)

    # crear nuevo marcador
    current_target_marker = mapa.set_marker(lat, lon, text="Destino")


def initialize_waypoint_tracking(total_waypoints):
    global waypoint_status
    waypoint_status = ["pending"] * total_waypoints
    update_waypoint_display()

def waypoint_reached(wp_number):
    global waypoint_status, waypoint_total

    # --- Validación básica ---
    if wp_number is None:
        log_message("⚠️ WAYPOINT_REACHED recibido sin número de waypoint")
        return

    total_wp = len(waypoint_status)

    # --- Si el dron reporta un WP fuera de rango ---
    if wp_number < 0:
        log_message(f"⚠️ WAYPOINT_REACHED inválido (<0): {wp_number}")
        return

    if wp_number >= total_wp:
        log_message(
            f"⚠️ WAYPOINT_REACHED fuera de rango: {wp_number} "
            f"(total={total_wp}). Marcando todos como completados."
        )
        # --- MEJORA OPCIONAL ---
        # Si el dron se saltea números → completar todos
        for i in range(total_wp):
            waypoint_status[i] = "completed"
        update_waypoint_display()
        return

    # --- MEJORA OPCIONAL ---
    # Si llega WP=5 pero 0..4 están sin completar → completarlos automáticamente
    for i in range(wp_number + 1):
        waypoint_status[i] = "completed"

    update_waypoint_display()
    log_message(f"Waypoint {wp_number} completado")

    # --- Último waypoint ---
    if wp_number == total_wp - 1:
        log_message("🎉 ¡Todos los waypoints completados!")


def update_waypoint_display():
    if not waypoint_status:
        return

    completed = waypoint_status.count("completed")
    total = len(waypoint_status)

    def update_gui():
        progress_var.set(f"Waypoints: {completed}/{total}")
        progress_bar['value'] = (completed / total) * 100

    root.after(0, update_gui)

# ===========================================
# [9] MAPA: EDICIÓN, DIBUJO Y MARCADORES
# ===========================================
def set_edit_mode(mode):
    global EDIT_MODE
    EDIT_MODE = mode
    modes = {
        'polygon': "Añadir Puntos de Polígono",
        'move': "Mover Marcadores",
        'delete': "Eliminar Marcadores"
    }
    status_message.set(f"Modo: {modes.get(mode, mode)}")
    log_message(f"Modo cambiado a: {modes.get(mode, mode)}")
    update_button_colors()

def update_button_colors():
    for btn in [add_btn, delete_btn]:
        btn.config(bg="SystemButtonFace")
    if EDIT_MODE == 'polygon':
        add_btn.config(bg="lightblue")
    elif EDIT_MODE == 'delete':
        delete_btn.config(bg="lightcoral")

def map_click(coords):
    lat, lon = coords
    if EDIT_MODE == 'polygon':
        current_mission.polygon_points.append((lat, lon))
        current_mission.polygon_points = order_polygon_points(current_mission.polygon_points)
        marker = mapa.set_marker(lat, lon, text=f"P{len(current_mission.polygon_points)}")
        polygon_markers.append(marker)
        update_polygon_drawing()
        refresh_mission_preview()
        log_message(f"Punto de polígono añadido: {lat:.6f}, {lon:.6f}")
    elif EDIT_MODE == 'delete':
        closest_marker = find_closest_marker(lat, lon)
        if closest_marker:
            delete_marker(closest_marker)
        else:
            log_message("No se encontró ningún marcador cercano")

def find_closest_marker(lat, lon, max_distance=1000):
    closest_marker = None
    min_distance = inf
    for i, marker in enumerate(polygon_markers):
        marker_pos = marker.position
        dist = calculate_distance(lat, lon, marker_pos[0], marker_pos[1])
        if dist < min_distance and dist < max_distance:
            min_distance = dist
            closest_marker = ('polygon', i, marker)
    if home_marker:
        marker_pos = home_marker.position
        dist = calculate_distance(lat, lon, marker_pos[0], marker_pos[1])
        if dist < min_distance and dist < max_distance:
            min_distance = dist
            closest_marker = ('home', 0, home_marker)
    return closest_marker

def delete_marker(marker_info):
    global home_marker, home_line
    btn_mission.config(state="disabled", bg="lightgray", fg="black")
    marker_type, index, marker = marker_info
    if marker_type == 'polygon':
        current_mission.polygon_points.pop(index)
        current_mission.polygon_points = order_polygon_points(current_mission.polygon_points)
        safe_delete(marker)
        polygon_markers.pop(index)
        for i, marker in enumerate(polygon_markers):
            marker.set_text(f"P{i + 1}")
        update_polygon_drawing()
        refresh_mission_preview()
        log_message(f"Punto P{index + 1} eliminado")
    elif marker_type == 'home':
        if home_marker:
            safe_delete(home_marker); 
        if home_line:
            safe_delete(home_line)
        home_marker = None
        home_line = None
        current_mission.home_position = None
        home_position_var.set("")
        log_message("🏠 HOME eliminado")

def set_home_position(lat, lon):
    global home_marker, home_line
    if home_marker: safe_delete(home_marker)
    if home_line: safe_delete(home_line)
    home_marker = None
    home_line = None

    current_mission.home_position = (lat, lon)
    home_marker = mapa.set_marker(lat, lon, text="HOME",
                                  marker_color_circle="white", marker_color_outside="green")
    home_position_var.set(f"{lat:.6f}, {lon:.6f}")
    log_message(f"🏠 Home position establecida: {lat:.6f}, {lon:.6f}")

    if current_mission.polygon_points:
        closest_point = find_closest_polygon_point(lat, lon)
        home_line = mapa.set_path([current_mission.home_position, closest_point], color="green", width=2)

    refresh_mission_preview()
    global polygon_set
    polygon_set = True
    update_buttons_state()


def set_home_from_telemetry():
    """Establece HOME desde última telemetría."""
    global last_telemetry_pos
    if not last_telemetry_pos:
        log_message("⚠️ No hay datos de telemetría para establecer HOME")
        messagebox.showwarning("Atención", "No hay datos de telemetría disponibles")
        return
    lat, lon = last_telemetry_pos
    set_home_position(lat, lon)
    log_message(f"🏠 HOME actualizado desde telemetría: {lat:.6f}, {lon:.6f}")
    global polygon_set
    polygon_set = True
    update_buttons_state()

def find_closest_polygon_point(lat, lon):
    if not current_mission.polygon_points:
        return None
    min_distance = inf
    closest_point = None
    for point in current_mission.polygon_points:
        dist = calculate_distance(lat, lon, point[0], point[1])
        if dist < min_distance:
            min_distance = dist
            closest_point = point
    return closest_point

def add_fire_marker(data):
    lat = data.get('lat')
    lon = data.get('lon')
    conf = data.get('confidence', None)

    if lat is None or lon is None:
        return

    # Construir etiqueta multilínea
    if conf is not None:
        label = f"FUEGO ({conf*100:.1f}%)\n{lat:.6f}, {lon:.6f}"
    else:
        label = f"FUEGO\n{lat:.6f}, {lon:.6f}"

    # Crear marcador principal
    marker = mapa.set_marker(
        lat, lon,
        text=label,
        marker_color_circle="orange",
        marker_color_outside="orange",
        text_color="black",
        font=("Arial", 9, "bold")
    )
    fire_markers.append(marker)

    # Log visual
    if conf is not None:
        log_message(f"🔥 Marcador FUEGO agregado: {lat:.6f}, {lon:.6f} (Confianza={conf*100:.1f}%)")
    else:
        log_message(f"🔥 Marcador FUEGO agregado: {lat:.6f}, {lon:.6f}")


def add_person_marker(data):
    lat = data.get('lat')
    lon = data.get('lon')
    conf = data.get('confidence', None)

    if lat is None or lon is None:
        return

    # Construir etiqueta multilínea
    if conf is not None:
        label = f"PERSONA ({conf*100:.1f}%)\n{lat:.6f}, {lon:.6f}"
    else:
        label = f"PERSONA\n{lat:.6f}, {lon:.6f}"

    # Crear marcador principal
    marker = mapa.set_marker(
        lat, lon,
        text=label,
        marker_color_circle="#8B4513",
        marker_color_outside="#8B4513",
        text_color="black",
        font=("Arial", 9, "bold")
    )
    person_markers.append(marker)

    # Log visual
    if conf is not None:
        log_message(f"🧍 Marcador PERSONA agregado: {lat:.6f}, {lon:.6f} (Confianza={conf*100:.1f}%)")
    else:
        log_message(f"🧍 Marcador PERSONA agregado: {lat:.6f}, {lon:.6f}")


def update_polygon_drawing():
    global polygon_path
    current_mission.polygon_points = order_polygon_points(current_mission.polygon_points)
    if polygon_path:
        safe_delete(polygon_path)
    if len(current_mission.polygon_points) >= 2:
        polygon_path = mapa.set_polygon(
            current_mission.polygon_points,
            outline_color="blue", fill_color="lightblue", border_width=2
 
         )
    refresh_mission_preview()

def order_polygon_points(points):
    """
    Ordena automáticamente los puntos del polígono según ángulo polar
    respecto al centroide, evitando cruces tipo 'moño'.
    """
    if len(points) < 3:
        return points

    cx = sum(p[0] for p in points) / len(points)
    cy = sum(p[1] for p in points) / len(points)

    ordered = sorted(points, key=lambda p: math.atan2(p[1] - cy, p[0] - cx))
    return ordered

def draw_mission_path(points):
    global mission_path
    if mission_path:
        try:
            safe_delete(mission_path)
        except:
            pass

    if len(points) > 1:
        mission_path = mapa.set_path(points, color="yellow", width=3)

def refresh_mission_preview():
    """Regenera el lawnmower automáticamente si hay polígono y HOME."""
    global mission_path

    if len(current_mission.polygon_points) < 3:
        if mission_path:
            safe_delete(mission_path)
            mission_path = None
        return

    # Actualizar parámetros de misión actuales
    current_mission.spacing = spacing_var.get()
    current_mission.detect_spacing = detect_spacing_var.get()

    # Generar path
    path = generate_lawnmower_path(
        current_mission.polygon_points,
        current_mission.spacing,
        current_mission.detect_spacing,
        home=current_mission.home_position
    )



    # Dibujarlo
    draw_mission_path(path)



def clear_all_waypoints():
    global waypoint_markers, active_wp_marker

    # Borrar marcador activo si existe
    if active_wp_marker:
        safe_delete(active_wp_marker)
        active_wp_marker = None

    # Borrar todos los demás waypoints
    for m in waypoint_markers:
        try:
            safe_delete(m)
        except:
            pass

    waypoint_markers.clear()
    print("🗑 Todos los waypoints eliminados")


def reset_polygon():
    global current_mission, polygon_markers, polygon_path
    global home_marker, home_line, mission_path
    global waypoint_status, person_markers, fire_markers
    global flight_track, flight_path
    global battery_fail_marker, battery_low_alert_shown   # 🟥 IMPORTANTE

    # Borrar marcadores del polígono
    for m in polygon_markers:
        safe_delete(m)
    polygon_markers.clear()

    # Borrar polígono dibujado
    if polygon_path is not None:
        try: 
            safe_delete(polygon_path)
        except Exception as e:
            log_message(f"Error borrando polígono: {e}")
        polygon_path = None

        # =====================================================================
    # 🟦 BORRAR TRAZADO DEL DRON (ESP)
    # =====================================================================
    global esp_mission_path, esp_wp_markers, esp_wp_chunks, esp_wp_total

    # Borrar línea celeste dibujada desde ESP
    if esp_mission_path:
        try:
            safe_delete(esp_mission_path)
        except:
            pass
        esp_mission_path = None

    # Borrar marcadores de ESP
    for m in esp_wp_markers:
        try:
            safe_delete(m)
        except:
            pass
    esp_wp_markers.clear()

    # Reset buffers de reconstrucción de fragmentos
    esp_wp_chunks = []
    esp_wp_total = 0

    log_message("🗑 Reset: Trazado del dron eliminado")


    # Limpiar ruta recorrida
    flight_track = []
    if flight_path:
        try:
            safe_delete(flight_path)
        except:
            pass
    flight_path = None

    # Borrar HOME
    if home_marker: safe_delete(home_marker)
    if home_line: safe_delete(home_line)
    home_marker = None
    home_line = None

    # Borrar marcadores de eventos PERSON
    for m in person_markers: 
        safe_delete(m)
    person_markers.clear()

    # Borrar marcadores de eventos FIRE
    for m in fire_markers: 
        safe_delete(m)
    fire_markers.clear()

    # 🟨 BORRAR CAMINO DE MISIÓN (mission_path)
    if mission_path:
        try:
            safe_delete(mission_path)
        except:
            pass
    mission_path = None

    # 🟥 BORRAR MARCADOR DE BATERÍA BAJA
    if battery_fail_marker:
        try:
            safe_delete(battery_fail_marker)
        except:
            pass
        battery_fail_marker = None

    # 🟥 Permitir que futuras alertas de batería baja vuelvan a mostrarse
    battery_low_alert_shown = False

    # Reset de la misión
    current_mission = MissionData()
    waypoint_status = []

    # Reset UI elements
    home_position_var.set("")
    progress_var.set("Waypoints: 0/0")
    progress_bar['value'] = 0
    altitude_var.set(3)
    spacing_var.set(5)
    detect_spacing_var.set(5)

    clear_all_waypoints()

    log_message("🔄 Reset completo: polígono, HOME, misión, mission path y marcador de batería baja eliminados")

    polygon_set = False
    mission_sent = False
    update_buttons_state()
# =========================================
# [11] ARCHIVOS DE MISIÓN (GUARDAR/CARGAR)
# =========================================
def save_mission():
    if not current_mission.polygon_points:
        messagebox.showwarning("Error", "No hay misión para guardar")
        return
    filename = filedialog.asksaveasfilename(
        defaultextension=".mission",
        filetypes=[("Mission files", "*.mission"), ("All files", "*.*")]
    )
    if filename:
        try:
            with open(filename, 'wb') as f:
                pickle.dump(current_mission.to_dict(), f)
            log_message(f"Misión guardada: {filename}")
        except Exception as e:
            log_message(f"Error guardando misión: {str(e)}")

def load_mission():
    filename = filedialog.askopenfilename(
        filetypes=[("Mission files", "*.mission"), ("All files", "*.*")]
    )
    if filename:
        try:
            with open(filename, 'rb') as f:
                mission_data = pickle.load(f)
            reset_polygon()
            current_mission.from_dict(mission_data)
            update_interface_from_mission()
            log_message(f"Misión cargada: {filename}")
        except Exception as e:
            log_message(f"Error cargando misión: {str(e)}")

def update_interface_from_mission():
    for i, (lat, lon) in enumerate(current_mission.polygon_points):
        marker = mapa.set_marker(lat, lon, text=f"P{i+1}")
        polygon_markers.append(marker)
    if current_mission.home_position:
        set_home_position(current_mission.home_position[0], current_mission.home_position[1])
    altitude_var.set(current_mission.altitude)
    spacing_var.set(current_mission.spacing)
    detect_spacing_var.set(current_mission.detect_spacing)
    update_polygon_drawing()

# =========================================
# [12] CONSTRUCCIÓN DE LA GUI (TKINTER)
# =========================================
def create_trim_pid_controls(frame):
    """Panel reducido: SOLO Gripper y Simulación"""

    # === CONTENEDOR PRINCIPAL ===
    container = tk.Frame(frame)
    container.pack(fill="both", expand=True, padx=10, pady=10)
    container.grid_columnconfigure(0, weight=1)

    # =====================================================================
    # GRIPPER — NUEVA VERSIÓN CON DOS BOTONES
    # =====================================================================
    gripper_frame = tk.LabelFrame(container, text="Gripper", padx=10, pady=10, font=("Arial", 10, "bold"))
    gripper_frame.grid(row=0, column=0, sticky="ew", pady=(0, 8))
    
    def gripper_open():
        send_command("GRIPPER", {"state": "OPEN"})
        log_message("🟢 Gripper ABIERTO")
        gripper_open_btn.config(bg="#4CAF50")
        gripper_close_btn.config(bg="#f44336")
    
    def gripper_close():
        send_command("GRIPPER", {"state": "CLOSE"})
        log_message("🔴 Gripper CERRADO")
        gripper_close_btn.config(bg="#4CAF50")
        gripper_open_btn.config(bg="#f44336")
    
    # Botón ABRIR
    gripper_open_btn = tk.Button(
        gripper_frame, text="ABIERTO",
        font=("Arial", 11, "bold"),
        width=15,
        bg="#4CAF50", fg="white",
        command=gripper_open
    )
    gripper_open_btn.pack(pady=5)
    
    # Botón CERRAR
    gripper_close_btn = tk.Button(
        gripper_frame, text="CERRADO",
        font=("Arial", 11, "bold"),
        width=15,
        bg="#f44336", fg="white",
        command=gripper_close
    )
    gripper_close_btn.pack(pady=5)
    
    # Estado inicial
    # El gripper comienza en CERRADO
    gripper_close_btn.config(bg="#4CAF50")   # botón cerrado resaltado

    # =====================================================================
    # SIMULACIÓN
    # =====================================================================
    sim_frame = tk.LabelFrame(container, text="Simulación", padx=10, pady=10, font=("Arial", 10, "bold"))
    sim_frame.grid(row=1, column=0, sticky="ew", pady=(0, 8))

    global sim_active
    sim_active = tk.BooleanVar(value=False)

    def toggle_sim():
        state = sim_active.get()
        cmd = "SIM_ON" if state else "SIM_OFF"
        send_command(cmd, {})
        log_message("🧪 Simulación ACTIVADA" if state else "🛑 Simulación DESACTIVADA")
        sim_btn.config(bg="#4CAF50" if state else "#f44336", text="SIM ON" if state else "SIM OFF")

    sim_btn = tk.Checkbutton(sim_frame, text="SIM OFF", variable=sim_active, command=toggle_sim,
                             font=("Arial", 11, "bold"), indicatoron=False, width=15, bg="#f44336",
                             fg="white", selectcolor="#4CAF50")
    sim_btn.pack(pady=10)

    # =====================================================================
    # SOLICITAR TRAZADO DEL DRON (DEBUG WAYPOINTS)
    # =====================================================================
    req_frame = tk.LabelFrame(container, text="Trazado del Dron", padx=10, pady=10,font=("Arial", 10, "bold"))
    req_frame.grid(row=2, column=0, sticky="ew", pady=(0, 8))

    def request_esp_traj():
        send_command("REQ_WP_DEBUG", {})
        log_message("📡 Solicitud enviada: Trazado del dron (waypoints ESP)")

    req_btn = tk.Button(
        req_frame,
        text="📡 Solicitar Trazado",
        font=("Arial", 11, "bold"),
        width=15,
        bg="#2196F3",         # azul estilo GS
        fg="white",
        command=request_esp_traj
    )
    req_btn.pack(pady=10)

        # Botón para BORRAR trazado del dron (ESP)
    def clear_esp_traj():
        global esp_mission_path, esp_wp_markers, esp_wp_chunks, esp_wp_total

        # Borrar línea trazada
        if esp_mission_path is not None:
            try:
                safe_delete(esp_mission_path)
            except:
                pass
            esp_mission_path = None

        # Borrar marcadores
        for m in esp_wp_markers:
            try:
                safe_delete(m)
            except:
                pass
        esp_wp_markers.clear()

        # Reset buffers de reconstrucción
        esp_wp_chunks = []
        esp_wp_total = 0

        log_message("🗑 Trazado del dron eliminado")

    clear_btn = tk.Button(req_frame,text="🗑 Borrar Trazado",font=("Arial", 11, "bold"),width=15,bg="#f44336",fg="white",command=clear_esp_traj)
    clear_btn.pack(pady=(0,10))


def create_gui():
    """Construye toda la interfaz (pestañas, botones, mapa, etc.)."""
    global root, mapa, status_label, telemetry_text, log_text
    global port_var, spacing_var, altitude_var, status_message, detect_spacing_var
    global home_position_var, progress_var, progress_bar
    global add_btn, home_btn, delete_btn
    global btn_arm, btn_disarm, btn_mission, btn_return
    global event_action_var

    root = tk.Tk()
    root.title("Ground Station - Dron Buscador Térmico")
    root.geometry("1200x900")

      
    event_action_var = tk.StringVar(value="VOLVER")

    # ---- Barra de conexión ----
    connection_frame = tk.Frame(root)
    connection_frame.pack(fill="x", padx=10, pady=5)

    ports = [port.device for port in serial.tools.list_ports.comports()]
    port_var = tk.StringVar(value=ports[0] if ports else "")

    tk.Label(connection_frame, text="Puerto:").pack(side="left")
    port_combo = ttk.Combobox(connection_frame, textvariable=port_var, values=ports, width=15)
    port_combo.pack(side="left", padx=5)

    def update_ports():
        new_ports = [port.device for port in serial.tools.list_ports.comports()]
        port_combo['values'] = new_ports
        if new_ports and not port_var.get():
            port_var.set(new_ports[0])

    tk.Button(connection_frame, text="Actualizar", command=update_ports).pack(side="left", padx=5)
    tk.Button(connection_frame, text="Conectar", command=connect_serial).pack(side="left", padx=5)
    tk.Button(connection_frame, text="Desconectar", command=disconnect_serial).pack(side="left", padx=5)

    status_label = tk.Label(connection_frame, text="Desconectado", fg="red")
    status_label.pack(side="right")

    # ---- Modo edición ----
    edit_frame = tk.Frame(root)
    edit_frame.pack(fill="x", padx=10, pady=5)

    tk.Label(edit_frame, text="Modo Edición:", font=("Arial", 10, "bold")).pack(side="left")
    add_btn = tk.Button(edit_frame, text="Colocar marcadores", command=lambda: set_edit_mode('polygon'), width=20)
    add_btn.pack(side="left", padx=2)
    home_btn = tk.Button(edit_frame, text="Colocar home", command=set_home_from_telemetry, width=20)
    home_btn.pack(side="left", padx=2)
    delete_btn = tk.Button(edit_frame, text="Eliminar marcadores", command=lambda: set_edit_mode('delete'), width=20)
    delete_btn.pack(side="left", padx=2)

    # ---- Parámetros de misión ----
    params_frame = tk.Frame(root)
    params_frame.pack(fill="x", padx=10, pady=5)

    tk.Label(params_frame, text="Altitud (m):").pack(side="left")
    altitude_var = tk.IntVar(value=3)
    tk.Spinbox(params_frame, from_=1, to=100, width=5, textvariable=altitude_var).pack(side="left", padx=5)

    tk.Label(params_frame, text="Ancho pasadas (m):").pack(side="left", padx=(20, 5))
    spacing_var = tk.IntVar(value=5)
    tk.Spinbox(params_frame, from_=1, to=50, width=5, textvariable=spacing_var).pack(side="left", padx=5)
    def on_spacing_change(*args):
        refresh_mission_preview()    
    spacing_var.trace_add("write", on_spacing_change)

    tk.Label(params_frame, text="Espaciado detecciones (m):").pack(side="left", padx=(20, 5))
    global detect_spacing_var
    detect_spacing_var = tk.IntVar(value=5)
    tk.Spinbox(params_frame, from_=1, to=50, width=5, textvariable=detect_spacing_var).pack(side="left", padx=5)
    def on_detect_change(*args):
        refresh_mission_preview()
    detect_spacing_var.trace_add("write", on_detect_change)

    
    home_position_var = tk.StringVar(value="")
    tk.Label(params_frame, textvariable=home_position_var, fg="green").pack(side="right")

    # ---- Estado y progreso ----
    status_frame = tk.Frame(root)
    status_frame.pack(fill="x", padx=10, pady=5)

    status_message = tk.StringVar(value="Modo: Polígono")
    tk.Label(status_frame, textvariable=status_message, fg="white", bg="#333", font=("Arial", 12, "bold"),padx=8, pady=3).pack(side="left")


    progress_var = tk.StringVar(value="Waypoints: 0/0")
    tk.Label(status_frame, textvariable=progress_var).pack(side="left", padx=20)

    progress_bar = ttk.Progressbar(status_frame, orient="horizontal", length=200, mode="determinate")
    progress_bar.pack(side="left", padx=5)

    # ---- Botones de misión ----
    mission_btn_frame = tk.Frame(root)
    mission_btn_frame.pack(fill="x", padx=10, pady=5)

    btn_mission = tk.Button(mission_btn_frame, text="COMENZAR MISIÓN", command=start_flight,
                            state="disabled", bg="lightgrey", fg="white")
    btn_mission.pack(side="left", expand=True, padx=5)

    btn_return = tk.Button(mission_btn_frame, text="REGRESAR", command=return_home,
                           state="disabled", bg="lightgrey", fg="white")
    btn_return.pack(side="left", expand=True, padx=5)

    tk.Button(mission_btn_frame, text="RESET COMPLETO", command=reset_polygon, bg="red", fg="white").pack(side="left", expand=True, padx=5)
    tk.Button(mission_btn_frame, text="GUARDAR", command=save_mission, bg="blue", fg="white").pack(side="left", expand=True, padx=5)
    tk.Button(mission_btn_frame, text="CARGAR", command=load_mission, bg="purple", fg="white").pack(side="left", expand=True, padx=5)

    tk.Label(mission_btn_frame, text="Acción tras evento:").pack(side="left", padx=5)
    event_action_menu = ttk.Combobox(mission_btn_frame, textvariable=event_action_var,
                                     values=["CONTINUAR", "VOLVER"], state="readonly", width=11)
    event_action_menu.pack(side="left", padx=5)
    event_action_menu.current(1)  # "VOLVER"

    # ---- Notebook ----
    notebook = ttk.Notebook(root)
    notebook.pack(fill="both", expand=True, padx=10, pady=5)

    # Pestaña: Misión
    frame_mission = ttk.Frame(notebook)
    notebook.add(frame_mission, text="Misión")

    # Mapa
    global mapa
    mapa = tkintermapview.TkinterMapView(frame_mission, width=1000, height=500, corner_radius=0)
    mapa.pack(pady=10, fill="both", expand=True)
    mapa.set_position(-34.6037, -58.3816)
    mapa.set_zoom(12)
    mapa.add_left_click_map_command(map_click)
    mapa.set_tile_server(
    "https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}",max_zoom=19)

    # Pestaña: Controles
    frame_controls = ttk.Frame(notebook)
    notebook.add(frame_controls, text="Controles")

    control_btn_frame = tk.Frame(frame_controls)
    control_btn_frame.pack(pady=10)

    global btn_arm, btn_disarm, send_mission_btn
    
    send_mission_btn = tk.Button(control_btn_frame,text="ENVIAR MISIÓN",font=("Arial", 11, "bold"),width=15,bg="#03A9F4",fg="white",
                                 state="normal",command=send_compact_mission)
    send_mission_btn.pack(pady=5)
    
    btn_arm = tk.Button(control_btn_frame, text="ARMAR", command=arm_drone, bg="green", fg="white", width=15)
    btn_arm.pack(side="left", padx=10)

    btn_disarm = tk.Button(control_btn_frame, text="DESARMAR", command=disarm_drone,
                           state="normal", bg="red", fg="white", width=15)
    btn_disarm.pack(side="left", padx=10)

    create_trim_pid_controls(frame_controls)


    # Pestaña: Telemetría
    frame_telemetry = ttk.Frame(notebook)
    notebook.add(frame_telemetry, text="Telemetría")

    global telemetry_text
    telemetry_text = scrolledtext.ScrolledText(frame_telemetry, width=80, height=15)
    telemetry_text.pack(pady=10, fill="both", expand=True)
    telemetry_text.insert("end", "Esperando datos de telemetría...\n")
    telemetry_text.config(state="disabled")

    # Pestaña: Log
    frame_log = ttk.Frame(notebook)
    notebook.add(frame_log, text="Log")

    global log_text
    log_text = scrolledtext.ScrolledText(frame_log, width=80, height=15)
    log_text.pack(pady=10, fill="both", expand=True)
    log_text.config(state="disabled")

    # Modo inicial
    set_edit_mode('polygon')

# =========================
# [13] INICIALIZACIÓN
# =========================
current_mission = MissionData()

# Ejecutar GUI 
create_gui()
log_message("✅ Interfaz lista. Conectá el puerto y espera telemetría...")
root.mainloop()
# Out:
# [SERIAL] ✅ Conectado a COM4 @ 115200 bps
# [SERIAL] 🚀 Lanzando hilos: recepción y ack_manager
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426565,"lon":-58.45495059,"alt":0.353100407,"speed":0.096287374,"heading":155,"battery":96,"voltage":11.79322,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":520771}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426565, 'lon': -58.45495059, 'alt': 0.353100407, 'speed': 0.096287374, 'heading': 155, 'battery': 96, 'voltage': 11.79322, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 520771}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426643,"lon":-58.45495086,"alt":0.354096777,"speed":0.092192365,"heading":155,"battery":96,"voltage":11.79025,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":522113}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426643, 'lon': -58.45495086, 'alt': 0.354096777, 'speed': 0.092192365, 'heading': 155, 'battery': 96, 'voltage': 11.79025, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 522113}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.7742664,"lon":-58.45495143,"alt":0.374361612,"speed":0.106052573,"heading":155,"battery":96,"voltage":11.79159,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":523455}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.7742664, 'lon': -58.45495143, 'alt': 0.374361612, 'speed': 0.106052573, 'heading': 155, 'battery': 96, 'voltage': 11.79159, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 523455}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.7742661,"lon":-58.4549522,"alt":0.407435941,"speed":0.13295745,"heading":155,"battery":96,"voltage":11.78492,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":524792}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.7742661, 'lon': -58.4549522, 'alt': 0.407435941, 'speed': 0.13295745, 'heading': 155, 'battery': 96, 'voltage': 11.78492, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 524792}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426651,"lon":-58.45495307,"alt":0.407225305,"speed":0.124063338,"heading":155,"battery":96,"voltage":11.78348,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":526129}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426651, 'lon': -58.45495307, 'alt': 0.407225305, 'speed': 0.124063338, 'heading': 155, 'battery': 96, 'voltage': 11.78348, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 526129}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426702,"lon":-58.45495408,"alt":0.417867477,"speed":0.065318254,"heading":155,"battery":96,"voltage":11.78964,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":527471}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426702, 'lon': -58.45495408, 'alt': 0.417867477, 'speed': 0.065318254, 'heading': 155, 'battery': 96, 'voltage': 11.78964, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 527471}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426664,"lon":-58.45495517,"alt":0.39770908,"speed":0.102924118,"heading":155,"battery":96,"voltage":11.78552,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":528813}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426664, 'lon': -58.45495517, 'alt': 0.39770908, 'speed': 0.102924118, 'heading': 155, 'battery': 96, 'voltage': 11.78552, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 528813}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426666,"lon":-58.45495578,"alt":0.377444635,"speed":0.093260575,"heading":155,"battery":96,"voltage":11.77595,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":530150}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426666, 'lon': -58.45495578, 'alt': 0.377444635, 'speed': 0.093260575, 'heading': 155, 'battery': 96, 'voltage': 11.77595, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 530150}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.7742667,"lon":-58.45495703,"alt":0.340195277,"speed":0.126542813,"heading":155,"battery":96,"voltage":11.76902,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":531492}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.7742667, 'lon': -58.45495703, 'alt': 0.340195277, 'speed': 0.126542813, 'heading': 155, 'battery': 96, 'voltage': 11.76902, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 531492}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426658,"lon":-58.45495726,"alt":0.311777431,"speed":0.047369317,"heading":155,"battery":96,"voltage":11.78939,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":532829}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426658, 'lon': -58.45495726, 'alt': 0.311777431, 'speed': 0.047369317, 'heading': 155, 'battery': 96, 'voltage': 11.78939, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 532829}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426683,"lon":-58.45495766,"alt":0.291252847,"speed":0.022106775,"heading":155,"battery":96,"voltage":11.81105,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":534171}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426683, 'lon': -58.45495766, 'alt': 0.291252847, 'speed': 0.022106775, 'heading': 155, 'battery': 96, 'voltage': 11.81105, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 534171}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426708,"lon":-58.45495778,"alt":0.293167296,"speed":0.050426,"heading":155,"battery":96,"voltage":11.81318,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":535513}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426708, 'lon': -58.45495778, 'alt': 0.293167296, 'speed': 0.050426, 'heading': 155, 'battery': 96, 'voltage': 11.81318, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 535513}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426715,"lon":-58.45495786,"alt":0.276688466,"speed":0.092001459,"heading":155,"battery":96,"voltage":11.80372,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":536850}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426715, 'lon': -58.45495786, 'alt': 0.276688466, 'speed': 0.092001459, 'heading': 155, 'battery': 96, 'voltage': 11.80372, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 536850}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426732,"lon":-58.45495794,"alt":0.264949681,"speed":0.101900399,"heading":155,"battery":96,"voltage":11.7956,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":538193}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426732, 'lon': -58.45495794, 'alt': 0.264949681, 'speed': 0.101900399, 'heading': 155, 'battery': 96, 'voltage': 11.7956, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 538193}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426729,"lon":-58.45495829,"alt":0.198283627,"speed":0.09784443,"heading":155,"battery":96,"voltage":11.7922,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":539530}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426729, 'lon': -58.45495829, 'alt': 0.198283627, 'speed': 0.09784443, 'heading': 155, 'battery': 96, 'voltage': 11.7922, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 539530}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426818,"lon":-58.45495902,"alt":0.177126651,"speed":0.241936165,"heading":155,"battery":96,"voltage":11.80657,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":540867}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426818, 'lon': -58.45495902, 'alt': 0.177126651, 'speed': 0.241936165, 'heading': 155, 'battery': 96, 'voltage': 11.80657, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 540867}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426923,"lon":-58.45495966,"alt":0.197521321,"speed":0.181916173,"heading":155,"battery":96,"voltage":11.80865,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":542209}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426923, 'lon': -58.45495966, 'alt': 0.197521321, 'speed': 0.181916173, 'heading': 155, 'battery': 96, 'voltage': 11.80865, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 542209}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426915,"lon":-58.45496037,"alt":0.202648384,"speed":0.054540296,"heading":155,"battery":96,"voltage":11.78801,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":543551}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426915, 'lon': -58.45496037, 'alt': 0.202648384, 'speed': 0.054540296, 'heading': 155, 'battery': 96, 'voltage': 11.78801, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 543551}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426886,"lon":-58.45495955,"alt":0.230273988,"speed":0.022677,"heading":155,"battery":96,"voltage":11.78213,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":544893}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426886, 'lon': -58.45495955, 'alt': 0.230273988, 'speed': 0.022677, 'heading': 155, 'battery': 96, 'voltage': 11.78213, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 544893}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426847,"lon":-58.45495925,"alt":0.28589227,"speed":0.119134015,"heading":155,"battery":96,"voltage":11.78506,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":546230}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426847, 'lon': -58.45495925, 'alt': 0.28589227, 'speed': 0.119134015, 'heading': 155, 'battery': 96, 'voltage': 11.78506, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 546230}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426798,"lon":-58.45495888,"alt":0.331560373,"speed":0.171561585,"heading":155,"battery":96,"voltage":11.79303,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":547567}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426798, 'lon': -58.45495888, 'alt': 0.331560373, 'speed': 0.171561585, 'heading': 155, 'battery': 96, 'voltage': 11.79303, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 547567}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426715,"lon":-58.45495783,"alt":0.376724337,"speed":0.202086559,"heading":155,"battery":96,"voltage":11.78922,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":548909}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426715, 'lon': -58.45495783, 'alt': 0.376724337, 'speed': 0.202086559, 'heading': 155, 'battery': 96, 'voltage': 11.78922, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 548909}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426707,"lon":-58.45495547,"alt":0.380682991,"speed":0.3102781,"heading":155,"battery":96,"voltage":11.79843,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":550251}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426707, 'lon': -58.45495547, 'alt': 0.380682991, 'speed': 0.3102781, 'heading': 155, 'battery': 96, 'voltage': 11.79843, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 550251}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426699,"lon":-58.45495332,"alt":0.377994116,"speed":0.333971,"heading":155,"battery":96,"voltage":11.80629,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":551588}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426699, 'lon': -58.45495332, 'alt': 0.377994116, 'speed': 0.333971, 'heading': 155, 'battery': 96, 'voltage': 11.80629, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 551588}
# [TX → LoRa/send_command] Frame enviado → GS#{"t":"MISSION_COMPACT","d":{"p":[[-34.774446,-58.454814],[-34.774338,-58.454905],[-34.774241,-58.454717],[-34.774363,-58.454615]],"h":[-34.774268,-58.454959],"a":2,"s":10,"ds":10,"event_action":"VOLVER"},"ts":1765409429376,"id":"a3ac370c"}#END
# [TX → LoRa/send_compact_mission] Datos misión compacta → {'p': [[-34.774446, -58.454814], [-34.774338, -58.454905], [-34.774241, -58.454717], [-34.774363, -58.454615]], 'h': [-34.774268, -58.454959], 'a': 2, 's': 10, 'ds': 10, 'event_action': 'VOLVER'}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"WP_UPDATE","wp":0,"lat":-34.77437145,"lon":-58.45487681,"ts":552944}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'WP_UPDATE' → {'t': 'WP_UPDATE', 'wp': 0, 'lat': -34.77437145, 'lon': -58.45487681, 'ts': 552944}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"WP_UPDATE","wp":0,"lat":-34.77437145,"lon":-58.45487681,"ts":553256}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'WP_UPDATE' → {'t': 'WP_UPDATE', 'wp': 0, 'lat': -34.77437145, 'lon': -58.45487681, 'ts': 553256}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426659,"lon":-58.45495241,"alt":0.375746895,"speed":0.223509926,"heading":155,"battery":96,"voltage":11.80813,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":553506}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426659, 'lon': -58.45495241, 'alt': 0.375746895, 'speed': 0.223509926, 'heading': 155, 'battery': 96, 'voltage': 11.80813, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 553506}
# [ACK MANAGER → LoRa] 🔄 Reintentando ID=a3ac370c (reintento 1)
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"WP_UPDATE","wp":0,"lat":-34.77437145,"lon":-58.45487681,"ts":554599}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'WP_UPDATE' → {'t': 'WP_UPDATE', 'wp': 0, 'lat': -34.77437145, 'lon': -58.45487681, 'ts': 554599}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"WP_UPDATE","wp":0,"lat":-34.77437145,"lon":-58.45487681,"ts":554911}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'WP_UPDATE' → {'t': 'WP_UPDATE', 'wp': 0, 'lat': -34.77437145, 'lon': -58.45487681, 'ts': 554911}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426594,"lon":-58.45495244,"alt":0.379602046,"speed":0.148782845,"heading":155,"battery":96,"voltage":11.79792,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":555161}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426594, 'lon': -58.45495244, 'alt': 0.379602046, 'speed': 0.148782845, 'heading': 155, 'battery': 96, 'voltage': 11.79792, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 555161}
# [ACK MANAGER → LoRa] 🔄 Reintentando ID=a3ac370c (reintento 2)
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"WP_UPDATE","wp":0,"lat":-34.77437145,"lon":-58.45487681,"ts":556224}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'WP_UPDATE' → {'t': 'WP_UPDATE', 'wp': 0, 'lat': -34.77437145, 'lon': -58.45487681, 'ts': 556224}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"WP_UPDATE","wp":0,"lat":-34.77437145,"lon":-58.45487681,"ts":556536}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'WP_UPDATE' → {'t': 'WP_UPDATE', 'wp': 0, 'lat': -34.77437145, 'lon': -58.45487681, 'ts': 556536}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426563,"lon":-58.45495228,"alt":0.354379197,"speed":0.085044184,"heading":155,"battery":96,"voltage":11.80057,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":556786}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426563, 'lon': -58.45495228, 'alt': 0.354379197, 'speed': 0.085044184, 'heading': 155, 'battery': 96, 'voltage': 11.80057, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 556786}
# [ACK MANAGER → LoRa] 🔄 Reintentando ID=a3ac370c (reintento 3)
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"WP_UPDATE","wp":0,"lat":-34.77437145,"lon":-58.45487681,"ts":557849}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'WP_UPDATE' → {'t': 'WP_UPDATE', 'wp': 0, 'lat': -34.77437145, 'lon': -58.45487681, 'ts': 557849}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"WP_UPDATE","wp":0,"lat":-34.77437145,"lon":-58.45487681,"ts":558161}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'WP_UPDATE' → {'t': 'WP_UPDATE', 'wp': 0, 'lat': -34.77437145, 'lon': -58.45487681, 'ts': 558161}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426557,"lon":-58.45495217,"alt":0.336972474,"speed":0.050194038,"heading":155,"battery":96,"voltage":11.79676,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":558411}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426557, 'lon': -58.45495217, 'alt': 0.336972474, 'speed': 0.050194038, 'heading': 155, 'battery': 96, 'voltage': 11.79676, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 558411}
# [ACK MANAGER] ❌ ACK no recibido tras 3 intentos → ID=a3ac370c
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.7742654,"lon":-58.45495048,"alt":0.327882556,"speed":0.16729462,"heading":155,"battery":96,"voltage":11.79705,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":559754}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.7742654, 'lon': -58.45495048, 'alt': 0.327882556, 'speed': 0.16729462, 'heading': 155, 'battery': 96, 'voltage': 11.79705, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 559754}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426524,"lon":-58.4549486,"alt":0.30662861,"speed":0.172602001,"heading":155,"battery":96,"voltage":11.81168,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":561091}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426524, 'lon': -58.4549486, 'alt': 0.30662861, 'speed': 0.172602001, 'heading': 155, 'battery': 96, 'voltage': 11.81168, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 561091}
# [TX → LoRa/send_command] Frame enviado → GS#{"t":"ARM","d":{},"ts":1765409439636,"id":"b5efed2a"}#END
# [TX → LoRa/arm_drone] Enviando comando ARM
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426445,"lon":-58.45494976,"alt":0.286165275,"speed":0.064356527,"heading":155,"battery":96,"voltage":11.79951,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":563765}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426445, 'lon': -58.45494976, 'alt': 0.286165275, 'speed': 0.064356527, 'heading': 155, 'battery': 96, 'voltage': 11.79951, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 563765}
# [ACK MANAGER → LoRa] 🔄 Reintentando ID=b5efed2a (reintento 1)
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"ARMING","ts":564723}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'ARMING', 'ts': 564723}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'ARMING', 'ts': 564723}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"READY_FOR_MISSION","ts":564837}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'READY_FOR_MISSION', 'ts': 564837}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'READY_FOR_MISSION', 'ts': 564837}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.7742637,"lon":-58.45494947,"alt":0.163484891,"speed":0.119763891,"heading":155,"battery":96,"voltage":11.79329,"armed":true,"mode":"GUIDED","batt_warn":false},"ts":565107}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.7742637, 'lon': -58.45494947, 'alt': 0.163484891, 'speed': 0.119763891, 'heading': 155, 'battery': 96, 'voltage': 11.79329, 'armed': True, 'mode': 'GUIDED', 'batt_warn': False}, 'ts': 565107}
# [ACK MANAGER → LoRa] 🔄 Reintentando ID=b5efed2a (reintento 2)
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"ARMING","ts":566334}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'ARMING', 'ts': 566334}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'ARMING', 'ts': 566334}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"ARMING","ts":564723}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'ARMING', 'ts': 564723}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'ARMING', 'ts': 564723}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426313,"lon":-58.45494974,"alt":0.04961995,"speed":0.176414372,"heading":155,"battery":96,"voltage":11.7924,"armed":true,"mode":"GUIDED","batt_warn":false},"ts":566823}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426313, 'lon': -58.45494974, 'alt': 0.04961995, 'speed': 0.176414372, 'heading': 155, 'battery': 96, 'voltage': 11.7924, 'armed': True, 'mode': 'GUIDED', 'batt_warn': False}, 'ts': 566823}
# [ACK MANAGER → LoRa] 🔄 Reintentando ID=b5efed2a (reintento 3)
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"ARMING","ts":567942}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'ARMING', 'ts': 567942}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'ARMING', 'ts': 567942}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"ARMING","ts":564723}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'ARMING', 'ts': 564723}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'ARMING', 'ts': 564723}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"ARMING","ts":566334}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'ARMING', 'ts': 566334}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'ARMING', 'ts': 566334}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.7742627,"lon":-58.45495023,"alt":0.022825828,"speed":0.152403063,"heading":155,"battery":96,"voltage":11.78997,"armed":true,"mode":"GUIDED","batt_warn":false},"ts":568614}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.7742627, 'lon': -58.45495023, 'alt': 0.022825828, 'speed': 0.152403063, 'heading': 155, 'battery': 96, 'voltage': 11.78997, 'armed': True, 'mode': 'GUIDED', 'batt_warn': False}, 'ts': 568614}
# [ACK MANAGER] ❌ ACK no recibido tras 3 intentos → ID=b5efed2a
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"ARMING","ts":567942}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'ARMING', 'ts': 567942}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'ARMING', 'ts': 567942}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"ARMING","ts":564723}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'ARMING', 'ts': 564723}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'ARMING', 'ts': 564723}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"ARMING","ts":566334}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'ARMING', 'ts': 566334}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'ARMING', 'ts': 566334}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.7742618,"lon":-58.45495012,"alt":-0.002270013,"speed":0.137678298,"heading":155,"battery":96,"voltage":11.78878,"armed":true,"mode":"GUIDED","batt_warn":false},"ts":570155}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.7742618, 'lon': -58.45495012, 'alt': -0.002270013, 'speed': 0.137678298, 'heading': 155, 'battery': 96, 'voltage': 11.78878, 'armed': True, 'mode': 'GUIDED', 'batt_warn': False}, 'ts': 570155}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"ARMING","ts":567942}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'ARMING', 'ts': 567942}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'ARMING', 'ts': 567942}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"ARMING","ts":564723}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'ARMING', 'ts': 564723}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'ARMING', 'ts': 564723}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"ARMING","ts":566334}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'ARMING', 'ts': 566334}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'ARMING', 'ts': 566334}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426086,"lon":-58.45494958,"alt":0.034934948,"speed":0.135834186,"heading":155,"battery":96,"voltage":11.78256,"armed":true,"mode":"GUIDED","batt_warn":false},"ts":571615}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426086, 'lon': -58.45494958, 'alt': 0.034934948, 'speed': 0.135834186, 'heading': 155, 'battery': 96, 'voltage': 11.78256, 'armed': True, 'mode': 'GUIDED', 'batt_warn': False}, 'ts': 571615}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"ARMING","ts":567942}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'ARMING', 'ts': 567942}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'ARMING', 'ts': 567942}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"ARMING","ts":566334}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'ARMING', 'ts': 566334}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'ARMING', 'ts': 566334}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.7742598,"lon":-58.45494994,"alt":0.106428119,"speed":0.166755094,"heading":155,"battery":96,"voltage":11.80371,"armed":true,"mode":"GUIDED","batt_warn":false},"ts":572952}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.7742598, 'lon': -58.45494994, 'alt': 0.106428119, 'speed': 0.166755094, 'heading': 155, 'battery': 96, 'voltage': 11.80371, 'armed': True, 'mode': 'GUIDED', 'batt_warn': False}, 'ts': 572952}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"ARMING","ts":567942}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'ARMING', 'ts': 567942}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'ARMING', 'ts': 567942}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77425891,"lon":-58.45495044,"alt":0.168826739,"speed":0.268906528,"heading":155,"battery":96,"voltage":11.8006,"armed":true,"mode":"GUIDED","batt_warn":false},"ts":574289}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77425891, 'lon': -58.45495044, 'alt': 0.168826739, 'speed': 0.268906528, 'heading': 155, 'battery': 96, 'voltage': 11.8006, 'armed': True, 'mode': 'GUIDED', 'batt_warn': False}, 'ts': 574289}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77425857,"lon":-58.45495191,"alt":0.201615892,"speed":0.30607717,"heading":155,"battery":96,"voltage":11.80302,"armed":true,"mode":"GUIDED","batt_warn":false},"ts":575626}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77425857, 'lon': -58.45495191, 'alt': 0.201615892, 'speed': 0.30607717, 'heading': 155, 'battery': 96, 'voltage': 11.80302, 'armed': True, 'mode': 'GUIDED', 'batt_warn': False}, 'ts': 575626}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77425909,"lon":-58.45495299,"alt":0.231618894,"speed":0.251558,"heading":155,"battery":96,"voltage":11.81161,"armed":true,"mode":"GUIDED","batt_warn":false},"ts":576963}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77425909, 'lon': -58.45495299, 'alt': 0.231618894, 'speed': 0.251558, 'heading': 155, 'battery': 96, 'voltage': 11.81161, 'armed': True, 'mode': 'GUIDED', 'batt_warn': False}, 'ts': 576963}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426062,"lon":-58.4549529,"alt":0.184082124,"speed":0.305565646,"heading":155,"battery":96,"voltage":11.80579,"armed":true,"mode":"GUIDED","batt_warn":false},"ts":578295}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426062, 'lon': -58.4549529, 'alt': 0.184082124, 'speed': 0.305565646, 'heading': 155, 'battery': 96, 'voltage': 11.80579, 'armed': True, 'mode': 'GUIDED', 'batt_warn': False}, 'ts': 578295}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77426271,"lon":-58.4549526,"alt":0.123378386,"speed":0.423289382,"heading":155,"battery":96,"voltage":11.81504,"armed":true,"mode":"GUIDED","batt_warn":false},"ts":579632}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77426271, 'lon': -58.4549526, 'alt': 0.123378386, 'speed': 0.423289382, 'heading': 155, 'battery': 96, 'voltage': 11.81504, 'armed': True, 'mode': 'GUIDED', 'batt_warn': False}, 'ts': 579632}
# [TX → LoRa/send_command] Frame enviado → GS#{"t":"START_FLIGHT","d":{},"ts":1765409457393,"id":"88d6baec"}#END
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"PREPARE_TAKEOFF","ts":580657}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'PREPARE_TAKEOFF', 'ts': 580657}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'PREPARE_TAKEOFF', 'ts': 580657}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"TAKEOFF","ts":580943}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'TAKEOFF', 'ts': 580943}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'TAKEOFF', 'ts': 580943}
# [ACK MANAGER → LoRa] 🔄 Reintentando ID=88d6baec (reintento 1)
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"PREPARE_TAKEOFF","ts":582249}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'PREPARE_TAKEOFF', 'ts': 582249}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'PREPARE_TAKEOFF', 'ts': 582249}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"TAKEOFF","ts":582680}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'TAKEOFF', 'ts': 582680}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'TAKEOFF', 'ts': 582680}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"TAKEOFF","ts":580943}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'TAKEOFF', 'ts': 580943}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'TAKEOFF', 'ts': 580943}
# [ACK MANAGER → LoRa] 🔄 Reintentando ID=88d6baec (reintento 2)
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"PREPARE_TAKEOFF","ts":583859}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'PREPARE_TAKEOFF', 'ts': 583859}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'PREPARE_TAKEOFF', 'ts': 583859}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"PREPARE_TAKEOFF","ts":582249}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'PREPARE_TAKEOFF', 'ts': 582249}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'PREPARE_TAKEOFF', 'ts': 582249}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"TAKEOFF","ts":584364}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'TAKEOFF', 'ts': 584364}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'TAKEOFF', 'ts': 584364}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"TAKEOFF","ts":580943}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'TAKEOFF', 'ts': 580943}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'TAKEOFF', 'ts': 580943}
# [ACK MANAGER → LoRa] 🔄 Reintentando ID=88d6baec (reintento 3)
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"PREPARE_TAKEOFF","ts":585469}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'PREPARE_TAKEOFF', 'ts': 585469}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'PREPARE_TAKEOFF', 'ts': 585469}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"PREPARE_TAKEOFF","ts":582249}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'PREPARE_TAKEOFF', 'ts': 582249}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'PREPARE_TAKEOFF', 'ts': 582249}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"TAKEOFF","ts":586128}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'TAKEOFF', 'ts': 586128}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'TAKEOFF', 'ts': 586128}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"TAKEOFF","ts":580943}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'TAKEOFF', 'ts': 580943}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'TAKEOFF', 'ts': 580943}
# [ACK MANAGER] ❌ ACK no recibido tras 3 intentos → ID=88d6baec
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"NAVIGATE","ts":586841}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'NAVIGATE', 'ts': 586841}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'NAVIGATE', 'ts': 586841}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"WP_UPDATE","wp":1,"lat":-34.77432988,"lon":-58.45477713,"ts":586956}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'WP_UPDATE' → {'t': 'WP_UPDATE', 'wp': 1, 'lat': -34.77432988, 'lon': -58.45477713, 'ts': 586956}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"PREPARE_TAKEOFF","ts":582249}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'PREPARE_TAKEOFF', 'ts': 582249}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'PREPARE_TAKEOFF', 'ts': 582249}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77427263,"lon":-58.45495262,"alt":1.908589753,"speed":0.276834762,"heading":145,"battery":96,"voltage":11.80092,"armed":true,"mode":"GUIDED","batt_warn":false},"ts":587564}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77427263, 'lon': -58.45495262, 'alt': 1.908589753, 'speed': 0.276834762, 'heading': 145, 'battery': 96, 'voltage': 11.80092, 'armed': True, 'mode': 'GUIDED', 'batt_warn': False}, 'ts': 587564}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"TAKEOFF","ts":580943}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'TAKEOFF', 'ts': 580943}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'TAKEOFF', 'ts': 580943}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"PREPARE_TAKEOFF","ts":582249}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'PREPARE_TAKEOFF', 'ts': 582249}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'PREPARE_TAKEOFF', 'ts': 582249}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77427436,"lon":-58.45494875,"alt":2.200664904,"speed":9.701555157,"heading":151,"battery":96,"voltage":11.77864,"armed":true,"mode":"GUIDED","batt_warn":false},"ts":588901}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77427436, 'lon': -58.45494875, 'alt': 2.200664904, 'speed': 9.701555157, 'heading': 151, 'battery': 96, 'voltage': 11.77864, 'armed': True, 'mode': 'GUIDED', 'batt_warn': False}, 'ts': 588901}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"TAKEOFF","ts":582680}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'TAKEOFF', 'ts': 582680}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'TAKEOFF', 'ts': 582680}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"PREPARE_TAKEOFF","ts":583859}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'PREPARE_TAKEOFF', 'ts': 583859}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'PREPARE_TAKEOFF', 'ts': 583859}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77427966,"lon":-58.45492858,"alt":2.211640067,"speed":18.70125046,"heading":154,"battery":96,"voltage":11.77165,"armed":true,"mode":"GUIDED","batt_warn":false},"ts":590238}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77427966, 'lon': -58.45492858, 'alt': 2.211640067, 'speed': 18.70125046, 'heading': 154, 'battery': 96, 'voltage': 11.77165, 'armed': True, 'mode': 'GUIDED', 'batt_warn': False}, 'ts': 590238}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77430009,"lon":-58.45486321,"alt":2.355515065,"speed":13.9869441,"heading":149,"battery":96,"voltage":11.77571,"armed":true,"mode":"GUIDED","batt_warn":false},"ts":591575}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77430009, 'lon': -58.45486321, 'alt': 2.355515065, 'speed': 13.9869441, 'heading': 149, 'battery': 96, 'voltage': 11.77571, 'armed': True, 'mode': 'GUIDED', 'batt_warn': False}, 'ts': 591575}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77431828,"lon":-58.45480646,"alt":2.430073453,"speed":5.804515314,"heading":158,"battery":96,"voltage":11.78816,"armed":true,"mode":"GUIDED","batt_warn":false},"ts":592912}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77431828, 'lon': -58.45480646, 'alt': 2.430073453, 'speed': 5.804515314, 'heading': 158, 'battery': 96, 'voltage': 11.78816, 'armed': True, 'mode': 'GUIDED', 'batt_warn': False}, 'ts': 592912}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"WAYPOINT_REACHED","wp":1,"ts":594240}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'WAYPOINT_REACHED' → {'t': 'WAYPOINT_REACHED', 'wp': 1, 'ts': 594240}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77432685,"lon":-58.45478098,"alt":2.279162938,"speed":0.801427,"heading":154,"battery":96,"voltage":11.7963,"armed":true,"mode":"GUIDED","batt_warn":false},"ts":594444}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77432685, 'lon': -58.45478098, 'alt': 2.279162938, 'speed': 0.801427, 'heading': 154, 'battery': 96, 'voltage': 11.7963, 'armed': True, 'mode': 'GUIDED', 'batt_warn': False}, 'ts': 594444}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"WAIT_ANALYSIS","ts":595579}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'WAIT_ANALYSIS', 'ts': 595579}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'WAIT_ANALYSIS', 'ts': 595579}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77432948,"lon":-58.4547745,"alt":2.112699992,"speed":1.012906945,"heading":159,"battery":96,"voltage":11.8036,"armed":true,"mode":"GUIDED","batt_warn":false},"ts":595776}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77432948, 'lon': -58.4547745, 'alt': 2.112699992, 'speed': 1.012906945, 'heading': 159, 'battery': 96, 'voltage': 11.8036, 'armed': True, 'mode': 'GUIDED', 'batt_warn': False}, 'ts': 595776}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77432949,"lon":-58.45477694,"alt":2.033385674,"speed":0.846095645,"heading":164,"battery":96,"voltage":11.79554,"armed":true,"mode":"GUIDED","batt_warn":false},"ts":597108}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77432949, 'lon': -58.45477694, 'alt': 2.033385674, 'speed': 0.846095645, 'heading': 164, 'battery': 96, 'voltage': 11.79554, 'armed': True, 'mode': 'GUIDED', 'batt_warn': False}, 'ts': 597108}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"STABILIZE","ts":594339}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'STABILIZE', 'ts': 594339}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'STABILIZE', 'ts': 594339}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"NAVIGATE","ts":597859}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'NAVIGATE', 'ts': 597859}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'NAVIGATE', 'ts': 597859}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77432854,"lon":-58.454778,"alt":2.081875936,"speed":0.860777038,"heading":154,"battery":96,"voltage":11.79554,"armed":true,"mode":"GUIDED","batt_warn":false},"ts":598445}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77432854, 'lon': -58.454778, 'alt': 2.081875936, 'speed': 0.860777038, 'heading': 154, 'battery': 96, 'voltage': 11.79554, 'armed': True, 'mode': 'GUIDED', 'batt_warn': False}, 'ts': 598445}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"WAIT_ANALYSIS","ts":595579}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'WAIT_ANALYSIS', 'ts': 595579}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'WAIT_ANALYSIS', 'ts': 595579}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"STABILIZE","ts":594339}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'STABILIZE', 'ts': 594339}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'STABILIZE', 'ts': 594339}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"NAVIGATE","ts":597859}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'NAVIGATE', 'ts': 597859}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'NAVIGATE', 'ts': 597859}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77432414,"lon":-58.45477102,"alt":2.183662978,"speed":11.50693,"heading":160,"battery":96,"voltage":11.79943,"armed":true,"mode":"GUIDED","batt_warn":false},"ts":599777}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77432414, 'lon': -58.45477102, 'alt': 2.183662978, 'speed': 11.50693, 'heading': 160, 'battery': 96, 'voltage': 11.79943, 'armed': True, 'mode': 'GUIDED', 'batt_warn': False}, 'ts': 599777}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"WAIT_ANALYSIS","ts":595579}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'WAIT_ANALYSIS', 'ts': 595579}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'WAIT_ANALYSIS', 'ts': 595579}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"STABILIZE","ts":594339}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'STABILIZE', 'ts': 594339}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'STABILIZE', 'ts': 594339}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"NAVIGATE","ts":597859}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'NAVIGATE', 'ts': 597859}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'NAVIGATE', 'ts': 597859}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77431163,"lon":-58.45473759,"alt":2.466477962,"speed":8.747376251,"heading":159,"battery":96,"voltage":11.79451,"armed":true,"mode":"GUIDED","batt_warn":false},"ts":601109}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77431163, 'lon': -58.45473759, 'alt': 2.466477962, 'speed': 8.747376251, 'heading': 159, 'battery': 96, 'voltage': 11.79451, 'armed': True, 'mode': 'GUIDED', 'batt_warn': False}, 'ts': 601109}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"WAIT_ANALYSIS","ts":595579}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'WAIT_ANALYSIS', 'ts': 595579}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'WAIT_ANALYSIS', 'ts': 595579}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77429982,"lon":-58.45470542,"alt":2.326389789,"speed":2.437226343,"heading":155,"battery":96,"voltage":11.78272,"armed":true,"mode":"GUIDED","batt_warn":false},"ts":602446}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77429982, 'lon': -58.45470542, 'alt': 2.326389789, 'speed': 2.437226343, 'heading': 155, 'battery': 96, 'voltage': 11.78272, 'armed': True, 'mode': 'GUIDED', 'batt_warn': False}, 'ts': 602446}
# ...
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77427078, 'lon': -58.45494699, 'alt': -0.545580096, 'speed': 2.610559916, 'heading': 209, 'battery': 96, 'voltage': 11.75107, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 636135}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77427222,"lon":-58.45494235,"alt":-1.413627482,"speed":2.617695665,"heading":213,"battery":96,"voltage":11.74884,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":637477}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77427222, 'lon': -58.45494235, 'alt': -1.413627482, 'speed': 2.617695665, 'heading': 213, 'battery': 96, 'voltage': 11.74884, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 637477}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77427249,"lon":-58.45494021,"alt":-2.106054061,"speed":3.518063235,"heading":216,"battery":96,"voltage":11.74656,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":638819}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77427249, 'lon': -58.45494021, 'alt': -2.106054061, 'speed': 3.518063235, 'heading': 216, 'battery': 96, 'voltage': 11.74656, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 638819}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77427258,"lon":-58.45493852,"alt":-2.754398571,"speed":3.245834899,"heading":213,"battery":96,"voltage":11.74372,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":640161}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77427258, 'lon': -58.45493852, 'alt': -2.754398571, 'speed': 3.245834899, 'heading': 213, 'battery': 96, 'voltage': 11.74372, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 640161}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77427318,"lon":-58.45493468,"alt":-3.49948466,"speed":2.932187247,"heading":208,"battery":96,"voltage":11.75619,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":641503}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77427318, 'lon': -58.45493468, 'alt': -3.49948466, 'speed': 2.932187247, 'heading': 208, 'battery': 96, 'voltage': 11.75619, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 641503}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77427383,"lon":-58.45493367,"alt":-3.882623857,"speed":2.366400576,"heading":197,"battery":96,"voltage":11.75373,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":642845}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77427383, 'lon': -58.45493367, 'alt': -3.882623857, 'speed': 2.366400576, 'heading': 197, 'battery': 96, 'voltage': 11.75373, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 642845}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77427484,"lon":-58.45493482,"alt":-4.11196699,"speed":2.154565,"heading":205,"battery":96,"voltage":11.78698,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":644187}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77427484, 'lon': -58.45493482, 'alt': -4.11196699, 'speed': 2.154565, 'heading': 205, 'battery': 96, 'voltage': 11.78698, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 644187}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77427664,"lon":-58.45493729,"alt":-4.357669117,"speed":2.754689384,"heading":175,"battery":96,"voltage":11.77372,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":645524}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77427664, 'lon': -58.45493729, 'alt': -4.357669117, 'speed': 2.754689384, 'heading': 175, 'battery': 96, 'voltage': 11.77372, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 645524}
# [TX → LoRa/send_command] Frame enviado → GS#{"t":"REQ_WP_DEBUG","d":{},"ts":1765409523941,"id":"cfeb1ddc"}#END
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77428327,"lon":-58.45494043,"alt":-4.597900438,"speed":1.747724283,"heading":160,"battery":96,"voltage":11.7894,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":648208}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77428327, 'lon': -58.45494043, 'alt': -4.597900438, 'speed': 1.747724283, 'heading': 160, 'battery': 96, 'voltage': 11.7894, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 648208}
# [ACK MANAGER → LoRa] 🔄 Reintentando ID=cfeb1ddc (reintento 1)
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77428264,"lon":-58.45494281,"alt":-4.577647272,"speed":1.504985,"heading":158,"battery":96,"voltage":11.78704,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":649550}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77428264, 'lon': -58.45494281, 'alt': -4.577647272, 'speed': 1.504985, 'heading': 158, 'battery': 96, 'voltage': 11.78704, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 649550}
# [ACK MANAGER → LoRa] 🔄 Reintentando ID=cfeb1ddc (reintento 2)
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77428205,"lon":-58.45494495,"alt":-4.723607763,"speed":1.401473951,"heading":159,"battery":96,"voltage":11.77239,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":650887}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77428205, 'lon': -58.45494495, 'alt': -4.723607763, 'speed': 1.401473951, 'heading': 159, 'battery': 96, 'voltage': 11.77239, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 650887}
# [ACK MANAGER → LoRa] 🔄 Reintentando ID=cfeb1ddc (reintento 3)
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77428223,"lon":-58.45494519,"alt":-4.993236587,"speed":1.155603468,"heading":149,"battery":96,"voltage":11.78256,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":652229}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77428223, 'lon': -58.45494519, 'alt': -4.993236587, 'speed': 1.155603468, 'heading': 149, 'battery': 96, 'voltage': 11.78256, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 652229}
# [ACK MANAGER] ❌ ACK no recibido tras 3 intentos → ID=cfeb1ddc
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77428238,"lon":-58.45494618,"alt":-4.846640128,"speed":2.066413522,"heading":149,"battery":96,"voltage":11.78669,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":653571}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77428238, 'lon': -58.45494618, 'alt': -4.846640128, 'speed': 2.066413522, 'heading': 149, 'battery': 96, 'voltage': 11.78669, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 653571}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77428135,"lon":-58.45494504,"alt":-4.241731809,"speed":2.588941741,"heading":148,"battery":96,"voltage":11.79041,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":654913}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77428135, 'lon': -58.45494504, 'alt': -4.241731809, 'speed': 2.588941741, 'heading': 148, 'battery': 96, 'voltage': 11.79041, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 654913}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77428191,"lon":-58.45494395,"alt":-3.199308012,"speed":2.342687058,"heading":148,"battery":95,"voltage":11.80499,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":656255}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77428191, 'lon': -58.45494395, 'alt': -3.199308012, 'speed': 2.342687058, 'heading': 148, 'battery': 95, 'voltage': 11.80499, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 656255}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77428214,"lon":-58.45494416,"alt":-2.092630015,"speed":1.942265654,"heading":148,"battery":95,"voltage":11.80335,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":657597}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77428214, 'lon': -58.45494416, 'alt': -2.092630015, 'speed': 1.942265654, 'heading': 148, 'battery': 95, 'voltage': 11.80335, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 657597}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77428103,"lon":-58.4549438,"alt":-0.795651724,"speed":1.925777,"heading":148,"battery":95,"voltage":11.80676,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":658939}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77428103, 'lon': -58.4549438, 'alt': -0.795651724, 'speed': 1.925777, 'heading': 148, 'battery': 95, 'voltage': 11.80676, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 658939}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77428204,"lon":-58.45494344,"alt":0.273048687,"speed":1.43451308,"heading":149,"battery":95,"voltage":11.79926,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":660276}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77428204, 'lon': -58.45494344, 'alt': 0.273048687, 'speed': 1.43451308, 'heading': 149, 'battery': 95, 'voltage': 11.79926, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 660276}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77428311,"lon":-58.45494642,"alt":0.960430296,"speed":1.215154839,"heading":149,"battery":95,"voltage":11.80097,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":661613}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77428311, 'lon': -58.45494642, 'alt': 0.960430296, 'speed': 1.215154839, 'heading': 149, 'battery': 95, 'voltage': 11.80097, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 661613}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77428381,"lon":-58.45494918,"alt":1.567446232,"speed":1.152052867,"heading":150,"battery":95,"voltage":11.80027,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":662955}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77428381, 'lon': -58.45494918, 'alt': 1.567446232, 'speed': 1.152052867, 'heading': 150, 'battery': 95, 'voltage': 11.80027, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 662955}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77428368,"lon":-58.45495011,"alt":1.974538447,"speed":1.236873436,"heading":150,"battery":95,"voltage":11.78801,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":664297}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77428368, 'lon': -58.45495011, 'alt': 1.974538447, 'speed': 1.236873436, 'heading': 150, 'battery': 95, 'voltage': 11.78801, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 664297}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77428416,"lon":-58.45495031,"alt":2.160000823,"speed":1.378209329,"heading":150,"battery":95,"voltage":11.78599,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":665639}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77428416, 'lon': -58.45495031, 'alt': 2.160000823, 'speed': 1.378209329, 'heading': 150, 'battery': 95, 'voltage': 11.78599, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 665639}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77428615,"lon":-58.45495118,"alt":2.221694238,"speed":1.719259071,"heading":150,"battery":95,"voltage":11.79082,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":666981}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77428615, 'lon': -58.45495118, 'alt': 2.221694238, 'speed': 1.719259071, 'heading': 150, 'battery': 95, 'voltage': 11.79082, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 666981}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77428851,"lon":-58.45495368,"alt":2.280437152,"speed":1.806913662,"heading":150,"battery":95,"voltage":11.79114,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":668323}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77428851, 'lon': -58.45495368, 'alt': 2.280437152, 'speed': 1.806913662, 'heading': 150, 'battery': 95, 'voltage': 11.79114, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 668323}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77429015,"lon":-58.45495519,"alt":2.276088113,"speed":1.8464432,"heading":151,"battery":95,"voltage":11.774,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":669665}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77429015, 'lon': -58.45495519, 'alt': 2.276088113, 'speed': 1.8464432, 'heading': 151, 'battery': 95, 'voltage': 11.774, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 669665}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77429181,"lon":-58.45495663,"alt":2.205582821,"speed":1.805058861,"heading":151,"battery":95,"voltage":11.78704,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":670997}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77429181, 'lon': -58.45495663, 'alt': 2.205582821, 'speed': 1.805058861, 'heading': 151, 'battery': 95, 'voltage': 11.78704, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 670997}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77429247,"lon":-58.45495865,"alt":2.10428772,"speed":1.675139093,"heading":151,"battery":95,"voltage":11.79185,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":672339}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77429247, 'lon': -58.45495865, 'alt': 2.10428772, 'speed': 1.675139093, 'heading': 151, 'battery': 95, 'voltage': 11.79185, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 672339}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.7742923,"lon":-58.45496151,"alt":1.999514419,"speed":1.515686,"heading":151,"battery":95,"voltage":11.78895,"armed":false,"mode":"UNKNOWN","batt_warn":false},"ts":673676}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.7742923, 'lon': -58.45496151, 'alt': 1.999514419, 'speed': 1.515686, 'heading': 151, 'battery': 95, 'voltage': 11.78895, 'armed': False, 'mode': 'UNKNOWN', 'batt_warn': False}, 'ts': 673676}
# [SERIAL] ✅ Puerto cerrado correctamente
