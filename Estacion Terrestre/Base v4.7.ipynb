# %%
# ================================================================
#  Ground Station (GS) - GUI + LoRa bridge 
# ================================================================

# =========================
# [1] IMPORTS Y CONSTANTES
# =========================
import tkinter as tk
from tkinter import ttk, messagebox, scrolledtext, filedialog
import serial
import serial.tools.list_ports
import threading
import time
import json
import pickle
from math import inf
import tkintermapview
from geographiclib.geodesic import Geodesic
import uuid

# Protocolo de comunicación
HEADER_OUT = "GS#"    # lo que ENVÍA la base
HEADER_IN  = "UAV#"   # lo que RECIBE la base
FOOTER     = "#END"

# Serial
SERIAL_PORT = None
SERIAL_BAUDRATE = 115200
ser = None
is_connected = False

# ACK
ACK_TIMEOUT = 1.5        # segundos para esperar ACK
MAX_RETRIES = 3          # reintentos máximos
pending_acks = {}        # { id: {"frame": str, "timestamp": float, "retries": int} }
ack_lock = threading.Lock()

# Estado
last_telemetry_pos = None

# Edición de mapa
EDIT_MODE = 'polygon'  # 'move', 'delete', 'home', 'polygon'

# =========================
# [2] ESTRUCTURAS DE DATOS
# =========================
class MissionData:
    def __init__(self):
        self.polygon_points = []   # [(lat, lon), ...]
        self.home_position = None  # (lat, lon) o None
        self.altitude = 30         # Altitud de misión (m)
        self.spacing = 10          # Ancho entre pasadas (m)
        self.takeoff_altitude = 10 # Altura de despegue (m)

    def to_dict(self):
        """Convierte a diccionario compacto para LoRa"""
        return {
            "p": [[round(lat, 6), round(lon, 6)] for lat, lon in self.polygon_points],
            "h": [round(self.home_position[0], 6), round(self.home_position[1], 6)] if self.home_position else None,
            "a": self.altitude,
            "s": self.spacing,
        }

    def from_dict(self, data):
        """Carga desde diccionario"""
        self.polygon_points = [tuple(point) for point in data.get("p", [])]
        self.home_position = tuple(data["h"]) if data.get("h") else None
        self.altitude = data.get("a", 30)
        self.spacing = data.get("s", 10)

# =========================
# [3] VARIABLES GLOBALES GUI
# =========================
# Mapa y marcadores
polygon_markers = []
polygon_path = None
home_marker = None
home_line = None
mission_path = None
waypoint_markers = []
waypoint_status = []
fire_markers = []
person_markers = []

# Controles / widgets
btn_disarm = None
btn_mission = None
btn_return = None
btn_arm = None
lbl_mag = None
mag_quality = None
event_action_var = None
port_var = None
spacing_var = None
altitude_var = None
status_message = None
home_position_var = None
progress_var = None
progress_bar = None

# Trim/Gripper
trim_accel_var = None
trim_roll_lr_var = None
trim_roll_fb_var = None
trim_rudder_var = None
trim_switch_var = None
slider_accel = None
slider_roll_lr = None
slider_roll_fb = None
slider_rudder = None
slider_switch = None
gripper_state_var = None
handle_trim_response_global = None  
handle_pid_status_global = None

# Vistas
root = None
mapa = None
telemetry_text = None
log_text = None

# =========================
# [4] UTILIDADES GEODÉSICAS
# =========================
def calculate_distance(lat1, lon1, lat2, lon2):
    """Distancia en metros entre dos puntos"""
    return Geodesic.WGS84.Inverse(lat1, lon1, lat2, lon2)['s12']

def calculate_bearing(lat1, lon1, lat2, lon2):
    """Rumbo en grados entre dos puntos"""
    return Geodesic.WGS84.Inverse(lat1, lon1, lat2, lon2)['azi1']

def get_point_at_distance(lat1, lon1, bearing, distance):
    """Punto desde (lat1, lon1) a distancia (m) y rumbo (°)"""
    result = Geodesic.WGS84.Direct(lat1, lon1, bearing, distance)
    return (result['lat2'], result['lon2'])

# =========================================================
# [5] LOG Y TELEMETRÍA (SEGUROS PARA LLAMAR DESDE HILOS)
# =========================================================
def log_message(message):
    """Agrega texto al log de manera segura desde cualquier hilo."""
    try:
        timestamp = time.strftime('%H:%M:%S')
        full_msg = f"{timestamp} - {message}\n"

        if 'log_text' not in globals() or not log_text:
            print(full_msg.strip())  # fallback si GUI aún no existe
            return

        def update_log():
            log_text.config(state="normal")
            log_text.insert("end", full_msg)
            log_text.see("end")
            log_text.config(state="disabled")

        root.after(0, update_log)
    except Exception as e:
        print(f"[Log Error] {e} :: {message}")

def update_telemetry(data):
    """Actualiza panel de telemetría y marcador del dron."""
    if not root:
        return

    def update_gui():
        global last_telemetry_pos
        telemetry_text.config(state="normal")
        telemetry_text.delete(1.0, "end")

        telemetry_str = f"Latitud: {data.get('lat', 'N/A')}\n"
        telemetry_str += f"Longitud: {data.get('lon', 'N/A')}\n"
        telemetry_str += f"Altitud: {data.get('alt', 'N/A')} m\n"
        telemetry_str += f"Velocidad: {data.get('speed', 'N/A')} km/h\n"
        telemetry_str += f"Rumbo: {data.get('heading', 'N/A')}°\n"
        telemetry_str += f"Batería: {data.get('battery', 'N/A')}\n"
        telemetry_str += f"Estado: {data.get('status', 'N/A')}\n"
        telemetry_str += f"Waypoint actual: {data.get('current_wp', 'N/A')}\n"
        telemetry_str += f"Waypoints totales: {data.get('total_wp', 'N/A')}\n"

        telemetry_text.insert("end", telemetry_str)
        telemetry_text.config(state="disabled")

        if 'lat' in data and 'lon' in data and data['lat'] != 'N/A' and data['lon'] != 'N/A':
            last_telemetry_pos = (data['lat'], data['lon'])
            update_drone_position(data['lat'], data['lon'])

    root.after(0, update_gui)

def update_drone_position(lat, lon):
    """Dibuja/actualiza el marcador del dron en el mapa."""
    if hasattr(update_drone_position, "marker") and update_drone_position.marker:
        update_drone_position.marker.delete()

    update_drone_position.marker = mapa.set_marker(
        lat, lon, text="DRON",
        marker_color_circle="red", marker_color_outside="red",
        text_color="red", font=("Helvetica", 12, "bold")
    )

    current_center = mapa.get_position()
    if calculate_distance(current_center[0], current_center[1], lat, lon) > 5000:
        mapa.set_position(lat, lon)
        mapa.set_zoom(15)

# =====================================
# [6] COMUNICACIÓN: CONEXIÓN / ENVÍOS
# =====================================
def connect_serial():
    """Conecta el puerto serial y lanza los hilos de recepción y ACK."""
    global ser, is_connected, SERIAL_PORT

    is_connected = False
    SERIAL_PORT = port_var.get()

    if not SERIAL_PORT:
        messagebox.showerror("Error", "Selecciona un puerto serial primero")
        return False

    try:
        ser = serial.Serial(SERIAL_PORT, SERIAL_BAUDRATE, timeout=1)
        ser.reset_input_buffer()
        ser.reset_output_buffer()

        is_connected = True
        print(f"[SERIAL] ✅ Conectado a {SERIAL_PORT} @ {SERIAL_BAUDRATE} bps")
        status_label.config(text=f"Conectado: {SERIAL_PORT}", fg="green")
        log_message(f"✅ Conectado correctamente a {SERIAL_PORT} a {SERIAL_BAUDRATE} bps")

        if 'root' in globals() and root:
            print("[SERIAL] 🚀 Lanzando hilos: recepción y ack_manager")
            threading.Thread(target=receive_data, daemon=True).start()
            threading.Thread(target=ack_manager, daemon=True).start()
        else:
            print("[SERIAL] ⚠️ GUI no inicializada aún, no se lanzan hilos")

        return True

    except Exception as e:
        is_connected = False
        print(f"[SERIAL] ❌ Error conectando a {SERIAL_PORT}: {e}")
        log_message(f"❌ Error conectando al puerto {SERIAL_PORT}: {e}")
        messagebox.showerror("Error", f"No se pudo conectar: {str(e)}")
        return False

def disconnect_serial():
    """Desconecta el puerto serial de forma segura y limpia."""
    global ser, is_connected

    if not is_connected:
        print("[SERIAL] ⚠️ No hay conexión activa para cerrar.")
        log_message("⚠️ No hay conexión activa para cerrar.")
        return

    try:
        is_connected = False
        time.sleep(0.2)  # permitir que terminen hilos
        if ser and ser.is_open:
            ser.close()
        status_label.config(text="Desconectado", fg="red")
        log_message("🔌 Puerto serial cerrado correctamente")
        print("[SERIAL] ✅ Puerto cerrado correctamente")
    except Exception as e:
        log_message(f"⚠️ Error al cerrar el puerto serial: {e}")
        print(f"[SERIAL] ⚠️ Error al cerrar puerto: {e}")
    finally:
        ser = None

def send_command(command_type, data=None, require_ack=True):
    """Forma el frame GS#...#END, envía y registra para ACK si corresponde."""
    if not is_connected:
        messagebox.showwarning("Error", "No hay conexión serial")
        return

    # ID único del paquete
    packet_id = str(uuid.uuid4())[:8]

    message = {
        "t": command_type,
        "d": data if data else {},
        "ts": int(time.time() * 1000),
        "id": packet_id
    }

    payload = json.dumps(message, separators=(",", ":"))
    frame   = f"{HEADER_OUT}{payload}{FOOTER}"

    try:
        # 🟦 Print de envío completo
        print(f"[TX → LoRa/send_command] Frame enviado → {frame}")
        
        ser.write(frame.encode())
        log_message(f"Enviado: {frame}")

        if require_ack and command_type != "TELEMETRY":
            with ack_lock:
                pending_acks[packet_id] = {
                    "frame": frame,
                    "timestamp": time.time(),
                    "retries": 0
                }

    except Exception as e:
        log_message(f"Error enviando: {str(e)}")

# ========================================
# [7] COMUNICACIÓN: RECEPCIÓN Y ACKs
# ========================================
def ack_manager():
    """Reintenta envíos sin ACK dentro del timeout."""
    while is_connected:
        time.sleep(0.2)
        now = time.time()

        with ack_lock:
            to_delete = []
            for pid, info in list(pending_acks.items()):
                if now - info["timestamp"] > ACK_TIMEOUT:
                    if info["retries"] < MAX_RETRIES:
                        try:
                            ser.write(info["frame"].encode())
                            pending_acks[pid]["timestamp"] = now
                            pending_acks[pid]["retries"] += 1
                            print(f"[ACK MANAGER → LoRa] 🔄 Reintentando ID={pid} (reintento {info['retries']})")
                            log_message(f"🔄 Reintentando envío ID={pid}")
                        except Exception as e:
                            print(f"[ACK MANAGER] ⚠️ Error reintentando ID={pid}: {e}")
                            log_message(f"Error reintentando ID={pid}: {e}")
                    else:
                        log_message(f"❌ No se recibió ACK para ID={pid}")
                        print(f"[ACK MANAGER] ❌ ACK no recibido tras {MAX_RETRIES} intentos → ID={pid}")
                        to_delete.append(pid)

            for pid in to_delete:
                del pending_acks[pid]

def receive_data():
    """Lee y procesa frames UAV#...#END desde el serial."""
    global is_connected
    buffer = ""

    while is_connected:
        if not ser or not ser.is_open:
            break
        try:
            if ser.in_waiting > 0:
                chunk = ser.read(ser.in_waiting).decode(errors="ignore")
                buffer += chunk

                while True:
                    h = buffer.find(HEADER_IN)
                    if h < 0:
                        if len(buffer) > 4096:
                            buffer = buffer[-512:]
                        break

                    f = buffer.find(FOOTER, h)
                    if f < 0:
                        if h > 0: buffer = buffer[h:]
                        break

                    payload = buffer[h + len(HEADER_IN):f].strip()
                    buffer = buffer[f + len(FOOTER):]

                    # 🟩 Print de recepción de paquete completo
                    print(f"[RX ← LoRa/receive_data] Frame recibido ← UAV#{payload}#END")

                    try:
                        msg = json.loads(payload)
                        process_received_message(msg)
                    except Exception as e:
                        log_message(f"❌ Mensaje inválido: {payload[:80]} ({e})")

            time.sleep(0.01)
        except Exception as e:
            log_message(f"Error recibiendo datos: {e}")
            time.sleep(0.1)

    log_message("📴 Hilo de recepción terminado")

def process_received_message(message):
    """
    Procesa cualquier JSON recibido desde el dron (UAV).
    Envía ACK automáticos cuando corresponde (manteniendo framing GS#/UAV# y #END).
    """

    msg_type = message.get("t", "")
    data = message.get("d", message)   # <— CORRECTO Y BIEN INDENTADO
    packet_id = message.get("id", data.get("id", None))

    print(f"[RX ← LoRa/process_received_message] Mensaje recibido tipo '{msg_type}' → {message}")

    if not msg_type:
        log_message(f"⚠️ Mensaje sin tipo: {message}")
        return

    # =====================================================================================
    # ACK entrante desde UAV
    # =====================================================================================
    if msg_type == "ACK":
        print(f"[ACK IN ← LoRa/process_received_message] {message}")
        ack_id = None

        if "id" in message:
            ack_id = message["id"]
        elif isinstance(message.get("d"), dict) and "id" in message["d"]:
            ack_id = message["d"]["id"]

        if ack_id:
            with ack_lock:
                if ack_id in pending_acks:
                    del pending_acks[ack_id]
                    log_message(f"✅ ACK recibido para ID={ack_id}")
                else:
                    log_message(f"⚠️ ACK recibido con ID desconocido: {ack_id}")
        else:
            log_message("⚠️ ACK recibido sin ID válido")

        return

    # =====================================================================================
    # TELEMETRY
    # =====================================================================================
    if msg_type == "TELEMETRY":
        update_telemetry(data)
        return

    # =====================================================================================
    # STATUS
    # =====================================================================================
    elif msg_type == "STATUS":
        # El ESP envía d["message"], pero dejamos compatibilidad futura con "state"
        estado = data.get("state", "") or data.get("message", "")

        print(f"[STATUS ← LoRa] Estado FSM = {estado}")
        log_message(f"Estado FSM: {estado}")

        status_message.set(f"Estado: {estado}")
        return

    # =====================================================================================
    # WAYPOINTS_INFO
    # =====================================================================================
    elif msg_type == "WAYPOINTS_INFO":
        total = data.get("total", 0)
        initialize_waypoint_tracking(total)
        log_message(f"Total de waypoints: {total}")
        progress_bar['value'] = 0
        return

    # =====================================================================================
    # WAYPOINT_REACHED
    # =====================================================================================
    elif msg_type == "WAYPOINT_REACHED":
        wp = data.get("wp", -1)

        print(f"[WAYPOINT_REACHED ← LoRa] WP alcanzado: {wp}")
        log_message(f"Waypoint alcanzado: {wp}")

        waypoint_reached(wp)
        return

    # =====================================================================================
    # DEBUG
    # =====================================================================================
    elif msg_type == "DEBUG":
        print(f"[DEBUG ← LoRa] Data: {data}")
        log_message(f"🪲 DEBUG: {data.get('message', '')}")
        return

    # =====================================================================================
    # FIRE
    # =====================================================================================
    elif msg_type == "FIRE":
        confidence = data.get("confidence", None)

        print(f"[FIRE ← LoRa] Data: {data}")

        if confidence is not None:
            try:
                confidence = float(confidence)
                if confidence > 1:
                    confidence /= 100.0
            except:
                confidence = None

            log_message(f"🔥 Evento FIRE detectado (confianza={confidence*100:.1f}%)")
        else:
            log_message("🔥 Evento FIRE detectado (sin dato de confianza)")

        add_fire_marker(data)
        return

    # =====================================================================================
    # PERSON
    # =====================================================================================
    elif msg_type == "PERSON":
        confidence = data.get("confidence", None)

        print(f"[PERSON ← LoRa] Data: {data}")

        if confidence is not None:
            try:
                confidence = float(confidence)
                if confidence > 1:
                    confidence /= 100.0
            except:
                confidence = None

            log_message(f"🧍 Evento PERSON detectado (confianza={confidence*100:.1f}%)")
        else:
            log_message("🧍 Evento PERSON detectado (sin dato de confianza)")

        add_person_marker(data)
        return

# ======================================
# [8] GESTIÓN DE MISIÓN (ENVÍOS, ESTADO)
# ======================================
def update_mission_parameters():
    current_mission.altitude = altitude_var.get()
    current_mission.spacing = spacing_var.get()
    log_message("Parámetros de misión actualizados")

def send_compact_mission():
    if len(current_mission.polygon_points) < 1:
        messagebox.showwarning("Error", "Definí al menos 1 punto en el mapa")
        return

    if not current_mission.home_position:
        messagebox.showwarning("Error", "Establece una posición HOME primero")
        return
    update_mission_parameters()
    mission_dict = current_mission.to_dict()
    mission_dict["event_action"] = event_action_var.get()
    send_command("MISSION_COMPACT", mission_dict)
    print(f"[TX → LoRa/send_compact_mission] Datos misión compacta → {mission_dict}")
    log_message(f"Misión enviada (formato compacto) con acción tras evento: {event_action_var.get()}")

def start_mission():
    btn_return.config(state="normal", bg="orange")
    send_compact_mission()

def return_home():
   # btn_disarm.config(state="normal", bg="red")
    btn_mission.config(state="disabled", bg="lightgrey")
    #btn_return.config(state="disabled", bg="lightgrey")
    send_command("RETURN")
    print("[TX → LoRa/return_home] Enviando comando RETURN")

def arm_drone():
    if not last_telemetry_pos:
        log_message("⚠️ No hay datos de telemetría para fijar HOME")
        return
    send_command("ARM")
    log_message("🚁 Drone ARMADO")
    print("[TX → LoRa/arm_drone] Enviando comando ARM")
   # btn_disarm.config(state="disabled", bg="lightgrey")
    btn_mission.config(state="normal", bg="green", fg="white")

def disarm_drone():
    global home_marker, home_line
    if home_marker:
        home_marker.delete(); 
    if home_line:
        home_line.delete()
    home_marker = None
    home_line = None
    current_mission.home_position = None
    home_position_var.set("")
    send_command("DISARM")
    print("[TX → LoRa/disarm_drone] Enviando comando DISARM")
    log_message("🛑 Drone DESARMADO")
    btn_mission.config(state="disabled", bg="lightgray", fg="black")
    btn_return.config(state="disabled", bg="lightgrey", fg="black")

# Stubs para evitar errores si se usan en el futuro
def at_home(): return True
def not_mission_started(): return True

def initialize_waypoint_tracking(total_waypoints):
    global waypoint_status
    waypoint_status = ["pending"] * total_waypoints
    update_waypoint_display()

def waypoint_reached(wp_number):
    if 0 <= wp_number < len(waypoint_status):
        waypoint_status[wp_number] = "completed"
        update_waypoint_display()
        log_message(f"Waypoint {wp_number} completado")

def update_waypoint_display():
    if waypoint_status:
        completed = waypoint_status.count("completed")
        total = len(waypoint_status)
        progress_var.set(f"Waypoints: {completed}/{total}")
        progress_bar['value'] = (completed / total) * 100

# ===========================================
# [9] MAPA: EDICIÓN, DIBUJO Y MARCADORES
# ===========================================
def set_edit_mode(mode):
    global EDIT_MODE
    EDIT_MODE = mode
    modes = {
        'polygon': "Añadir Puntos de Polígono",
        'move': "Mover Marcadores",
        'delete': "Eliminar Marcadores"
    }
    status_message.set(f"Modo: {modes.get(mode, mode)}")
    log_message(f"Modo cambiado a: {modes.get(mode, mode)}")
    update_button_colors()

def update_button_colors():
    for btn in [add_btn, delete_btn]:
        btn.config(bg="SystemButtonFace")
    if EDIT_MODE == 'polygon':
        add_btn.config(bg="lightblue")
    elif EDIT_MODE == 'delete':
        delete_btn.config(bg="lightcoral")

def map_click(coords):
    lat, lon = coords
    if EDIT_MODE == 'polygon':
        current_mission.polygon_points.append((lat, lon))
        marker = mapa.set_marker(lat, lon, text=f"P{len(current_mission.polygon_points)}")
        polygon_markers.append(marker)
        update_polygon_drawing()
        log_message(f"Punto de polígono añadido: {lat:.6f}, {lon:.6f}")
    elif EDIT_MODE == 'delete':
        closest_marker = find_closest_marker(lat, lon)
        if closest_marker:
            delete_marker(closest_marker)
        else:
            log_message("No se encontró ningún marcador cercano")

def find_closest_marker(lat, lon, max_distance=1000):
    closest_marker = None
    min_distance = inf
    for i, marker in enumerate(polygon_markers):
        marker_pos = marker.position
        dist = calculate_distance(lat, lon, marker_pos[0], marker_pos[1])
        if dist < min_distance and dist < max_distance:
            min_distance = dist
            closest_marker = ('polygon', i, marker)
    if home_marker:
        marker_pos = home_marker.position
        dist = calculate_distance(lat, lon, marker_pos[0], marker_pos[1])
        if dist < min_distance and dist < max_distance:
            min_distance = dist
            closest_marker = ('home', 0, home_marker)
    return closest_marker

def delete_marker(marker_info):
    global home_marker, home_line
    btn_mission.config(state="disabled", bg="lightgray", fg="black")
    marker_type, index, marker = marker_info
    if marker_type == 'polygon':
        current_mission.polygon_points.pop(index)
        marker.delete()
        polygon_markers.pop(index)
        for i, marker in enumerate(polygon_markers):
            marker.set_text(f"P{i + 1}")
        update_polygon_drawing()
        log_message(f"Punto P{index + 1} eliminado")
    elif marker_type == 'home':
        if home_marker:
            home_marker.delete(); 
        if home_line:
            home_line.delete()
        home_marker = None
        home_line = None
        current_mission.home_position = None
        home_position_var.set("")
        log_message("🏠 HOME eliminado")

def set_home_position(lat, lon):
    global home_marker, home_line
    if home_marker: home_marker.delete()
    if home_line: home_line.delete()
    home_marker = None
    home_line = None

    current_mission.home_position = (lat, lon)
    home_marker = mapa.set_marker(lat, lon, text="HOME",
                                  marker_color_circle="green", marker_color_outside="green")
    home_position_var.set(f"{lat:.6f}, {lon:.6f}")
    log_message(f"🏠 Home position establecida: {lat:.6f}, {lon:.6f}")

    if current_mission.polygon_points:
        closest_point = find_closest_polygon_point(lat, lon)
        home_line = mapa.set_path([current_mission.home_position, closest_point], color="green", width=2)

def set_home_from_telemetry():
    """Establece HOME desde última telemetría."""
    global last_telemetry_pos
    if not last_telemetry_pos:
        log_message("⚠️ No hay datos de telemetría para establecer HOME")
        messagebox.showwarning("Atención", "No hay datos de telemetría disponibles")
        return
    lat, lon = last_telemetry_pos
    set_home_position(lat, lon)
    log_message(f"🏠 HOME actualizado desde telemetría: {lat:.6f}, {lon:.6f}")

def find_closest_polygon_point(lat, lon):
    if not current_mission.polygon_points:
        return None
    min_distance = inf
    closest_point = None
    for point in current_mission.polygon_points:
        dist = calculate_distance(lat, lon, point[0], point[1])
        if dist < min_distance:
            min_distance = dist
            closest_point = point
    return closest_point

def add_fire_marker(data):
    lat = data.get('lat')
    lon = data.get('lon')
    conf = data.get('confidence', None)

    if lat is None or lon is None:
        return

    # Construir etiqueta multilínea
    if conf is not None:
        label = f"FUEGO ({conf*100:.1f}%)\n{lat:.6f}, {lon:.6f}"
    else:
        label = f"FUEGO\n{lat:.6f}, {lon:.6f}"

    # Crear marcador principal
    marker = mapa.set_marker(
        lat, lon,
        text=label,
        marker_color_circle="orange",
        marker_color_outside="orange",
        text_color="black",
        font=("Arial", 9, "bold")
    )
    fire_markers.append(marker)

    # Log visual
    if conf is not None:
        log_message(f"🔥 Marcador FUEGO agregado: {lat:.6f}, {lon:.6f} (Confianza={conf*100:.1f}%)")
    else:
        log_message(f"🔥 Marcador FUEGO agregado: {lat:.6f}, {lon:.6f}")


def add_person_marker(data):
    lat = data.get('lat')
    lon = data.get('lon')
    conf = data.get('confidence', None)

    if lat is None or lon is None:
        return

    # Construir etiqueta multilínea
    if conf is not None:
        label = f"PERSONA ({conf*100:.1f}%)\n{lat:.6f}, {lon:.6f}"
    else:
        label = f"PERSONA\n{lat:.6f}, {lon:.6f}"

    # Crear marcador principal
    marker = mapa.set_marker(
        lat, lon,
        text=label,
        marker_color_circle="#8B4513",
        marker_color_outside="#8B4513",
        text_color="black",
        font=("Arial", 9, "bold")
    )
    person_markers.append(marker)

    # Log visual
    if conf is not None:
        log_message(f"🧍 Marcador PERSONA agregado: {lat:.6f}, {lon:.6f} (Confianza={conf*100:.1f}%)")
    else:
        log_message(f"🧍 Marcador PERSONA agregado: {lat:.6f}, {lon:.6f}")


def update_polygon_drawing():
    global polygon_path
    if polygon_path:
        polygon_path.delete()
    if len(current_mission.polygon_points) >= 2:
        polygon_path = mapa.set_polygon(
            current_mission.polygon_points,
            outline_color="blue", fill_color="lightblue", border_width=2
        )

def reset_polygon():
    global current_mission, polygon_markers, polygon_path
    global home_marker, home_line, mission_path, waypoint_status, person_markers, fire_markers

    for m in polygon_markers:
        m.delete()
    polygon_markers.clear()

    if polygon_path is not None:
        try: polygon_path.delete()
        except Exception as e: log_message(f"Error borrando polígono: {e}")
        polygon_path = None

    if home_marker: home_marker.delete()
    if home_line: home_line.delete()
    home_marker = None
    home_line = None

    for m in person_markers: m.delete()
    person_markers.clear()

    for m in fire_markers: m.delete()
    fire_markers.clear()
   
    if mission_path:
        mission_path.delete()
        mission_path = None

    current_mission = MissionData()
    waypoint_status = []

    home_position_var.set("")
    progress_var.set("Waypoints: 0/0")
    progress_bar['value'] = 0
    altitude_var.set(30)
    spacing_var.set(10)

    log_message("🔄 Reset completo: polígono, HOME y misión eliminados")

# =========================================
# [10] TRIMS / GRIPPER (COMANDOS Y UI)
# =========================================
def request_trim_data():
    """Solicita los trims al dron y deshabilita sliders mientras tanto."""
    for s in [slider_accel, slider_roll_lr, slider_roll_fb, slider_rudder, slider_switch]:
        s.config(state="disabled")
    send_command("GET_TRIMS", {})
    log_message("📡 Solicitando trims al dron...")
    print("[TX → LoRa/request_trim_data] Enviando comando GET_TRIMS")

def handle_trim_response(data):
    """Actualiza los sliders con la respuesta TRIM_DATA."""
    print(f"[RX ← LoRa/handle_trim_response] Datos recibidos TRIM_DATA → {data}")
    try:
        trim_accel_var.set(data.get("accel", 128))
        trim_roll_lr_var.set(data.get("roll_lr", 128))
        trim_roll_fb_var.set(data.get("roll_fb", 128))
        trim_rudder_var.set(data.get("rudder", 128))
        trim_switch_var.set(data.get("switch", 128))
        for slider in [slider_accel, slider_roll_lr, slider_roll_fb, slider_rudder, slider_switch]:
            slider.config(state="normal")
        log_message("✅ Trims actualizados y controles habilitados")
    except Exception as e:
        log_message(f"❌ Error procesando trims: {e}")

# =========================================
# [11] ARCHIVOS DE MISIÓN (GUARDAR/CARGAR)
# =========================================
def save_mission():
    if not current_mission.polygon_points:
        messagebox.showwarning("Error", "No hay misión para guardar")
        return
    filename = filedialog.asksaveasfilename(
        defaultextension=".mission",
        filetypes=[("Mission files", "*.mission"), ("All files", "*.*")]
    )
    if filename:
        try:
            with open(filename, 'wb') as f:
                pickle.dump(current_mission.to_dict(), f)
            log_message(f"Misión guardada: {filename}")
        except Exception as e:
            log_message(f"Error guardando misión: {str(e)}")

def load_mission():
    filename = filedialog.askopenfilename(
        filetypes=[("Mission files", "*.mission"), ("All files", "*.*")]
    )
    if filename:
        try:
            with open(filename, 'rb') as f:
                mission_data = pickle.load(f)
            reset_polygon()
            current_mission.from_dict(mission_data)
            update_interface_from_mission()
            log_message(f"Misión cargada: {filename}")
        except Exception as e:
            log_message(f"Error cargando misión: {str(e)}")

def update_interface_from_mission():
    for i, (lat, lon) in enumerate(current_mission.polygon_points):
        marker = mapa.set_marker(lat, lon, text=f"P{i+1}")
        polygon_markers.append(marker)
    if current_mission.home_position:
        set_home_position(current_mission.home_position[0], current_mission.home_position[1])
    altitude_var.set(current_mission.altitude)
    spacing_var.set(current_mission.spacing)
    update_polygon_drawing()

# =========================================
# [12] CONSTRUCCIÓN DE LA GUI (TKINTER)
# =========================================
def create_trim_pid_controls(frame):
    """Pestaña Controles: TRIM, PID, GRIPPER, SIMULACIÓN, MAGNETÓMETRO."""
    global trim_accel_var, trim_roll_lr_var, trim_roll_fb_var, trim_rudder_var, trim_switch_var
    global slider_accel, slider_roll_lr, slider_roll_fb, slider_rudder, slider_switch
    global pid_vars_by_channel, gripper_state_var, handle_trim_response_global, handle_pid_status_global
    handle_trim_response_global = handle_trim_response

    # === CONTENEDOR PRINCIPAL ===
    container = tk.Frame(frame)
    container.pack(fill="both", expand=True, padx=10, pady=10)
    container.grid_columnconfigure(0, weight=1)
    container.grid_columnconfigure(1, weight=1)
    container.grid_columnconfigure(2, weight=1)
    container.grid_rowconfigure(0, weight=1)

    # =====================================================================
    # FUNCIONES AUXILIARES PID
    # =====================================================================
    
    pid_vars_by_channel = {}  # {"roll": (kp_var, ki_var, kd_var), ...}
        
    def send_all_pid_to_drone():
        data = {
            "t": "PID_SET",
            "id":  str(int(time.time()*1000) % 100000),
            "d": {}
        }
    
        for ch, (kp, ki, kd) in pid_vars_by_channel.items():
            data["d"][ch] = {
                "kp": float(str(kp.get()).replace(",", ".")),
                "ki": float(str(ki.get()).replace(",", ".")),
                "kd": float(str(kd.get()).replace(",", "."))
            }
    
        send_command("PID_SET", data)
        log_message(f"⚙️ Enviando PID_SET al dron...")

    
    def request_pid_refresh():
        data = {"t": "GET_PID", "id": str(int(time.time()*1000) % 100000)}
        send_command("GET_PID", data)
        log_message("📡 Solicitando PID actuales al dron...")

    
    def handle_pid_status(payload):
        try:
            d = payload["d"]
            for ch, vals in d.items():
                if ch in pid_vars_by_channel:
                    kp, ki, kd = pid_vars_by_channel[ch]
                    kp.set(vals.get("kp", 0))
                    ki.set(vals.get("ki", 0))
                    kd.set(vals.get("kd", 0))
            log_message("✅ PID actualizados desde dron.")
        except Exception as e:
            log_message(f"⚠️ Error al actualizar PID: {e}")
    
    handle_pid_status_global = handle_pid_status


    # =====================================================================
    # COLUMNA 0 → CONTROLES DE TRIM
    # =====================================================================
    trim_frame = tk.LabelFrame(container, text="Controles de Trim", padx=10, pady=10, font=("Arial", 10, "bold"))
    trim_frame.grid(row=0, column=0, sticky="nsew", padx=5)

    trim_accel_var = tk.IntVar(value=128)
    trim_roll_lr_var = tk.IntVar(value=128)
    trim_roll_fb_var = tk.IntVar(value=128)
    trim_rudder_var = tk.IntVar(value=128)
    trim_switch_var = tk.IntVar(value=128)

    sliders_info = [
        ("Acelerador", trim_accel_var),
        ("Rolido Izq/Der", trim_roll_lr_var),
        ("Rolido Del/Atr", trim_roll_fb_var),
        ("Timón", trim_rudder_var),
        ("Switch Control", trim_switch_var),
    ]
    slider_widgets = []
    for i, (label_text, var) in enumerate(sliders_info):
        tk.Label(trim_frame, text=label_text, font=("Arial", 9)).grid(row=i, column=0, sticky="w", pady=3)
        slider = tk.Scale(trim_frame, from_=0, to=255, orient="horizontal", variable=var,
                          state="disabled", length=200)
        slider.grid(row=i, column=1, sticky="we", pady=3)
        slider.bind("<ButtonRelease-1>", lambda e, v=var: send_trim_data())
        slider_widgets.append(slider)
    slider_accel, slider_roll_lr, slider_roll_fb, slider_rudder, slider_switch = slider_widgets

    def send_trim_data(event=None):
        data = {
            "accel": trim_accel_var.get(),
            "roll_lr": trim_roll_lr_var.get(),
            "roll_fb": trim_roll_fb_var.get(),
            "rudder": trim_rudder_var.get(),
            "switch": trim_switch_var.get(),
        }
        send_command("TRIM", data)
        log_message(f"Trim enviado: {data}")

    tk.Button(trim_frame, text="📡 Refrescar Trims", command=request_trim_data,
              bg="#2196F3", fg="white", font=("Arial", 9, "bold"), width=20).grid(
                  row=len(sliders_info), column=0, columnspan=2, pady=(8, 5)
              )

    # =====================================================================
    # COLUMNA 1 → AJUSTES PID
    # =====================================================================
    pid_frame = tk.LabelFrame(container, text="Ajuste PID", padx=10, pady=10, font=("Arial", 10, "bold"))
    pid_frame.grid(row=0, column=1, sticky="nsew", padx=5)
    
    channels = ["ACCEL", "ROLL_LR", "ROLL_FB", "RUDDER"]
    headers = ["Canal", "Kp", "Ki", "Kd"]
    
    # --- Cabeceras ---
    for j, h in enumerate(headers):
        tk.Label(pid_frame, text=h, font=("Arial", 9, "bold")).grid(row=0, column=j, padx=3, pady=3)
    
    # --- Filas de PID ---
    for i, ch in enumerate(channels, start=1):
        tk.Label(pid_frame, text=ch, font=("Arial", 9, "bold")).grid(row=i, column=0, sticky="w", padx=4)
    
        kp = tk.DoubleVar(value=1.0)
        ki = tk.DoubleVar(value=0.0)
        kd = tk.DoubleVar(value=0.0)
        pid_vars_by_channel[ch] = (kp, ki, kd)
    
        tk.Entry(pid_frame, textvariable=kp, width=8).grid(row=i, column=1, padx=2)
        tk.Entry(pid_frame, textvariable=ki, width=8).grid(row=i, column=2, padx=2)
        tk.Entry(pid_frame, textvariable=kd, width=8).grid(row=i, column=3, padx=2)
    
    # --- Botones de acción unificados ---
    btn_frame = tk.Frame(pid_frame)
    btn_frame.grid(row=len(channels)+1, column=0, columnspan=4, pady=(10, 5))
    
    tk.Button( btn_frame, text="💾 Guardar PID", bg="#4CAF50", fg="white",font=("Arial", 9, "bold"), width=18, command=send_all_pid_to_drone
    ).grid(row=0, column=0, padx=5)
    
    tk.Button(btn_frame, text="🔄 Refrescar PID", bg="#2196F3", fg="white",font=("Arial", 9, "bold"), width=18, command=request_pid_refresh
    ).grid(row=0, column=1, padx=5)

    # =====================================================================
    # COLUMNA 2 → BOTONES LATERALES
    # =====================================================================
    right_frame = tk.Frame(container)
    right_frame.grid(row=0, column=2, sticky="nsew", padx=5)
    right_frame.grid_rowconfigure(2, weight=1)

    # --- GRIPPER ---
    gripper_frame = tk.LabelFrame(right_frame, text="Gripper", padx=10, pady=10, font=("Arial", 10, "bold"))
    gripper_frame.grid(row=0, column=0, sticky="ew", pady=(0, 8))

    gripper_state_var = tk.BooleanVar(value=False)

    def toggle_gripper():
        state = gripper_state_var.get()
        send_command("GRIPPER", {"state": "OPEN" if state else "CLOSE"})
        if state:
            gripper_btn.config(bg="#4CAF50", text="ABIERTO")
            log_message("🟢 Gripper ABIERTO")
        else:
            gripper_btn.config(bg="#f44336", text="CERRADO")
            log_message("🔴 Gripper CERRADO")

    gripper_btn = tk.Checkbutton(gripper_frame, text="CERRADO", variable=gripper_state_var, command=toggle_gripper,
                                 font=("Arial", 11, "bold"), indicatoron=False, width=15, bg="#f44336",
                                 fg="white", selectcolor="#4CAF50")
    gripper_btn.pack(pady=10)

    # --- SIMULACIÓN ---
    sim_frame = tk.LabelFrame(right_frame, text="Simulación", padx=10, pady=10, font=("Arial", 10, "bold"))
    sim_frame.grid(row=1, column=0, sticky="ew", pady=(0, 8))

    sim_active = tk.BooleanVar(value=False)

    def toggle_sim():
        state = sim_active.get()
        cmd = "SIM_ON" if state else "SIM_OFF"
        send_command(cmd, {})
        log_message("🧪 Simulación ACTIVADA" if state else "🛑 Simulación DESACTIVADA")
        sim_btn.config(bg="#4CAF50" if state else "#f44336", text="SIM ON" if state else "SIM OFF")

    sim_btn = tk.Checkbutton(sim_frame, text="SIM OFF", variable=sim_active, command=toggle_sim,
                             font=("Arial", 11, "bold"), indicatoron=False, width=15, bg="#f44336",
                             fg="white", selectcolor="#4CAF50")
    sim_btn.pack(pady=10)

    # --- MAGNETÓMETRO ---
    mag_frame = tk.LabelFrame(right_frame, text="Magnetómetro", padx=10, pady=10, font=("Arial", 10, "bold"))
    mag_frame.grid(row=2, column=0, sticky="ew")

    mag_calibrating = tk.BooleanVar(value=False)
    global mag_quality
    mag_quality = tk.StringVar(value="INACTIVO")

    def calibrate_mag():
        send_command("CALIB_MAG", {})
        mag_calibrating.set(True)
        mag_quality.set("CALIBRANDO...")   # ✅ actualiza texto correctamente
        lbl_mag.config(bg="#FFA000", fg="black")
        log_message("🧭 Calibración del magnetómetro iniciada...")

    tk.Button(mag_frame, text="🧭 Calibrar", command=calibrate_mag,
              bg="#2196F3", fg="white", font=("Arial", 10, "bold"), width=18).pack(pady=(5, 5))

    global lbl_mag
    lbl_mag = tk.Label(mag_frame, textvariable=mag_quality,font=("Arial", 10, "bold"),bg="#B71C1C", fg="white", width=18, pady=3)
    lbl_mag.pack(pady=(0, 5))


    # Manejo desde JSON: calidad del magnetómetro
    def handle_mag_status(payload):
        try:
            d = payload["d"]
            quality = d.get("quality", "UNKNOWN")
            mag_quality.set(quality)
            color = {"GOOD": "#4CAF50", "WARN": "#FFC107", "BAD": "#F44336"}.get(quality, "#9E9E9E")
            lbl_mag.config(bg=color)
        except Exception as e:
            log_message(f"⚠️ Error al actualizar calidad MAG: {e}")

def create_gui():
    """Construye toda la interfaz (pestañas, botones, mapa, etc.)."""
    global root, mapa, status_label, telemetry_text, log_text
    global port_var, spacing_var, altitude_var, status_message
    global home_position_var, progress_var, progress_bar
    global add_btn, home_btn, delete_btn
    global btn_arm, btn_disarm, btn_mission, btn_return
    global event_action_var

    root = tk.Tk()
    root.title("Ground Station - Dron Buscador Térmico")
    root.geometry("1200x900")

    event_action_var = tk.StringVar(value="VOLVER")

    # ---- Barra de conexión ----
    connection_frame = tk.Frame(root)
    connection_frame.pack(fill="x", padx=10, pady=5)

    ports = [port.device for port in serial.tools.list_ports.comports()]
    port_var = tk.StringVar(value=ports[0] if ports else "")

    tk.Label(connection_frame, text="Puerto:").pack(side="left")
    port_combo = ttk.Combobox(connection_frame, textvariable=port_var, values=ports, width=15)
    port_combo.pack(side="left", padx=5)

    def update_ports():
        new_ports = [port.device for port in serial.tools.list_ports.comports()]
        port_combo['values'] = new_ports
        if new_ports and not port_var.get():
            port_var.set(new_ports[0])

    tk.Button(connection_frame, text="Actualizar", command=update_ports).pack(side="left", padx=5)
    tk.Button(connection_frame, text="Conectar", command=connect_serial).pack(side="left", padx=5)
    tk.Button(connection_frame, text="Desconectar", command=disconnect_serial).pack(side="left", padx=5)

    status_label = tk.Label(connection_frame, text="Desconectado", fg="red")
    status_label.pack(side="right")

    # ---- Modo edición ----
    edit_frame = tk.Frame(root)
    edit_frame.pack(fill="x", padx=10, pady=5)

    tk.Label(edit_frame, text="Modo Edición:", font=("Arial", 10, "bold")).pack(side="left")
    add_btn = tk.Button(edit_frame, text="Colocar marcadores", command=lambda: set_edit_mode('polygon'), width=20)
    add_btn.pack(side="left", padx=2)
    home_btn = tk.Button(edit_frame, text="Colocar home", command=set_home_from_telemetry, width=20)
    home_btn.pack(side="left", padx=2)
    delete_btn = tk.Button(edit_frame, text="Eliminar marcadores", command=lambda: set_edit_mode('delete'), width=20)
    delete_btn.pack(side="left", padx=2)

    # ---- Parámetros de misión ----
    params_frame = tk.Frame(root)
    params_frame.pack(fill="x", padx=10, pady=5)

    tk.Label(params_frame, text="Altitud (m):").pack(side="left")
    altitude_var = tk.IntVar(value=2)
    tk.Spinbox(params_frame, from_=1, to=100, width=5, textvariable=altitude_var).pack(side="left", padx=5)

    tk.Label(params_frame, text="Ancho pasadas (m):").pack(side="left", padx=(20, 5))
    spacing_var = tk.IntVar(value=5)
    tk.Spinbox(params_frame, from_=1, to=50, width=5, textvariable=spacing_var).pack(side="left", padx=5)
    
    home_position_var = tk.StringVar(value="")
    tk.Label(params_frame, textvariable=home_position_var, fg="green").pack(side="right")

    # ---- Estado y progreso ----
    status_frame = tk.Frame(root)
    status_frame.pack(fill="x", padx=10, pady=5)

    status_message = tk.StringVar(value="Modo: Polígono")
    tk.Label(status_frame, textvariable=status_message, fg="white", bg="#333", font=("Arial", 12, "bold"),padx=8, pady=3).pack(side="left")


    progress_var = tk.StringVar(value="Waypoints: 0/0")
    tk.Label(status_frame, textvariable=progress_var).pack(side="left", padx=20)

    progress_bar = ttk.Progressbar(status_frame, orient="horizontal", length=200, mode="determinate")
    progress_bar.pack(side="left", padx=5)

    # ---- Botones de misión ----
    mission_btn_frame = tk.Frame(root)
    mission_btn_frame.pack(fill="x", padx=10, pady=5)

    btn_mission = tk.Button(mission_btn_frame, text="COMENZAR MISIÓN", command=start_mission,
                            state="disabled", bg="lightgrey", fg="white")
    btn_mission.pack(side="left", expand=True, padx=5)

    btn_return = tk.Button(mission_btn_frame, text="REGRESAR", command=return_home,
                           state="disabled", bg="lightgrey", fg="white")
    btn_return.pack(side="left", expand=True, padx=5)

    tk.Button(mission_btn_frame, text="RESET COMPLETO", command=reset_polygon, bg="red", fg="white").pack(side="left", expand=True, padx=5)
    tk.Button(mission_btn_frame, text="GUARDAR", command=save_mission, bg="blue", fg="white").pack(side="left", expand=True, padx=5)
    tk.Button(mission_btn_frame, text="CARGAR", command=load_mission, bg="purple", fg="white").pack(side="left", expand=True, padx=5)

    tk.Label(mission_btn_frame, text="Acción tras evento:").pack(side="left", padx=5)
    event_action_menu = ttk.Combobox(mission_btn_frame, textvariable=event_action_var,
                                     values=["CONTINUAR", "VOLVER"], state="readonly", width=11)
    event_action_menu.pack(side="left", padx=5)
    event_action_menu.current(1)  # "VOLVER"

    # ---- Notebook ----
    notebook = ttk.Notebook(root)
    notebook.pack(fill="both", expand=True, padx=10, pady=5)

    # Pestaña: Misión
    frame_mission = ttk.Frame(notebook)
    notebook.add(frame_mission, text="Misión")

    # Mapa
    global mapa
    mapa = tkintermapview.TkinterMapView(frame_mission, width=1000, height=500, corner_radius=0)
    mapa.pack(pady=10, fill="both", expand=True)
    mapa.set_position(-34.6037, -58.3816)
    mapa.set_zoom(12)
    mapa.add_left_click_map_command(map_click)

    # Pestaña: Controles
    frame_controls = ttk.Frame(notebook)
    notebook.add(frame_controls, text="Controles")

    control_btn_frame = tk.Frame(frame_controls)
    control_btn_frame.pack(pady=10)

    global btn_arm, btn_disarm
    btn_arm = tk.Button(control_btn_frame, text="ARMAR", command=arm_drone, bg="green", fg="white", width=15)
    btn_arm.pack(side="left", padx=10)

    btn_disarm = tk.Button(control_btn_frame, text="DESARMAR", command=disarm_drone,
                           state="normal", bg="lightgrey", fg="white", width=15)
    btn_disarm.pack(side="left", padx=10)

    create_trim_pid_controls(frame_controls)


    # Pestaña: Telemetría
    frame_telemetry = ttk.Frame(notebook)
    notebook.add(frame_telemetry, text="Telemetría")

    global telemetry_text
    telemetry_text = scrolledtext.ScrolledText(frame_telemetry, width=80, height=15)
    telemetry_text.pack(pady=10, fill="both", expand=True)
    telemetry_text.insert("end", "Esperando datos de telemetría...\n")
    telemetry_text.config(state="disabled")

    # Pestaña: Log
    frame_log = ttk.Frame(notebook)
    notebook.add(frame_log, text="Log")

    global log_text
    log_text = scrolledtext.ScrolledText(frame_log, width=80, height=15)
    log_text.pack(pady=10, fill="both", expand=True)
    log_text.config(state="disabled")

    # Modo inicial
    set_edit_mode('polygon')

# =========================
# [13] INICIALIZACIÓN
# =========================
current_mission = MissionData()

# Ejecutar GUI 
create_gui()
log_message("✅ Interfaz lista. Conectá el puerto y espera telemetría...")
root.mainloop()
# Out:
# [SERIAL] ✅ Conectado a COM4 @ 115200 bps
# [SERIAL] 🚀 Lanzando hilos: recepción y ack_manager
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":18740}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 18740}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":18959}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 18959}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":19178}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 19178}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":19397}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 19397}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":19617}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 19617}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":19836}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 19836}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":20055}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 20055}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"RETURN_HOME","ts":20167}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'RETURN_HOME', 'ts': 20167}
# [STATUS ← LoRa] Estado FSM = RETURN_HOME
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":20287}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 20287}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":20506}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 20506}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":20726}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 20726}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":20945}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 20945}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":21164}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 21164}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":21383}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 21383}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"RETURN_HOME","ts":21495}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'RETURN_HOME', 'ts': 21495}
# [STATUS ← LoRa] Estado FSM = RETURN_HOME
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":21615}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 21615}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"RETURN_HOME","ts":21726}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'RETURN_HOME', 'ts': 21726}
# [STATUS ← LoRa] Estado FSM = RETURN_HOME
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":21845}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 21845}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":22064}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 22064}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":22284}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 22284}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":22503}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 22503}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":22722}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 22722}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":22942}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 22942}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":23161}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 23161}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":23380}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 23380}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":23600}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 23600}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":23819}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 23819}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":24038}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 24038}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":24257}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 24257}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":24476}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 24476}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":24696}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 24696}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":24915}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 24915}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":25135}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 25135}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":25354}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 25354}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"RETURN_HOME","ts":25465}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'RETURN_HOME', 'ts': 25465}
# [STATUS ← LoRa] Estado FSM = RETURN_HOME
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":25585}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 25585}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":25806}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 25806}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":26025}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 26025}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":26244}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 26244}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":26463}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 26463}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":26683}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 26683}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":26902}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 26902}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":27121}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 27121}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":27340}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 27340}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":27559}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 27559}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":27779}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 27779}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":27998}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 27998}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":28217}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 28217}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":28437}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 28437}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":28656}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 28656}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":28875}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 28875}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":29094}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 29094}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":29315}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 29315}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":29534}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 29534}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":29754}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 29754}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":29973}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 29973}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":30192}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 30192}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":30411}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 30411}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":30631}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 30631}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":30850}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 30850}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":31069}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 31069}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":31288}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 31288}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":31508}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 31508}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":31727}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 31727}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":31946}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 31946}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":32166}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 32166}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":32385}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 32385}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":32604}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 32604}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":32823}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 32823}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":33043}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 33043}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":33263}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 33263}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":33482}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 33482}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":33702}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 33702}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":33921}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 33921}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":34140}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 34140}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":34359}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 34359}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":34579}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 34579}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":34798}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 34798}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":35018}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 35018}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":35238}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 35238}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":35457}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 35457}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":35677}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 35677}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":35896}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 35896}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":36115}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 36115}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":36334}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 36334}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":36553}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 36553}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":36773}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 36773}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":36992}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 36992}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":37211}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 37211}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":37431}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 37431}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":37650}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 37650}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":37869}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 37869}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":38088}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 38088}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":38308}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 38308}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":38527}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 38527}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":38746}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 38746}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":38966}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 38966}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":39185}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 39185}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":39404}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 39404}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":39624}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 39624}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":39843}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 39843}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":40062}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 40062}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":40281}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 40281}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":40500}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 40500}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":40720}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 40720}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":40939}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 40939}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":41158}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 41158}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":41377}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 41377}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":41597}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 41597}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":41816}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 41816}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":42035}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 42035}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":42254}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 42254}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":42474}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 42474}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":42693}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 42693}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":42912}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 42912}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":43132}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 43132}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":43351}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 43351}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":43570}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 43570}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":43790}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 43790}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":44009}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 44009}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":44228}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 44228}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":44447}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 44447}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":44667}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 44667}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":44886}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 44886}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":45106}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 45106}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":45325}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 45325}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":45544}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 45544}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":45764}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 45764}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":45983}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 45983}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":46202}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 46202}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":46421}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 46421}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":46641}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 46641}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":46860}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 46860}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":47079}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 47079}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":47298}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 47298}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":47517}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 47517}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":47737}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 47737}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":47956}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 47956}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":48175}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 48175}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":48394}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 48394}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":48614}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 48614}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":48833}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 48833}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":49052}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 49052}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":49272}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 49272}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":49491}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 49491}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":49710}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 49710}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":49929}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 49929}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":50149}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 50149}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":50368}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 50368}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":50587}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 50587}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":50807}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 50807}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":51026}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 51026}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":51245}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 51245}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":51464}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 51464}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":51684}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 51684}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":51903}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 51903}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":52122}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 52122}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":52341}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 52341}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":52560}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 52560}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":52780}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 52780}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":52999}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 52999}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":53218}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 53218}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":53438}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 53438}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":53657}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 53657}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":53876}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 53876}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":54095}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 54095}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":54315}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 54315}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":54534}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 54534}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":54753}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 54753}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":54973}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 54973}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":55192}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 55192}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":55411}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 55411}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":55631}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 55631}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":55850}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 55850}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":56069}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 56069}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":56289}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 56289}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":56508}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 56508}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"LAND","ts":56727}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'LAND', 'ts': 56727}
# [STATUS ← LoRa] Estado FSM = LAND
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.72010794,"lon":-58.36421434,"alt":0.967921875,"speed":0,"heading":0,"battery":0,"status":0},"ts":2087}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.72010794, 'lon': -58.36421434, 'alt': 0.967921875, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 2087}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77499201,"lon":-58.45647748,"alt":0.850701904,"speed":0,"heading":0,"battery":0,"status":0},"ts":3321}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77499201, 'lon': -58.45647748, 'alt': 0.850701904, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 3321}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77503255,"lon":-58.4565432,"alt":0.085026592,"speed":0,"heading":0,"battery":0,"status":0},"ts":4554}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77503255, 'lon': -58.4565432, 'alt': 0.085026592, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 4554}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77503336,"lon":-58.45654132,"alt":-0.025445726,"speed":0,"heading":0,"battery":0,"status":0},"ts":5787}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77503336, 'lon': -58.45654132, 'alt': -0.025445726, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 5787}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77503463,"lon":-58.45654019,"alt":-0.001049544,"speed":0,"heading":0,"battery":0,"status":0},"ts":7020}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77503463, 'lon': -58.45654019, 'alt': -0.001049544, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 7020}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.7750373,"lon":-58.45653859,"alt":0.016241426,"speed":0,"heading":0,"battery":0,"status":0},"ts":8253}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.7750373, 'lon': -58.45653859, 'alt': 0.016241426, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 8253}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77503843,"lon":-58.45653557,"alt":0.005906006,"speed":0,"heading":0,"battery":0,"status":0},"ts":9486}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77503843, 'lon': -58.45653557, 'alt': 0.005906006, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 9486}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77503854,"lon":-58.45653315,"alt":-0.000516729,"speed":0,"heading":0,"battery":0,"status":0},"ts":10719}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77503854, 'lon': -58.45653315, 'alt': -0.000516729, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 10719}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.7750384,"lon":-58.45652942,"alt":0.001265211,"speed":0,"heading":0,"battery":0,"status":0},"ts":11957}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.7750384, 'lon': -58.45652942, 'alt': 0.001265211, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 11957}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77503755,"lon":-58.45652538,"alt":0.018073365,"speed":0,"heading":0,"battery":0,"status":0},"ts":13190}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77503755, 'lon': -58.45652538, 'alt': 0.018073365, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 13190}
# ...
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77504046,"lon":-58.45651045,"alt":-0.229149025,"speed":0,"heading":0,"battery":0,"status":0},"ts":476591}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77504046, 'lon': -58.45651045, 'alt': -0.229149025, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 476591}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77504002,"lon":-58.45650678,"alt":-0.206277011,"speed":0,"heading":0,"battery":0,"status":0},"ts":477829}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77504002, 'lon': -58.45650678, 'alt': -0.206277011, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 477829}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77503932,"lon":-58.45650321,"alt":-0.176554185,"speed":0,"heading":0,"battery":0,"status":0},"ts":479067}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77503932, 'lon': -58.45650321, 'alt': -0.176554185, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 479067}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77503854,"lon":-58.45650051,"alt":-0.193957337,"speed":0,"heading":0,"battery":0,"status":0},"ts":480305}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77503854, 'lon': -58.45650051, 'alt': -0.193957337, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 480305}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77503776,"lon":-58.45649962,"alt":-0.22789768,"speed":0,"heading":0,"battery":0,"status":0},"ts":481543}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77503776, 'lon': -58.45649962, 'alt': -0.22789768, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 481543}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77503717,"lon":-58.45649956,"alt":-0.262595803,"speed":0,"heading":0,"battery":0,"status":0},"ts":482781}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77503717, 'lon': -58.45649956, 'alt': -0.262595803, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 482781}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77503757,"lon":-58.45649933,"alt":-0.319795737,"speed":0,"heading":0,"battery":0,"status":0},"ts":484019}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77503757, 'lon': -58.45649933, 'alt': -0.319795737, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 484019}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77503847,"lon":-58.45649886,"alt":-0.403812767,"speed":0,"heading":0,"battery":0,"status":0},"ts":485257}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77503847, 'lon': -58.45649886, 'alt': -0.403812767, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 485257}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77503881,"lon":-58.4564963,"alt":-0.411840242,"speed":0,"heading":0,"battery":0,"status":0},"ts":486495}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77503881, 'lon': -58.4564963, 'alt': -0.411840242, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 486495}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77503898,"lon":-58.45649497,"alt":-0.370980356,"speed":0,"heading":0,"battery":0,"status":0},"ts":487733}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77503898, 'lon': -58.45649497, 'alt': -0.370980356, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 487733}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77503899,"lon":-58.45649456,"alt":-0.359015058,"speed":0,"heading":0,"battery":0,"status":0},"ts":488971}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77503899, 'lon': -58.45649456, 'alt': -0.359015058, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 488971}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77503905,"lon":-58.4564949,"alt":-0.369746332,"speed":0,"heading":0,"battery":0,"status":0},"ts":490209}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77503905, 'lon': -58.4564949, 'alt': -0.369746332, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 490209}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77503886,"lon":-58.45649642,"alt":-0.358763446,"speed":0,"heading":0,"battery":0,"status":0},"ts":491447}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77503886, 'lon': -58.45649642, 'alt': -0.358763446, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 491447}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77503879,"lon":-58.45649859,"alt":-0.378301893,"speed":0,"heading":0,"battery":0,"status":0},"ts":492685}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77503879, 'lon': -58.45649859, 'alt': -0.378301893, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 492685}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77503918,"lon":-58.45650148,"alt":-0.397597427,"speed":0,"heading":0,"battery":0,"status":0},"ts":493923}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77503918, 'lon': -58.45650148, 'alt': -0.397597427, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 493923}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77503984,"lon":-58.4565036,"alt":-0.397128302,"speed":0,"heading":0,"battery":0,"status":0},"ts":495161}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77503984, 'lon': -58.4565036, 'alt': -0.397128302, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 495161}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77504088,"lon":-58.45650453,"alt":-0.418294563,"speed":0,"heading":0,"battery":0,"status":0},"ts":496399}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77504088, 'lon': -58.45650453, 'alt': -0.418294563, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 496399}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77504145,"lon":-58.45650518,"alt":-0.450998715,"speed":0,"heading":0,"battery":0,"status":0},"ts":497637}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77504145, 'lon': -58.45650518, 'alt': -0.450998715, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 497637}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77504208,"lon":-58.45650531,"alt":-0.468473892,"speed":0,"heading":0,"battery":0,"status":0},"ts":498875}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77504208, 'lon': -58.45650531, 'alt': -0.468473892, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 498875}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77504284,"lon":-58.45650551,"alt":-0.467819727,"speed":0,"heading":0,"battery":0,"status":0},"ts":500113}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77504284, 'lon': -58.45650551, 'alt': -0.467819727, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 500113}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77504423,"lon":-58.45650596,"alt":-0.506140523,"speed":0,"heading":0,"battery":0,"status":0},"ts":501351}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77504423, 'lon': -58.45650596, 'alt': -0.506140523, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 501351}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77504496,"lon":-58.45650657,"alt":-0.551559434,"speed":0,"heading":0,"battery":0,"status":0},"ts":502589}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77504496, 'lon': -58.45650657, 'alt': -0.551559434, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 502589}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77504587,"lon":-58.4565078,"alt":-0.597565876,"speed":0,"heading":0,"battery":0,"status":0},"ts":503827}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77504587, 'lon': -58.4565078, 'alt': -0.597565876, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 503827}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77504614,"lon":-58.45650864,"alt":-0.647401007,"speed":0,"heading":0,"battery":0,"status":0},"ts":505065}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77504614, 'lon': -58.45650864, 'alt': -0.647401007, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 505065}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77504574,"lon":-58.45650765,"alt":-0.666255127,"speed":0,"heading":0,"battery":0,"status":0},"ts":506303}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77504574, 'lon': -58.45650765, 'alt': -0.666255127, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 506303}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77504516,"lon":-58.45650642,"alt":-0.611486325,"speed":0,"heading":0,"battery":0,"status":0},"ts":507541}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77504516, 'lon': -58.45650642, 'alt': -0.611486325, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 507541}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77504498,"lon":-58.45650456,"alt":-0.525888069,"speed":0,"heading":0,"battery":0,"status":0},"ts":508779}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77504498, 'lon': -58.45650456, 'alt': -0.525888069, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 508779}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77504495,"lon":-58.45650208,"alt":-0.504534278,"speed":0,"heading":0,"battery":0,"status":0},"ts":510017}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77504495, 'lon': -58.45650208, 'alt': -0.504534278, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 510017}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77504438,"lon":-58.45650039,"alt":-0.48938635,"speed":0,"heading":0,"battery":0,"status":0},"ts":511255}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77504438, 'lon': -58.45650039, 'alt': -0.48938635, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 511255}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77504286,"lon":-58.4564986,"alt":-0.493472409,"speed":0,"heading":0,"battery":0,"status":0},"ts":512493}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77504286, 'lon': -58.4564986, 'alt': -0.493472409, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 512493}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.7750421,"lon":-58.45649696,"alt":-0.540068698,"speed":0,"heading":0,"battery":0,"status":0},"ts":513731}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.7750421, 'lon': -58.45649696, 'alt': -0.540068698, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 513731}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.7750417,"lon":-58.45649538,"alt":-0.566671895,"speed":0,"heading":0,"battery":0,"status":0},"ts":514969}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.7750417, 'lon': -58.45649538, 'alt': -0.566671895, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 514969}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77504148,"lon":-58.45649417,"alt":-0.604188919,"speed":0,"heading":0,"battery":0,"status":0},"ts":516207}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77504148, 'lon': -58.45649417, 'alt': -0.604188919, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 516207}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77504145,"lon":-58.45649282,"alt":-0.649129571,"speed":0,"heading":0,"battery":0,"status":0},"ts":517445}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77504145, 'lon': -58.45649282, 'alt': -0.649129571, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 517445}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77504221,"lon":-58.45649106,"alt":-0.681235707,"speed":0,"heading":0,"battery":0,"status":0},"ts":518683}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77504221, 'lon': -58.45649106, 'alt': -0.681235707, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 518683}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77504202,"lon":-58.45649107,"alt":-0.671773712,"speed":0,"heading":0,"battery":0,"status":0},"ts":519921}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77504202, 'lon': -58.45649107, 'alt': -0.671773712, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 519921}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77504226,"lon":-58.45648957,"alt":-0.617441903,"speed":0,"heading":0,"battery":0,"status":0},"ts":521159}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77504226, 'lon': -58.45648957, 'alt': -0.617441903, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 521159}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77504334,"lon":-58.45648787,"alt":-0.572968786,"speed":0,"heading":0,"battery":0,"status":0},"ts":522397}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77504334, 'lon': -58.45648787, 'alt': -0.572968786, 'speed': 0, 'heading': 0, 'battery': 0, 'status': 0}, 'ts': 522397}
# [SERIAL] ✅ Puerto cerrado correctamente
