# %%
# =========================
# [1] IMPORTS Y CONSTANTES
# =========================
import tkinter as tk
from tkinter import ttk, messagebox, scrolledtext, filedialog
import serial
import serial.tools.list_ports
import threading
import time
import json
import pickle
from math import inf
import math
import tkintermapview
from geographiclib.geodesic import Geodesic
import uuid
from PIL import Image, ImageTk

# Protocolo de comunicación
HEADER_OUT = "GS#"    # lo que ENVÍA la base
HEADER_IN  = "UAV#"   # lo que RECIBE la base
FOOTER     = "#END"

# Serial
SERIAL_PORT = None
SERIAL_BAUDRATE = 115200
ser = None
is_connected = False

# ACK
ACK_TIMEOUT = 1.5        # segundos para esperar ACK
MAX_RETRIES = 3          # reintentos máximos
pending_acks = {}        # { id: {"frame": str, "timestamp": float, "retries": int} }
ack_lock = threading.Lock()

# Estado
last_telemetry_pos = None

# Edición de mapa
EDIT_MODE = 'polygon'  # 'move', 'delete', 'home', 'polygon'

# =========================
# [2] ESTRUCTURAS DE DATOS
# =========================
class MissionData:
    def __init__(self):
        self.polygon_points = []   # [(lat, lon), ...]
        self.home_position = None  # (lat, lon) o None
        self.altitude = 3         # Altitud de misión (m)
        self.spacing = 5          # Ancho entre pasadas (m)
        self.detect_spacing = 5 

    def to_dict(self):
        """Convierte a diccionario compacto para LoRa"""
        return {
            "p": [[round(lat, 6), round(lon, 6)] for lat, lon in self.polygon_points],
            "h": [round(self.home_position[0], 6), round(self.home_position[1], 6)] if self.home_position else None,
            "a": self.altitude,
            "s": self.spacing,
            "ds": self.detect_spacing,
        }

    def from_dict(self, data):
        """Carga desde diccionario"""
        self.polygon_points = [tuple(point) for point in data.get("p", [])]
        self.home_position = tuple(data["h"]) if data.get("h") else None
        self.altitude = data.get("a", 3)
        self.spacing = data.get("s", 5)
        self.detect_spacing = data.get("ds", 5)

# =========================
# [3] VARIABLES GLOBALES GUI
# =========================
# Mapa y marcadores
polygon_markers = []
polygon_path = None
home_marker = None
home_line = None
mission_path = None
waypoint_markers = []
waypoint_status = []
fire_markers = []
person_markers = []
current_target_marker = None


# Controles / widgets
btn_disarm = None
btn_mission = None
btn_return = None
btn_arm = None
event_action_var = None
port_var = None
spacing_var = None
altitude_var = None
detect_spacing_var = None   
status_message = None
home_position_var = None
progress_var = None
progress_bar = None

# Gripper
gripper_state_var = None

# Vistas
root = None
mapa = None
telemetry_text = None
log_text = None

#iconos
active_wp_marker = None      # marcador del waypoint actual
waypoint_list = []           # coordenadas de cada waypoint enviadas por el dron
waypoint_total = 0

flight_track = []     # lista de puntos reales recorridos
flight_path = None    # path verde en el mapa


# =========================
# [4] UTILIDADES GEODÉSICAS
# =========================
def calculate_distance(lat1, lon1, lat2, lon2):
    """Distancia en metros entre dos puntos"""
    return Geodesic.WGS84.Inverse(lat1, lon1, lat2, lon2)['s12']

def calculate_bearing(lat1, lon1, lat2, lon2):
    """Rumbo en grados entre dos puntos"""
    return Geodesic.WGS84.Inverse(lat1, lon1, lat2, lon2)['azi1']

def get_point_at_distance(lat1, lon1, bearing, distance):
    """Punto desde (lat1, lon1) a distancia (m) y rumbo (°)"""
    result = Geodesic.WGS84.Direct(lat1, lon1, bearing, distance)
    return (result['lat2'], result['lon2'])

# =============================================
# [4B] GENERACIÓN DE PATRÓN LAWNMOWER EN LA GS
# =============================================

def rotate_point(lat, lon, origin_lat, origin_lon, angle_deg):
    """
    Convierte (lat, lon) a coordenadas locales en METROS respecto al origen
    y las rota angle_deg grados. Devuelve (x_rot, y_rot) en metros.
    """
    # 1) Pasar de lat/lon a sistema local (x,y) en metros
    dx = calculate_distance(origin_lat, origin_lon, origin_lat, lon)
    if lon < origin_lon:
        dx = -dx

    dy = calculate_distance(origin_lat, origin_lon, lat, origin_lon)
    if lat < origin_lat:
        dy = -dy

    # 2) Rotar en el plano local
    angle = math.radians(angle_deg)
    xr = dx * math.cos(angle) - dy * math.sin(angle)
    yr = dx * math.sin(angle) + dy * math.cos(angle)

    # 3) OJO: acá NO volvemos a lat/lon.
    #     Devolvemos coordenadas locales rotadas en METROS.
    return xr, yr


def rotate_polygon(points, origin, angle_deg):
    return [rotate_point(p[0], p[1], origin[0], origin[1], angle_deg) for p in points]

def local_to_latlon(x, y, origin_lat, origin_lon, angle_deg):
    """
    Convierte coordenadas locales (x,y) EN METROS, rotadas, 
    nuevamente a coordenadas geográficas (lat/lon).
    angle_deg = ángulo original del polígono respecto al norte.
    """
    # Rotar de vuelta al sistema global
    angle = math.radians(angle_deg)
    xr = x * math.cos(angle) - y * math.sin(angle)
    yr = x * math.sin(angle) + y * math.cos(angle)

    # Convertir valores locales (xr, yr) de metros a lat/lon reales
    lat = get_point_at_distance(origin_lat, origin_lon, 0, yr)[0]
    lon = get_point_at_distance(origin_lat, origin_lon, 90, xr)[1]

    return lat, lon


def generate_lawnmower_path(polygon, spacing, ds):
    """
    Genera el patrón lawnmower COMPLETO para mostrar en GS.
    polygon: lista [(lat, lon), ...]
    spacing: separación entre pasadas (en metros)
    ds: distancia entre puntos de detección (en metros)
    """
    if len(polygon) < 3:
        return []

    # -------------------------
    # 1. Encontrar lado mayor
    # -------------------------
    max_len = -1
    pA, pB = polygon[0], polygon[1]
    for i in range(len(polygon)):
        for j in range(i+1, len(polygon)):
            d = calculate_distance(polygon[i][0], polygon[i][1],
                                   polygon[j][0], polygon[j][1])
            if d > max_len:
                max_len = d
                pA, pB = polygon[i], polygon[j]

    # rumbo del lado mayor
    bearing = calculate_bearing(pA[0], pA[1], pB[0], pB[1])

    # -------------------------
    # 2. Rotar polígono para que lado mayor quede horizontal
    # -------------------------
    origin = pA
    polygon_rot = rotate_polygon(polygon, origin, -bearing)

    # -------------------------
    # 3. Encontrar Y min y Y max
    # -------------------------
    ys = [pt[1] for pt in polygon_rot]
    min_y, max_y = min(ys), max(ys)

    # -------------------------
    # 4. Generar pasadas a intervalos "spacing"
    # -------------------------
    path = []
    y = min_y
    direction = 1

    while y <= max_y:
        # Intersecciones de borde con esta línea horizontal "y"
        intersections = []
        for i in range(len(polygon_rot)):
            x1, y1 = polygon_rot[i]
            x2, y2 = polygon_rot[(i + 1) % len(polygon_rot)]

            # chequear si cruza
            if (y1 <= y <= y2) or (y2 <= y <= y1):
                if y1 == y2:
                    continue  # borde horizontal, ignorar
                t = (y - y1) / (y2 - y1)
                x = x1 + t * (x2 - x1)
                intersections.append(x)

        intersections.sort()

        if len(intersections) >= 2:
            x_start, x_end = intersections[0], intersections[-1]

            # ----------------------------
            # Crear puntos cada "ds" metros
            # ----------------------------
            segment_length = abs(x_end - x_start)
            n_points = max(2, int(segment_length / ds))

            if direction == 1:
                xs = [x_start + (segment_length * i / (n_points - 1))
                      for i in range(n_points)]
            else:
                xs = [x_end - (segment_length * i / (n_points - 1))
                      for i in range(n_points)]

            # ----------------------------
            # Convertir x,y rotado → lat/lon real
            # ----------------------------
            for x in xs:
                lat, lon = local_to_latlon(x, y, origin[0], origin[1], bearing)
                path.append((lat, lon))

        direction *= -1
        y += spacing

    return path

# =========================================================
# [5] LOG Y TELEMETRÍA (SEGUROS PARA LLAMAR DESDE HILOS)
# =========================================================
def log_message(message):
    """Agrega texto al log de manera segura desde cualquier hilo."""
    try:
        timestamp = time.strftime('%H:%M:%S')
        full_msg = f"{timestamp} - {message}\n"

        if 'log_text' not in globals() or not log_text:
            print(full_msg.strip())  # fallback si GUI aún no existe
            return

        def update_log():
            log_text.config(state="normal")
            log_text.insert("end", full_msg)
            log_text.see("end")
            log_text.config(state="disabled")

        root.after(0, update_log)
    except Exception as e:
        print(f"[Log Error] {e} :: {message}")

def update_telemetry(data):
    """Actualiza panel de telemetría y marcador del dron."""
    if not root:
        return

    def update_gui():
        global last_telemetry_pos
        telemetry_text.config(state="normal")
        telemetry_text.delete(1.0, "end")

        telemetry_str = f"Latitud: {data.get('lat', 'N/A')}\n"
        telemetry_str += f"Longitud: {data.get('lon', 'N/A')}\n"
        telemetry_str += f"Altitud: {data.get('alt', 'N/A')} m\n"
        telemetry_str += f"Velocidad: {data.get('speed', 'N/A')} km/h\n"
        telemetry_str += f"Rumbo: {data.get('heading', 'N/A')}°\n"
        telemetry_str += f"Batería: {data.get('battery', 'N/A')}\n"
        telemetry_str += f"Estado: {data.get('status', 'N/A')}\n"
        telemetry_str += f"Waypoint actual: {data.get('current_wp', 'N/A')}\n"
        telemetry_str += f"Waypoints totales: {data.get('total_wp', 'N/A')}\n"

        telemetry_text.insert("end", telemetry_str)
        telemetry_text.config(state="disabled")

        if 'lat' in data and 'lon' in data and data['lat'] != 'N/A' and data['lon'] != 'N/A':
            lat = data['lat']
            lon = data['lon']
            last_telemetry_pos = (lat, lon)
        
            update_drone_position(lat, lon)   # marcador DRON
            update_flight_track(lat, lon)     # ← NUEVO: ruta recorrida


    root.after(0, update_gui)

def update_drone_position(lat, lon):
    """Dibuja/actualiza el marcador del dron en el mapa."""
    if hasattr(update_drone_position, "marker") and update_drone_position.marker:
        update_drone_position.marker.delete()

    update_drone_position.marker = mapa.set_marker(
        lat, lon, text="DRON",
        marker_color_circle="red", marker_color_outside="red",
        text_color="red", font=("Helvetica", 12, "bold")
    )

    current_center = mapa.get_position()
    if calculate_distance(current_center[0], current_center[1], lat, lon) > 5000:
        mapa.set_position(lat, lon)
        mapa.set_zoom(15)
def update_flight_track(lat, lon):
    global flight_track, flight_path

    # Agregar punto si cambia realmente la posición
    if not flight_track or (flight_track[-1][0] != lat or flight_track[-1][1] != lon):
        flight_track.append((lat, lon))

    # Borrar path anterior
    if flight_path:
        try:
            flight_path.delete()
        except:
            pass

    # Dibujar nueva ruta
    if len(flight_track) > 1:
        flight_path = mapa.set_path(flight_track, color="green", width=3)


def create_active_wp_marker(lat, lon, wp_id):
    return mapa.set_marker(
        lat, lon,
        text=f"WP{wp_id}",
        marker_color_circle="#FFD000",   # amarillo fuerte
        marker_color_outside="#A67C00",  # borde marrón oscuro
        text_color="black",
        font=("Helvetica", 11, "bold")
    )
def update_active_waypoint(lat, lon, wp_id):
    global active_wp_marker

    # borrar anterior
    if active_wp_marker:
        active_wp_marker.delete()

    # crear el nuevo
    active_wp_marker = create_active_wp_marker(lat, lon, wp_id)


# =====================================
# [6] COMUNICACIÓN: CONEXIÓN / ENVÍOS
# =====================================
def connect_serial():
    """Conecta el puerto serial y lanza los hilos de recepción y ACK."""
    global ser, is_connected, SERIAL_PORT

    is_connected = False
    SERIAL_PORT = port_var.get()

    if not SERIAL_PORT:
        messagebox.showerror("Error", "Selecciona un puerto serial primero")
        return False

    try:
        ser = serial.Serial(SERIAL_PORT, SERIAL_BAUDRATE, timeout=1)
        ser.reset_input_buffer()
        ser.reset_output_buffer()

        is_connected = True
        print(f"[SERIAL] ✅ Conectado a {SERIAL_PORT} @ {SERIAL_BAUDRATE} bps")
        status_label.config(text=f"Conectado: {SERIAL_PORT}", fg="green")
        log_message(f"✅ Conectado correctamente a {SERIAL_PORT} a {SERIAL_BAUDRATE} bps")

        if 'root' in globals() and root:
            print("[SERIAL] 🚀 Lanzando hilos: recepción y ack_manager")
            threading.Thread(target=receive_data, daemon=True).start()
            threading.Thread(target=ack_manager, daemon=True).start()
        else:
            print("[SERIAL] ⚠️ GUI no inicializada aún, no se lanzan hilos")

        return True

    except Exception as e:
        is_connected = False
        print(f"[SERIAL] ❌ Error conectando a {SERIAL_PORT}: {e}")
        log_message(f"❌ Error conectando al puerto {SERIAL_PORT}: {e}")
        messagebox.showerror("Error", f"No se pudo conectar: {str(e)}")
        return False

def disconnect_serial():
    """Desconecta el puerto serial de forma segura y limpia."""
    global ser, is_connected

    if not is_connected:
        print("[SERIAL] ⚠️ No hay conexión activa para cerrar.")
        log_message("⚠️ No hay conexión activa para cerrar.")
        return

    try:
        is_connected = False
        time.sleep(0.2)  # permitir que terminen hilos
        if ser and ser.is_open:
            ser.close()
        status_label.config(text="Desconectado", fg="red")
        log_message("🔌 Puerto serial cerrado correctamente")
        print("[SERIAL] ✅ Puerto cerrado correctamente")
    except Exception as e:
        log_message(f"⚠️ Error al cerrar el puerto serial: {e}")
        print(f"[SERIAL] ⚠️ Error al cerrar puerto: {e}")
    finally:
        ser = None

def send_command(command_type, data=None, require_ack=True):
    """Forma el frame GS#...#END, envía y registra para ACK si corresponde."""
    if not is_connected:
        messagebox.showwarning("Error", "No hay conexión serial")
        return

    # ID único del paquete
    packet_id = str(uuid.uuid4())[:8]

    message = {
        "t": command_type,
        "d": data if data else {},
        "ts": int(time.time() * 1000),
        "id": packet_id
    }

    payload = json.dumps(message, separators=(",", ":"))
    frame   = f"{HEADER_OUT}{payload}{FOOTER}"

    try:
        # 🟦 Print de envío completo
        print(f"[TX → LoRa/send_command] Frame enviado → {frame}")
        
        ser.write(frame.encode())
        log_message(f"Enviado: {frame}")

        if require_ack and command_type != "TELEMETRY":
            with ack_lock:
                pending_acks[packet_id] = {
                    "frame": frame,
                    "timestamp": time.time(),
                    "retries": 0
                }

    except Exception as e:
        log_message(f"Error enviando: {str(e)}")

# ========================================
# [7] COMUNICACIÓN: RECEPCIÓN Y ACKs
# ========================================
def ack_manager():
    """Reintenta envíos sin ACK dentro del timeout."""
    while is_connected:
        time.sleep(0.2)
        now = time.time()

        with ack_lock:
            to_delete = []
            for pid, info in list(pending_acks.items()):
                if now - info["timestamp"] > ACK_TIMEOUT:
                    if info["retries"] < MAX_RETRIES:
                        try:
                            ser.write(info["frame"].encode())
                            pending_acks[pid]["timestamp"] = now
                            pending_acks[pid]["retries"] += 1
                            print(f"[ACK MANAGER → LoRa] 🔄 Reintentando ID={pid} (reintento {info['retries']})")
                            log_message(f"🔄 Reintentando envío ID={pid}")
                        except Exception as e:
                            print(f"[ACK MANAGER] ⚠️ Error reintentando ID={pid}: {e}")
                            log_message(f"Error reintentando ID={pid}: {e}")
                    else:
                        log_message(f"❌ No se recibió ACK para ID={pid}")
                        print(f"[ACK MANAGER] ❌ ACK no recibido tras {MAX_RETRIES} intentos → ID={pid}")
                        to_delete.append(pid)

            for pid in to_delete:
                del pending_acks[pid]

def receive_data():
    """Lee y procesa frames UAV#...#END desde el serial."""
    global is_connected
    buffer = ""

    while is_connected:
        if not ser or not ser.is_open:
            break
        try:
            if ser.in_waiting > 0:
                chunk = ser.read(ser.in_waiting).decode(errors="ignore")
                buffer += chunk

                while True:
                    h = buffer.find(HEADER_IN)
                    if h < 0:
                        if len(buffer) > 4096:
                            buffer = buffer[-512:]
                        break

                    f = buffer.find(FOOTER, h)
                    if f < 0:
                        if h > 0: buffer = buffer[h:]
                        break

                    payload = buffer[h + len(HEADER_IN):f].strip()
                    buffer = buffer[f + len(FOOTER):]

                    # 🟩 Print de recepción de paquete completo
                    print(f"[RX ← LoRa/receive_data] Frame recibido ← UAV#{payload}#END")

                    try:
                        msg = json.loads(payload)
                        process_received_message(msg)
                    except Exception as e:
                        log_message(f"❌ Mensaje inválido: {payload[:80]} ({e})")

            time.sleep(0.01)
        except Exception as e:
            log_message(f"Error recibiendo datos: {e}")
            time.sleep(0.1)

    log_message("📴 Hilo de recepción terminado")

def process_received_message(message):
    """
    Procesa cualquier JSON recibido desde el dron (UAV).
    Envía ACK automáticos cuando corresponde (manteniendo framing GS#/UAV# y #END).
    """

    msg_type = message.get("t", "")
    data = message.get("d", message)   # <— CORRECTO Y BIEN INDENTADO
    packet_id = message.get("id", data.get("id", None))

    print(f"[RX ← LoRa/process_received_message] Mensaje recibido tipo '{msg_type}' → {message}")

    if not msg_type:
        log_message(f"⚠️ Mensaje sin tipo: {message}")
        return

    # =====================================================================================
    # ACK entrante desde UAV
    # =====================================================================================
    if msg_type == "ACK":
        print(f"[ACK IN ← LoRa/process_received_message] {message}")
        ack_id = None

        if "id" in message:
            ack_id = message["id"]
        elif isinstance(message.get("d"), dict) and "id" in message["d"]:
            ack_id = message["d"]["id"]

        if ack_id:
            with ack_lock:
                if ack_id in pending_acks:
                    del pending_acks[ack_id]
                    log_message(f"✅ ACK recibido para ID={ack_id}")
                else:
                    log_message(f"⚠️ ACK recibido con ID desconocido: {ack_id}")
        else:
            log_message("⚠️ ACK recibido sin ID válido")

        return

    # =====================================================================================
    # TELEMETRY
    # =====================================================================================
    if msg_type == "TELEMETRY":
        update_telemetry(data)
        return

    # =====================================================================================
    # STATUS
    # =====================================================================================
    elif msg_type == "STATUS":
        # Ejemplo de data:
        # {"t":"STATUS","state":3,"state_name":"NAVIGATE"}
        print(f"[STATUS ← LoRa] Data: {data}")
    
        # Intentamos distintas claves, para ser robustos:
        name = (
            data.get("state_name")
            or data.get("message")
            or str(data.get("state", "DESCONOCIDO"))
        )
    
        log_message(f"Estado FSM: {name}")
        status_message.set(f"Estado FSM: {name}")
        return


    # =====================================================================================
    # WAYPOINTS_INFO
    # =====================================================================================
    elif msg_type == "WAYPOINTS_INFO":
        global waypoint_total, waypoint_list
    
        total = data.get("total", 0)
    
        initialize_waypoint_tracking(total)
    
        waypoint_total = total       # ← ahora sí actualiza la global
        waypoint_list.clear()
        
        # Crear lista vacía del tamaño adecuado
        for _ in range(total):
            waypoint_list.append((None, None))   # Placeholder seguro
        
        update_active_waypoint(None, None, 0)  # marcador vacío opcional

    
        log_message(f"Total de waypoints: {total}")
        progress_bar["value"] = 0
        return

    # =====================================================================================
    # WAYPOINT_REACHED
    # =====================================================================================
    elif msg_type == "WAYPOINT_REACHED":
        wp = data.get("wp", -1)
    
        log_message(f"Waypoint alcanzado: {wp}")
        waypoint_reached(wp)  # ← ACTUALIZA barra y texto
    
        # manejo del marcador amarillo
        global active_wp_marker
    
        # último waypoint → borrar marcador
        if wp + 1 >= waypoint_total:
            if active_wp_marker:
                active_wp_marker.delete()
                active_wp_marker = None
            return
    
        # si tenemos la lista (por ahora quizás solo wp0)
        if wp + 1 < len(waypoint_list):
            lat, lon = waypoint_list[wp + 1]
            update_active_waypoint(lat, lon, wp + 1)
    
        return
    
    # =====================================================================================
    # WP_UPDATE (nuevo, enviado por el dron)
    # =====================================================================================
    elif msg_type == "WP_UPDATE":
    
        wp = data.get("wp", -1)
        lat = data.get("lat")
        lon = data.get("lon")
    
        if lat is None or lon is None:
            return
    
        update_active_waypoint(lat, lon, wp)
    
        # Guardar en lista por si querés usarlo luego
        if wp < len(waypoint_list):
            waypoint_list[wp] = (lat, lon)
        else:
            waypoint_list.append((lat, lon))
    
        return


    # =====================================================================================
    # DEBUG
    # =====================================================================================
    elif msg_type == "DEBUG":
        print(f"[DEBUG ← LoRa] Data: {data}")
        log_message(f"🪲 DEBUG: {data.get('message', '')}")
        return

    # =====================================================================================
    # FIRE
    # =====================================================================================
    elif msg_type == "FIRE":
        confidence = data.get("confidence", None)

        print(f"[FIRE ← LoRa] Data: {data}")

        if confidence is not None:
            try:
                confidence = float(confidence)
                if confidence > 1:
                    confidence /= 100.0
            except:
                confidence = None

            log_message(f"🔥 Evento FIRE detectado (confianza={confidence*100:.1f}%)")
        else:
            log_message("🔥 Evento FIRE detectado (sin dato de confianza)")

        add_fire_marker(data)
        return

    # =====================================================================================
    # PERSON
    # =====================================================================================
    elif msg_type == "PERSON":
        confidence = data.get("confidence", None)

        print(f"[PERSON ← LoRa] Data: {data}")

        if confidence is not None:
            try:
                confidence = float(confidence)
                if confidence > 1:
                    confidence /= 100.0
            except:
                confidence = None

            log_message(f"🧍 Evento PERSON detectado (confianza={confidence*100:.1f}%)")
        else:
            log_message("🧍 Evento PERSON detectado (sin dato de confianza)")

        add_person_marker(data)
        return

# ======================================
# [8] GESTIÓN DE MISIÓN (ENVÍOS, ESTADO)
# ======================================
def update_mission_parameters():
    current_mission.altitude = altitude_var.get()
    current_mission.spacing = spacing_var.get()
    current_mission.detect_spacing = detect_spacing_var.get()
    log_message("Parámetros de misión actualizados")

def send_compact_mission():
    if len(current_mission.polygon_points) < 4:
        messagebox.showwarning("Error", "Definí al menos 4 punto en el mapa")
        return

    if not current_mission.home_position:
        messagebox.showwarning("Error", "Establece una posición HOME primero")
        return
    update_mission_parameters()
    mission_dict = current_mission.to_dict()
    mission_dict["event_action"] = event_action_var.get()

    # Generar path para visualizar
    path = generate_lawnmower_path(
        current_mission.polygon_points,
        current_mission.spacing,
        detect_spacing_var.get()  # (lo agregaremos)
    )
    draw_mission_path(path)

    
    send_command("MISSION_COMPACT", mission_dict)
    print(f"[TX → LoRa/send_compact_mission] Datos misión compacta → {mission_dict}")
    log_message(f"Misión enviada (formato compacto) con acción tras evento: {event_action_var.get()}")

def start_mission():
    btn_return.config(state="normal", bg="orange")
    
    # ==== NUEVO ====
    global waypoint_status, waypoint_total
    path = generate_lawnmower_path(
        current_mission.polygon_points,
        current_mission.spacing,
        current_mission.detect_spacing
    )
    print(f"[DEBUG GS] lawnmower tiene {len(path)} puntos")
    waypoint_total = len(path)
    waypoint_status = ["pending"] * waypoint_total
    update_waypoint_display()
    # ===============

    send_compact_mission()


def return_home():
   # btn_disarm.config(state="normal", bg="red")
    btn_mission.config(state="disabled", bg="lightgrey")
    #btn_return.config(state="disabled", bg="lightgrey")
    send_command("RETURN")
    print("[TX → LoRa/return_home] Enviando comando RETURN")

def arm_drone():
    if not last_telemetry_pos:
        log_message("⚠️ No hay datos de telemetría para fijar HOME")
        return
    send_command("ARM")
    log_message("🚁 Drone ARMADO")
    print("[TX → LoRa/arm_drone] Enviando comando ARM")
   # btn_disarm.config(state="disabled", bg="lightgrey")
    btn_mission.config(state="normal", bg="green", fg="white")

def disarm_drone():
    global home_marker, home_line
    if home_marker:
        home_marker.delete(); 
    if home_line:
        home_line.delete()
    home_marker = None
    home_line = None
    current_mission.home_position = None
    home_position_var.set("")
    send_command("DISARM")
    print("[TX → LoRa/disarm_drone] Enviando comando DISARM")
    log_message("🛑 Drone DESARMADO")
    btn_mission.config(state="disabled", bg="lightgray", fg="black")
    btn_return.config(state="disabled", bg="lightgrey", fg="black")

# Stubs para evitar errores si se usan en el futuro
def at_home(): return True
def not_mission_started(): return True

def show_target_waypoint(lat, lon):
    global current_target_marker

    # borrar marcador anterior
    if current_target_marker is not None:
        current_target_marker.delete()

    # crear nuevo marcador
    current_target_marker = mapa.set_marker(lat, lon, text="Destino")


def initialize_waypoint_tracking(total_waypoints):
    global waypoint_status
    waypoint_status = ["pending"] * total_waypoints
    update_waypoint_display()

def waypoint_reached(wp_number):
    global waypoint_status, waypoint_total

    # --- Validación básica ---
    if wp_number is None:
        log_message("⚠️ WAYPOINT_REACHED recibido sin número de waypoint")
        return

    total_wp = len(waypoint_status)

    # --- Si el dron reporta un WP fuera de rango ---
    if wp_number < 0:
        log_message(f"⚠️ WAYPOINT_REACHED inválido (<0): {wp_number}")
        return

    if wp_number >= total_wp:
        log_message(
            f"⚠️ WAYPOINT_REACHED fuera de rango: {wp_number} "
            f"(total={total_wp}). Marcando todos como completados."
        )
        # --- MEJORA OPCIONAL ---
        # Si el dron se saltea números → completar todos
        for i in range(total_wp):
            waypoint_status[i] = "completed"
        update_waypoint_display()
        return

    # --- MEJORA OPCIONAL ---
    # Si llega WP=5 pero 0..4 están sin completar → completarlos automáticamente
    for i in range(wp_number + 1):
        waypoint_status[i] = "completed"

    update_waypoint_display()
    log_message(f"Waypoint {wp_number} completado")

    # --- Último waypoint ---
    if wp_number == total_wp - 1:
        log_message("🎉 ¡Todos los waypoints completados!")


def update_waypoint_display():
    if not waypoint_status:
        return

    completed = waypoint_status.count("completed")
    total = len(waypoint_status)

    def update_gui():
        progress_var.set(f"Waypoints: {completed}/{total}")
        progress_bar['value'] = (completed / total) * 100

    root.after(0, update_gui)

# ===========================================
# [9] MAPA: EDICIÓN, DIBUJO Y MARCADORES
# ===========================================
def set_edit_mode(mode):
    global EDIT_MODE
    EDIT_MODE = mode
    modes = {
        'polygon': "Añadir Puntos de Polígono",
        'move': "Mover Marcadores",
        'delete': "Eliminar Marcadores"
    }
    status_message.set(f"Modo: {modes.get(mode, mode)}")
    log_message(f"Modo cambiado a: {modes.get(mode, mode)}")
    update_button_colors()

def update_button_colors():
    for btn in [add_btn, delete_btn]:
        btn.config(bg="SystemButtonFace")
    if EDIT_MODE == 'polygon':
        add_btn.config(bg="lightblue")
    elif EDIT_MODE == 'delete':
        delete_btn.config(bg="lightcoral")

def map_click(coords):
    lat, lon = coords
    if EDIT_MODE == 'polygon':
        current_mission.polygon_points.append((lat, lon))
        current_mission.polygon_points = order_polygon_points(current_mission.polygon_points)
        marker = mapa.set_marker(lat, lon, text=f"P{len(current_mission.polygon_points)}")
        polygon_markers.append(marker)
        update_polygon_drawing()
        refresh_mission_preview()
        log_message(f"Punto de polígono añadido: {lat:.6f}, {lon:.6f}")
    elif EDIT_MODE == 'delete':
        closest_marker = find_closest_marker(lat, lon)
        if closest_marker:
            delete_marker(closest_marker)
        else:
            log_message("No se encontró ningún marcador cercano")

def find_closest_marker(lat, lon, max_distance=1000):
    closest_marker = None
    min_distance = inf
    for i, marker in enumerate(polygon_markers):
        marker_pos = marker.position
        dist = calculate_distance(lat, lon, marker_pos[0], marker_pos[1])
        if dist < min_distance and dist < max_distance:
            min_distance = dist
            closest_marker = ('polygon', i, marker)
    if home_marker:
        marker_pos = home_marker.position
        dist = calculate_distance(lat, lon, marker_pos[0], marker_pos[1])
        if dist < min_distance and dist < max_distance:
            min_distance = dist
            closest_marker = ('home', 0, home_marker)
    return closest_marker

def delete_marker(marker_info):
    global home_marker, home_line
    btn_mission.config(state="disabled", bg="lightgray", fg="black")
    marker_type, index, marker = marker_info
    if marker_type == 'polygon':
        current_mission.polygon_points.pop(index)
        current_mission.polygon_points = order_polygon_points(current_mission.polygon_points)
        marker.delete()
        polygon_markers.pop(index)
        for i, marker in enumerate(polygon_markers):
            marker.set_text(f"P{i + 1}")
        update_polygon_drawing()
        refresh_mission_preview()
        log_message(f"Punto P{index + 1} eliminado")
    elif marker_type == 'home':
        if home_marker:
            home_marker.delete(); 
        if home_line:
            home_line.delete()
        home_marker = None
        home_line = None
        current_mission.home_position = None
        home_position_var.set("")
        log_message("🏠 HOME eliminado")

def set_home_position(lat, lon):
    global home_marker, home_line
    if home_marker: home_marker.delete()
    if home_line: home_line.delete()
    home_marker = None
    home_line = None

    current_mission.home_position = (lat, lon)
    home_marker = mapa.set_marker(lat, lon, text="HOME",
                                  marker_color_circle="white", marker_color_outside="green")
    home_position_var.set(f"{lat:.6f}, {lon:.6f}")
    log_message(f"🏠 Home position establecida: {lat:.6f}, {lon:.6f}")

    if current_mission.polygon_points:
        closest_point = find_closest_polygon_point(lat, lon)
        home_line = mapa.set_path([current_mission.home_position, closest_point], color="green", width=2)

    refresh_mission_preview()


def set_home_from_telemetry():
    """Establece HOME desde última telemetría."""
    global last_telemetry_pos
    if not last_telemetry_pos:
        log_message("⚠️ No hay datos de telemetría para establecer HOME")
        messagebox.showwarning("Atención", "No hay datos de telemetría disponibles")
        return
    lat, lon = last_telemetry_pos
    set_home_position(lat, lon)
    log_message(f"🏠 HOME actualizado desde telemetría: {lat:.6f}, {lon:.6f}")

def find_closest_polygon_point(lat, lon):
    if not current_mission.polygon_points:
        return None
    min_distance = inf
    closest_point = None
    for point in current_mission.polygon_points:
        dist = calculate_distance(lat, lon, point[0], point[1])
        if dist < min_distance:
            min_distance = dist
            closest_point = point
    return closest_point

def add_fire_marker(data):
    lat = data.get('lat')
    lon = data.get('lon')
    conf = data.get('confidence', None)

    if lat is None or lon is None:
        return

    # Construir etiqueta multilínea
    if conf is not None:
        label = f"FUEGO ({conf*100:.1f}%)\n{lat:.6f}, {lon:.6f}"
    else:
        label = f"FUEGO\n{lat:.6f}, {lon:.6f}"

    # Crear marcador principal
    marker = mapa.set_marker(
        lat, lon,
        text=label,
        marker_color_circle="orange",
        marker_color_outside="orange",
        text_color="black",
        font=("Arial", 9, "bold")
    )
    fire_markers.append(marker)

    # Log visual
    if conf is not None:
        log_message(f"🔥 Marcador FUEGO agregado: {lat:.6f}, {lon:.6f} (Confianza={conf*100:.1f}%)")
    else:
        log_message(f"🔥 Marcador FUEGO agregado: {lat:.6f}, {lon:.6f}")


def add_person_marker(data):
    lat = data.get('lat')
    lon = data.get('lon')
    conf = data.get('confidence', None)

    if lat is None or lon is None:
        return

    # Construir etiqueta multilínea
    if conf is not None:
        label = f"PERSONA ({conf*100:.1f}%)\n{lat:.6f}, {lon:.6f}"
    else:
        label = f"PERSONA\n{lat:.6f}, {lon:.6f}"

    # Crear marcador principal
    marker = mapa.set_marker(
        lat, lon,
        text=label,
        marker_color_circle="#8B4513",
        marker_color_outside="#8B4513",
        text_color="black",
        font=("Arial", 9, "bold")
    )
    person_markers.append(marker)

    # Log visual
    if conf is not None:
        log_message(f"🧍 Marcador PERSONA agregado: {lat:.6f}, {lon:.6f} (Confianza={conf*100:.1f}%)")
    else:
        log_message(f"🧍 Marcador PERSONA agregado: {lat:.6f}, {lon:.6f}")


def update_polygon_drawing():
    global polygon_path
    current_mission.polygon_points = order_polygon_points(current_mission.polygon_points)
    if polygon_path:
        polygon_path.delete()
    if len(current_mission.polygon_points) >= 2:
        polygon_path = mapa.set_polygon(
            current_mission.polygon_points,
            outline_color="blue", fill_color="lightblue", border_width=2
 
         )
    refresh_mission_preview()

def order_polygon_points(points):
    """
    Ordena automáticamente los puntos del polígono según ángulo polar
    respecto al centroide, evitando cruces tipo 'moño'.
    """
    if len(points) < 3:
        return points

    cx = sum(p[0] for p in points) / len(points)
    cy = sum(p[1] for p in points) / len(points)

    ordered = sorted(points, key=lambda p: math.atan2(p[1] - cy, p[0] - cx))
    return ordered

def draw_mission_path(points):
    global mission_path
    if mission_path:
        try:
            mission_path.delete()
        except:
            pass

    if len(points) > 1:
        mission_path = mapa.set_path(points, color="yellow", width=3)

def refresh_mission_preview():
    """Regenera el lawnmower automáticamente si hay polígono y HOME."""
    global mission_path

    if len(current_mission.polygon_points) < 3:
        if mission_path:
            mission_path.delete()
            mission_path = None
        return

    # Actualizar parámetros de misión actuales
    current_mission.spacing = spacing_var.get()
    current_mission.detect_spacing = detect_spacing_var.get()

    # Generar path
    path = generate_lawnmower_path(
        current_mission.polygon_points,
        current_mission.spacing,
        current_mission.detect_spacing
    )
    
    # Insertar HOME como primer punto como hace el ESP
    if current_mission.home_position:
        path.insert(0, current_mission.home_position)


    # Dibujarlo
    draw_mission_path(path)



def clear_all_waypoints():
    global waypoint_markers, active_wp_marker

    # Borrar marcador activo si existe
    if active_wp_marker:
        active_wp_marker.delete()
        active_wp_marker = None

    # Borrar todos los demás waypoints
    for m in waypoint_markers:
        try:
            m.delete()
        except:
            pass

    waypoint_markers.clear()
    print("🗑 Todos los waypoints eliminados")


def reset_polygon():
    global current_mission, polygon_markers, polygon_path
    global home_marker, home_line, mission_path
    global waypoint_status, person_markers, fire_markers

    # Borrar marcadores del polígono
    for m in polygon_markers:
        m.delete()
    polygon_markers.clear()

    # Borrar polígono dibujado
    if polygon_path is not None:
        try: 
            polygon_path.delete()
        except Exception as e:
            log_message(f"Error borrando polígono: {e}")
        polygon_path = None

    # Limpiar ruta recorrida
    global flight_track, flight_path
    flight_track = []
    if flight_path:
        try:
            flight_path.delete()
        except:
            pass
    flight_path = None

    # Borrar HOME
    if home_marker: home_marker.delete()
    if home_line: home_line.delete()
    home_marker = None
    home_line = None

    # Borrar marcadores de eventos
    for m in person_markers: m.delete()
    person_markers.clear()

    for m in fire_markers: m.delete()
    fire_markers.clear()

    # 🟨 BORRAR CAMINO DE MISIÓN (mission_path)
    if mission_path:
        try:
            mission_path.delete()
        except:
            pass
    mission_path = None

    # Reset de la misión
    current_mission = MissionData()
    waypoint_status = []

    # Reset UI elements
    home_position_var.set("")
    progress_var.set("Waypoints: 0/0")
    progress_bar['value'] = 0
    altitude_var.set(3)
    spacing_var.set(5)
    detect_spacing_var.set(5)

    clear_all_waypoints()

    log_message("🔄 Reset completo: polígono, HOME, misión y mission path eliminados")


# =========================================
# [11] ARCHIVOS DE MISIÓN (GUARDAR/CARGAR)
# =========================================
def save_mission():
    if not current_mission.polygon_points:
        messagebox.showwarning("Error", "No hay misión para guardar")
        return
    filename = filedialog.asksaveasfilename(
        defaultextension=".mission",
        filetypes=[("Mission files", "*.mission"), ("All files", "*.*")]
    )
    if filename:
        try:
            with open(filename, 'wb') as f:
                pickle.dump(current_mission.to_dict(), f)
            log_message(f"Misión guardada: {filename}")
        except Exception as e:
            log_message(f"Error guardando misión: {str(e)}")

def load_mission():
    filename = filedialog.askopenfilename(
        filetypes=[("Mission files", "*.mission"), ("All files", "*.*")]
    )
    if filename:
        try:
            with open(filename, 'rb') as f:
                mission_data = pickle.load(f)
            reset_polygon()
            current_mission.from_dict(mission_data)
            update_interface_from_mission()
            log_message(f"Misión cargada: {filename}")
        except Exception as e:
            log_message(f"Error cargando misión: {str(e)}")

def update_interface_from_mission():
    for i, (lat, lon) in enumerate(current_mission.polygon_points):
        marker = mapa.set_marker(lat, lon, text=f"P{i+1}")
        polygon_markers.append(marker)
    if current_mission.home_position:
        set_home_position(current_mission.home_position[0], current_mission.home_position[1])
    altitude_var.set(current_mission.altitude)
    spacing_var.set(current_mission.spacing)
    detect_spacing_var.set(current_mission.detect_spacing)
    update_polygon_drawing()

# =========================================
# [12] CONSTRUCCIÓN DE LA GUI (TKINTER)
# =========================================
def create_trim_pid_controls(frame):
    """Panel reducido: SOLO Gripper y Simulación"""

    # === CONTENEDOR PRINCIPAL ===
    container = tk.Frame(frame)
    container.pack(fill="both", expand=True, padx=10, pady=10)
    container.grid_columnconfigure(0, weight=1)

    # =====================================================================
    # GRIPPER — NUEVA VERSIÓN CON DOS BOTONES
    # =====================================================================
    gripper_frame = tk.LabelFrame(container, text="Gripper", padx=10, pady=10, font=("Arial", 10, "bold"))
    gripper_frame.grid(row=0, column=0, sticky="ew", pady=(0, 8))
    
    def gripper_open():
        send_command("GRIPPER", {"state": "OPEN"})
        log_message("🟢 Gripper ABIERTO")
        gripper_open_btn.config(bg="#4CAF50")
        gripper_close_btn.config(bg="#f44336")
    
    def gripper_close():
        send_command("GRIPPER", {"state": "CLOSE"})
        log_message("🔴 Gripper CERRADO")
        gripper_close_btn.config(bg="#4CAF50")
        gripper_open_btn.config(bg="#f44336")
    
    # Botón ABRIR
    gripper_open_btn = tk.Button(
        gripper_frame, text="ABIERTO",
        font=("Arial", 11, "bold"),
        width=15,
        bg="#4CAF50", fg="white",
        command=gripper_open
    )
    gripper_open_btn.pack(pady=5)
    
    # Botón CERRAR
    gripper_close_btn = tk.Button(
        gripper_frame, text="CERRADO",
        font=("Arial", 11, "bold"),
        width=15,
        bg="#f44336", fg="white",
        command=gripper_close
    )
    gripper_close_btn.pack(pady=5)
    
    # Estado inicial
    # El gripper comienza en CERRADO
    gripper_close_btn.config(bg="#4CAF50")   # botón cerrado resaltado

    # =====================================================================
    # SIMULACIÓN
    # =====================================================================
    sim_frame = tk.LabelFrame(container, text="Simulación", padx=10, pady=10, font=("Arial", 10, "bold"))
    sim_frame.grid(row=1, column=0, sticky="ew", pady=(0, 8))

    global sim_active
    sim_active = tk.BooleanVar(value=False)

    def toggle_sim():
        state = sim_active.get()
        cmd = "SIM_ON" if state else "SIM_OFF"
        send_command(cmd, {})
        log_message("🧪 Simulación ACTIVADA" if state else "🛑 Simulación DESACTIVADA")
        sim_btn.config(bg="#4CAF50" if state else "#f44336", text="SIM ON" if state else "SIM OFF")

    sim_btn = tk.Checkbutton(sim_frame, text="SIM OFF", variable=sim_active, command=toggle_sim,
                             font=("Arial", 11, "bold"), indicatoron=False, width=15, bg="#f44336",
                             fg="white", selectcolor="#4CAF50")
    sim_btn.pack(pady=10)


def create_gui():
    """Construye toda la interfaz (pestañas, botones, mapa, etc.)."""
    global root, mapa, status_label, telemetry_text, log_text
    global port_var, spacing_var, altitude_var, status_message, detect_spacing_var
    global home_position_var, progress_var, progress_bar
    global add_btn, home_btn, delete_btn
    global btn_arm, btn_disarm, btn_mission, btn_return
    global event_action_var

    root = tk.Tk()
    root.title("Ground Station - Dron Buscador Térmico")
    root.geometry("1200x900")

      
    event_action_var = tk.StringVar(value="VOLVER")

    # ---- Barra de conexión ----
    connection_frame = tk.Frame(root)
    connection_frame.pack(fill="x", padx=10, pady=5)

    ports = [port.device for port in serial.tools.list_ports.comports()]
    port_var = tk.StringVar(value=ports[0] if ports else "")

    tk.Label(connection_frame, text="Puerto:").pack(side="left")
    port_combo = ttk.Combobox(connection_frame, textvariable=port_var, values=ports, width=15)
    port_combo.pack(side="left", padx=5)

    def update_ports():
        new_ports = [port.device for port in serial.tools.list_ports.comports()]
        port_combo['values'] = new_ports
        if new_ports and not port_var.get():
            port_var.set(new_ports[0])

    tk.Button(connection_frame, text="Actualizar", command=update_ports).pack(side="left", padx=5)
    tk.Button(connection_frame, text="Conectar", command=connect_serial).pack(side="left", padx=5)
    tk.Button(connection_frame, text="Desconectar", command=disconnect_serial).pack(side="left", padx=5)

    status_label = tk.Label(connection_frame, text="Desconectado", fg="red")
    status_label.pack(side="right")

    # ---- Modo edición ----
    edit_frame = tk.Frame(root)
    edit_frame.pack(fill="x", padx=10, pady=5)

    tk.Label(edit_frame, text="Modo Edición:", font=("Arial", 10, "bold")).pack(side="left")
    add_btn = tk.Button(edit_frame, text="Colocar marcadores", command=lambda: set_edit_mode('polygon'), width=20)
    add_btn.pack(side="left", padx=2)
    home_btn = tk.Button(edit_frame, text="Colocar home", command=set_home_from_telemetry, width=20)
    home_btn.pack(side="left", padx=2)
    delete_btn = tk.Button(edit_frame, text="Eliminar marcadores", command=lambda: set_edit_mode('delete'), width=20)
    delete_btn.pack(side="left", padx=2)

    # ---- Parámetros de misión ----
    params_frame = tk.Frame(root)
    params_frame.pack(fill="x", padx=10, pady=5)

    tk.Label(params_frame, text="Altitud (m):").pack(side="left")
    altitude_var = tk.IntVar(value=3)
    tk.Spinbox(params_frame, from_=1, to=100, width=5, textvariable=altitude_var).pack(side="left", padx=5)

    tk.Label(params_frame, text="Ancho pasadas (m):").pack(side="left", padx=(20, 5))
    spacing_var = tk.IntVar(value=5)
    tk.Spinbox(params_frame, from_=1, to=50, width=5, textvariable=spacing_var).pack(side="left", padx=5)
    def on_spacing_change(*args):
        refresh_mission_preview()    
    spacing_var.trace_add("write", on_spacing_change)

    tk.Label(params_frame, text="Espaciado detecciones (m):").pack(side="left", padx=(20, 5))
    global detect_spacing_var
    detect_spacing_var = tk.IntVar(value=5)
    tk.Spinbox(params_frame, from_=1, to=50, width=5, textvariable=detect_spacing_var).pack(side="left", padx=5)
    def on_detect_change(*args):
        refresh_mission_preview()
    detect_spacing_var.trace_add("write", on_detect_change)

    
    home_position_var = tk.StringVar(value="")
    tk.Label(params_frame, textvariable=home_position_var, fg="green").pack(side="right")

    # ---- Estado y progreso ----
    status_frame = tk.Frame(root)
    status_frame.pack(fill="x", padx=10, pady=5)

    status_message = tk.StringVar(value="Modo: Polígono")
    tk.Label(status_frame, textvariable=status_message, fg="white", bg="#333", font=("Arial", 12, "bold"),padx=8, pady=3).pack(side="left")


    progress_var = tk.StringVar(value="Waypoints: 0/0")
    tk.Label(status_frame, textvariable=progress_var).pack(side="left", padx=20)

    progress_bar = ttk.Progressbar(status_frame, orient="horizontal", length=200, mode="determinate")
    progress_bar.pack(side="left", padx=5)

    # ---- Botones de misión ----
    mission_btn_frame = tk.Frame(root)
    mission_btn_frame.pack(fill="x", padx=10, pady=5)

    btn_mission = tk.Button(mission_btn_frame, text="COMENZAR MISIÓN", command=start_mission,
                            state="disabled", bg="lightgrey", fg="white")
    btn_mission.pack(side="left", expand=True, padx=5)

    btn_return = tk.Button(mission_btn_frame, text="REGRESAR", command=return_home,
                           state="disabled", bg="lightgrey", fg="white")
    btn_return.pack(side="left", expand=True, padx=5)

    tk.Button(mission_btn_frame, text="RESET COMPLETO", command=reset_polygon, bg="red", fg="white").pack(side="left", expand=True, padx=5)
    tk.Button(mission_btn_frame, text="GUARDAR", command=save_mission, bg="blue", fg="white").pack(side="left", expand=True, padx=5)
    tk.Button(mission_btn_frame, text="CARGAR", command=load_mission, bg="purple", fg="white").pack(side="left", expand=True, padx=5)

    tk.Label(mission_btn_frame, text="Acción tras evento:").pack(side="left", padx=5)
    event_action_menu = ttk.Combobox(mission_btn_frame, textvariable=event_action_var,
                                     values=["CONTINUAR", "VOLVER"], state="readonly", width=11)
    event_action_menu.pack(side="left", padx=5)
    event_action_menu.current(1)  # "VOLVER"

    # ---- Notebook ----
    notebook = ttk.Notebook(root)
    notebook.pack(fill="both", expand=True, padx=10, pady=5)

    # Pestaña: Misión
    frame_mission = ttk.Frame(notebook)
    notebook.add(frame_mission, text="Misión")

    # Mapa
    global mapa
    mapa = tkintermapview.TkinterMapView(frame_mission, width=1000, height=500, corner_radius=0)
    mapa.pack(pady=10, fill="both", expand=True)
    mapa.set_position(-34.6037, -58.3816)
    mapa.set_zoom(12)
    mapa.add_left_click_map_command(map_click)
    mapa.set_tile_server(
    "https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}",max_zoom=19)

    # Pestaña: Controles
    frame_controls = ttk.Frame(notebook)
    notebook.add(frame_controls, text="Controles")

    control_btn_frame = tk.Frame(frame_controls)
    control_btn_frame.pack(pady=10)

    global btn_arm, btn_disarm
    btn_arm = tk.Button(control_btn_frame, text="ARMAR", command=arm_drone, bg="green", fg="white", width=15)
    btn_arm.pack(side="left", padx=10)

    btn_disarm = tk.Button(control_btn_frame, text="DESARMAR", command=disarm_drone,
                           state="normal", bg="red", fg="white", width=15)
    btn_disarm.pack(side="left", padx=10)

    create_trim_pid_controls(frame_controls)


    # Pestaña: Telemetría
    frame_telemetry = ttk.Frame(notebook)
    notebook.add(frame_telemetry, text="Telemetría")

    global telemetry_text
    telemetry_text = scrolledtext.ScrolledText(frame_telemetry, width=80, height=15)
    telemetry_text.pack(pady=10, fill="both", expand=True)
    telemetry_text.insert("end", "Esperando datos de telemetría...\n")
    telemetry_text.config(state="disabled")

    # Pestaña: Log
    frame_log = ttk.Frame(notebook)
    notebook.add(frame_log, text="Log")

    global log_text
    log_text = scrolledtext.ScrolledText(frame_log, width=80, height=15)
    log_text.pack(pady=10, fill="both", expand=True)
    log_text.config(state="disabled")

    # Modo inicial
    set_edit_mode('polygon')

# =========================
# [13] INICIALIZACIÓN
# =========================
current_mission = MissionData()

# Ejecutar GUI 
create_gui()
log_message("✅ Interfaz lista. Conectá el puerto y espera telemetría...")
root.mainloop()
# Out:
# [SERIAL] ✅ Conectado a COM4 @ 115200 bps
# [SERIAL] 🚀 Lanzando hilos: recepción y ack_manager
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"IDLE","ts":2082}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'IDLE', 'ts': 2082}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'IDLE', 'ts': 2082}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-27.99334963,"lon":-47.05629284,"alt":-0.52,"speed":0.629544336,"heading":263,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":3176}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -27.99334963, 'lon': -47.05629284, 'alt': -0.52, 'speed': 0.629544336, 'heading': 263, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 3176}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"IDLE","ts":2082}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'IDLE', 'ts': 2082}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'IDLE', 'ts': 2082}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77286555,"lon":-58.45253207,"alt":-0.549976563,"speed":0.718440306,"heading":263,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":4471}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77286555, 'lon': -58.45253207, 'alt': -0.549976563, 'speed': 0.718440306, 'heading': 263, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 4471}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"IDLE","ts":2082}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'IDLE', 'ts': 2082}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'IDLE', 'ts': 2082}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77434689,"lon":-58.45502304,"alt":-0.554952759,"speed":0.769445,"heading":263,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":5777}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77434689, 'lon': -58.45502304, 'alt': -0.554952759, 'speed': 0.769445, 'heading': 263, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 5777}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"IDLE","ts":2082}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'IDLE', 'ts': 2082}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'IDLE', 'ts': 2082}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77434839,"lon":-58.45502612,"alt":-0.666358821,"speed":0.857979977,"heading":264,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":7078}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77434839, 'lon': -58.45502612, 'alt': -0.666358821, 'speed': 0.857979977, 'heading': 264, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 7078}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"STATUS","message":"IDLE","ts":2082}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'STATUS' → {'t': 'STATUS', 'message': 'IDLE', 'ts': 2082}
# [STATUS ← LoRa] Data: {'t': 'STATUS', 'message': 'IDLE', 'ts': 2082}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77434951,"lon":-58.45502673,"alt":-0.705997212,"speed":1.031245959,"heading":264,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":8384}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77434951, 'lon': -58.45502673, 'alt': -0.705997212, 'speed': 1.031245959, 'heading': 264, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 8384}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77435066,"lon":-58.4550283,"alt":-0.724007868,"speed":1.033118,"heading":264,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":9690}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77435066, 'lon': -58.4550283, 'alt': -0.724007868, 'speed': 1.033118, 'heading': 264, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 9690}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77435247,"lon":-58.45502864,"alt":-0.793702527,"speed":0.896613979,"heading":264,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":10990}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77435247, 'lon': -58.45502864, 'alt': -0.793702527, 'speed': 0.896613979, 'heading': 264, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 10990}
# 🗑 Todos los waypoints eliminados
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77435618,"lon":-58.45502887,"alt":-0.823370396,"speed":0.955988324,"heading":264,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":12296}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77435618, 'lon': -58.45502887, 'alt': -0.823370396, 'speed': 0.955988324, 'heading': 264, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 12296}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77436113,"lon":-58.45502866,"alt":-0.838289005,"speed":0.891425675,"heading":264,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":13602}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77436113, 'lon': -58.45502866, 'alt': -0.838289005, 'speed': 0.891425675, 'heading': 264, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 13602}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.7743647,"lon":-58.45502896,"alt":-0.889783614,"speed":1.193168,"heading":264,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":14908}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.7743647, 'lon': -58.45502896, 'alt': -0.889783614, 'speed': 1.193168, 'heading': 264, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 14908}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77436843,"lon":-58.45503151,"alt":-1.028160081,"speed":1.123477471,"heading":264,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":16208}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77436843, 'lon': -58.45503151, 'alt': -1.028160081, 'speed': 1.123477471, 'heading': 264, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 16208}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77436911,"lon":-58.45503083,"alt":-1.111546313,"speed":0.856231177,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":17514}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77436911, 'lon': -58.45503083, 'alt': -1.111546313, 'speed': 0.856231177, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 17514}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437062,"lon":-58.45502816,"alt":-1.076972277,"speed":0.412482387,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":18820}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437062, 'lon': -58.45502816, 'alt': -1.076972277, 'speed': 0.412482387, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 18820}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437139,"lon":-58.45502538,"alt":-1.000618601,"speed":0.509087938,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":20126}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437139, 'lon': -58.45502538, 'alt': -1.000618601, 'speed': 0.509087938, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 20126}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437114,"lon":-58.45502329,"alt":-0.992256768,"speed":0.40914073,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":21432}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437114, 'lon': -58.45502329, 'alt': -0.992256768, 'speed': 0.40914073, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 21432}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.774372,"lon":-58.45502092,"alt":-0.917478072,"speed":0.267902711,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":22738}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.774372, 'lon': -58.45502092, 'alt': -0.917478072, 'speed': 0.267902711, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 22738}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437242,"lon":-58.45501765,"alt":-0.827715609,"speed":0.26669907,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":24039}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437242, 'lon': -58.45501765, 'alt': -0.827715609, 'speed': 0.26669907, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 24039}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437223,"lon":-58.45501482,"alt":-0.733032392,"speed":0.296832213,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":25345}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437223, 'lon': -58.45501482, 'alt': -0.733032392, 'speed': 0.296832213, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 25345}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437167,"lon":-58.45501239,"alt":-0.700333486,"speed":0.293588135,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":26651}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437167, 'lon': -58.45501239, 'alt': -0.700333486, 'speed': 0.293588135, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 26651}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.7743715,"lon":-58.45501132,"alt":-0.70764993,"speed":0.407037127,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":27957}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.7743715, 'lon': -58.45501132, 'alt': -0.70764993, 'speed': 0.407037127, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 27957}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437088,"lon":-58.45501055,"alt":-0.689589746,"speed":0.602082324,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":29257}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437088, 'lon': -58.45501055, 'alt': -0.689589746, 'speed': 0.602082324, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 29257}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437084,"lon":-58.45500957,"alt":-0.689369611,"speed":0.457871,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":30563}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437084, 'lon': -58.45500957, 'alt': -0.689369611, 'speed': 0.457871, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 30563}
# 🗑 Todos los waypoints eliminados
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437055,"lon":-58.45500751,"alt":-0.69377651,"speed":0.608685172,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":31864}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437055, 'lon': -58.45500751, 'alt': -0.69377651, 'speed': 0.608685172, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 31864}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437034,"lon":-58.45500694,"alt":-0.70756911,"speed":0.753438681,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":33170}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437034, 'lon': -58.45500694, 'alt': -0.70756911, 'speed': 0.753438681, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 33170}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437067,"lon":-58.45500736,"alt":-0.747484353,"speed":1.065702581,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":34476}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437067, 'lon': -58.45500736, 'alt': -0.747484353, 'speed': 1.065702581, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 34476}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437139,"lon":-58.45500895,"alt":-0.850885033,"speed":1.322880399,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":35782}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437139, 'lon': -58.45500895, 'alt': -0.850885033, 'speed': 1.322880399, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 35782}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437219,"lon":-58.45501171,"alt":-0.990209507,"speed":1.638391757,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":37088}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437219, 'lon': -58.45501171, 'alt': -0.990209507, 'speed': 1.638391757, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 37088}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437243,"lon":-58.45501396,"alt":-1.140968823,"speed":1.472834766,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":38394}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437243, 'lon': -58.45501396, 'alt': -1.140968823, 'speed': 1.472834766, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 38394}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437191,"lon":-58.45501361,"alt":-1.157731023,"speed":1.22608881,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":39700}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437191, 'lon': -58.45501361, 'alt': -1.157731023, 'speed': 1.22608881, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 39700}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437141,"lon":-58.45501274,"alt":-1.09584758,"speed":1.036735797,"heading":266,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":41006}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437141, 'lon': -58.45501274, 'alt': -1.09584758, 'speed': 1.036735797, 'heading': 266, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 41006}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437049,"lon":-58.45501078,"alt":-1.016776828,"speed":0.778719252,"heading":266,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":42312}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437049, 'lon': -58.45501078, 'alt': -1.016776828, 'speed': 0.778719252, 'heading': 266, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 42312}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77436924,"lon":-58.45500669,"alt":-1.001680537,"speed":0.456659335,"heading":266,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":43618}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77436924, 'lon': -58.45500669, 'alt': -1.001680537, 'speed': 0.456659335, 'heading': 266, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 43618}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77436817,"lon":-58.45500193,"alt":-1.02384451,"speed":0.29528777,"heading":266,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":44924}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77436817, 'lon': -58.45500193, 'alt': -1.02384451, 'speed': 0.29528777, 'heading': 266, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 44924}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77436657,"lon":-58.45499681,"alt":-1.027872189,"speed":0.287401566,"heading":266,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":46225}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77436657, 'lon': -58.45499681, 'alt': -1.027872189, 'speed': 0.287401566, 'heading': 266, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 46225}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77436549,"lon":-58.45499297,"alt":-1.037018756,"speed":0.441342768,"heading":266,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":47531}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77436549, 'lon': -58.45499297, 'alt': -1.037018756, 'speed': 0.441342768, 'heading': 266, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 47531}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77436508,"lon":-58.45499149,"alt":-1.112882264,"speed":0.904989,"heading":266,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":48837}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77436508, 'lon': -58.45499149, 'alt': -1.112882264, 'speed': 0.904989, 'heading': 266, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 48837}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77436541,"lon":-58.45499277,"alt":-1.148318645,"speed":1.309328699,"heading":266,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":50138}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77436541, 'lon': -58.45499277, 'alt': -1.148318645, 'speed': 1.309328699, 'heading': 266, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 50138}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77436616,"lon":-58.45499465,"alt":-1.182873711,"speed":1.356200087,"heading":266,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":51444}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77436616, 'lon': -58.45499465, 'alt': -1.182873711, 'speed': 1.356200087, 'heading': 266, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 51444}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77436686,"lon":-58.4549954,"alt":-1.2068889,"speed":1.365576017,"heading":266,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":52750}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77436686, 'lon': -58.4549954, 'alt': -1.2068889, 'speed': 1.365576017, 'heading': 266, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 52750}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77436765,"lon":-58.4549966,"alt":-1.194682924,"speed":1.390146554,"heading":266,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":54051}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77436765, 'lon': -58.4549966, 'alt': -1.194682924, 'speed': 1.390146554, 'heading': 266, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 54051}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77436876,"lon":-58.45499766,"alt":-1.154135218,"speed":1.423959231,"heading":266,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":55357}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77436876, 'lon': -58.45499766, 'alt': -1.154135218, 'speed': 1.423959231, 'heading': 266, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 55357}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437027,"lon":-58.45499965,"alt":-1.117515425,"speed":1.582508576,"heading":266,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":56663}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437027, 'lon': -58.45499965, 'alt': -1.117515425, 'speed': 1.582508576, 'heading': 266, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 56663}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437137,"lon":-58.45500305,"alt":-1.130910826,"speed":1.640631187,"heading":266,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":57969}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437137, 'lon': -58.45500305, 'alt': -1.130910826, 'speed': 1.640631187, 'heading': 266, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 57969}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437279,"lon":-58.45500736,"alt":-1.200947814,"speed":1.817570829,"heading":266,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":59275}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437279, 'lon': -58.45500736, 'alt': -1.200947814, 'speed': 1.817570829, 'heading': 266, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 59275}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.7743734,"lon":-58.45501161,"alt":-1.220764882,"speed":1.900666094,"heading":266,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":60581}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.7743734, 'lon': -58.45501161, 'alt': -1.220764882, 'speed': 1.900666094, 'heading': 266, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 60581}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437403,"lon":-58.45501646,"alt":-1.243910876,"speed":1.824605,"heading":266,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":61887}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437403, 'lon': -58.45501646, 'alt': -1.243910876, 'speed': 1.824605, 'heading': 266, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 61887}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437412,"lon":-58.45501996,"alt":-1.288408941,"speed":1.780928421,"heading":266,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":63188}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437412, 'lon': -58.45501996, 'alt': -1.288408941, 'speed': 1.780928421, 'heading': 266, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 63188}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437444,"lon":-58.45502384,"alt":-1.346799589,"speed":1.903600645,"heading":266,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":64494}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437444, 'lon': -58.45502384, 'alt': -1.346799589, 'speed': 1.903600645, 'heading': 266, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 64494}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437494,"lon":-58.45502902,"alt":-1.374885419,"speed":1.935356,"heading":266,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":65800}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437494, 'lon': -58.45502902, 'alt': -1.374885419, 'speed': 1.935356, 'heading': 266, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 65800}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437517,"lon":-58.45503241,"alt":-1.352244255,"speed":1.597317803,"heading":266,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":67100}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437517, 'lon': -58.45503241, 'alt': -1.352244255, 'speed': 1.597317803, 'heading': 266, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 67100}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437489,"lon":-58.45503396,"alt":-1.283641369,"speed":1.370303893,"heading":266,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":68406}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437489, 'lon': -58.45503396, 'alt': -1.283641369, 'speed': 1.370303893, 'heading': 266, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 68406}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437477,"lon":-58.45503479,"alt":-1.223017226,"speed":1.112998295,"heading":266,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":69712}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437477, 'lon': -58.45503479, 'alt': -1.223017226, 'speed': 1.112998295, 'heading': 266, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 69712}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437526,"lon":-58.4550349,"alt":-1.176737712,"speed":0.782719606,"heading":266,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":71018}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437526, 'lon': -58.4550349, 'alt': -1.176737712, 'speed': 0.782719606, 'heading': 266, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 71018}
# 🗑 Todos los waypoints eliminados
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437567,"lon":-58.45503266,"alt":-1.133541697,"speed":0.44760527,"heading":266,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":72324}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437567, 'lon': -58.45503266, 'alt': -1.133541697, 'speed': 0.44760527, 'heading': 266, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 72324}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437608,"lon":-58.45502867,"alt":-1.092152935,"speed":0.185115726,"heading":266,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":73630}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437608, 'lon': -58.45502867, 'alt': -1.092152935, 'speed': 0.185115726, 'heading': 266, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 73630}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437635,"lon":-58.45502471,"alt":-1.082383665,"speed":0.219659829,"heading":266,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":74936}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437635, 'lon': -58.45502471, 'alt': -1.082383665, 'speed': 0.219659829, 'heading': 266, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 74936}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.7743775,"lon":-58.45502148,"alt":-1.077983708,"speed":0.251387331,"heading":266,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":76242}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.7743775, 'lon': -58.45502148, 'alt': -1.077983708, 'speed': 0.251387331, 'heading': 266, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 76242}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77437861,"lon":-58.45502023,"alt":-1.085293243,"speed":0.322698417,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":77548}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77437861, 'lon': -58.45502023, 'alt': -1.085293243, 'speed': 0.322698417, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 77548}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.7743802,"lon":-58.455019,"alt":-1.096789937,"speed":0.521093559,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":78854}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.7743802, 'lon': -58.455019, 'alt': -1.096789937, 'speed': 0.521093559, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 78854}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77438169,"lon":-58.45501874,"alt":-1.143186734,"speed":0.622988319,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":80155}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77438169, 'lon': -58.45501874, 'alt': -1.143186734, 'speed': 0.622988319, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 80155}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77438349,"lon":-58.45501902,"alt":-1.218153466,"speed":0.74652518,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":81461}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77438349, 'lon': -58.45501902, 'alt': -1.218153466, 'speed': 0.74652518, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 81461}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77438503,"lon":-58.45501993,"alt":-1.258314179,"speed":0.861849439,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":82767}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77438503, 'lon': -58.45501993, 'alt': -1.258314179, 'speed': 0.861849439, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 82767}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77438703,"lon":-58.45502071,"alt":-1.286391364,"speed":1.014713681,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":84073}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77438703, 'lon': -58.45502071, 'alt': -1.286391364, 'speed': 1.014713681, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 84073}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77438949,"lon":-58.45502178,"alt":-1.27952624,"speed":1.02724818,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":85379}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77438949, 'lon': -58.45502178, 'alt': -1.27952624, 'speed': 1.02724818, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 85379}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77439092,"lon":-58.4550219,"alt":-1.255787263,"speed":0.828541017,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":86680}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77439092, 'lon': -58.4550219, 'alt': -1.255787263, 'speed': 0.828541017, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 86680}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77439149,"lon":-58.45502052,"alt":-1.202712326,"speed":0.584476519,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":87986}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77439149, 'lon': -58.45502052, 'alt': -1.202712326, 'speed': 0.584476519, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 87986}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77439165,"lon":-58.4550181,"alt":-1.149446359,"speed":0.373814079,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":89292}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77439165, 'lon': -58.4550181, 'alt': -1.149446359, 'speed': 0.373814079, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 89292}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77439161,"lon":-58.45501543,"alt":-1.115023754,"speed":0.241574067,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":90598}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77439161, 'lon': -58.45501543, 'alt': -1.115023754, 'speed': 0.241574067, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 90598}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77439149,"lon":-58.45501229,"alt":-1.0858033,"speed":0.078484956,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":91904}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77439149, 'lon': -58.45501229, 'alt': -1.0858033, 'speed': 0.078484956, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 91904}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77439149,"lon":-58.45500815,"alt":-1.083539173,"speed":0.035879042,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":93205}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77439149, 'lon': -58.45500815, 'alt': -1.083539173, 'speed': 0.035879042, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 93205}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77439121,"lon":-58.45500474,"alt":-1.113038344,"speed":0.034814506,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":94511}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77439121, 'lon': -58.45500474, 'alt': -1.113038344, 'speed': 0.034814506, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 94511}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77439055,"lon":-58.45500088,"alt":-1.15642736,"speed":0.137471111,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":95817}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77439055, 'lon': -58.45500088, 'alt': -1.15642736, 'speed': 0.137471111, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 95817}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.7743901,"lon":-58.45499784,"alt":-1.218921032,"speed":0.243303502,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":97123}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.7743901, 'lon': -58.45499784, 'alt': -1.218921032, 'speed': 0.243303502, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 97123}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77438988,"lon":-58.45499513,"alt":-1.296043841,"speed":0.428290656,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":98429}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77438988, 'lon': -58.45499513, 'alt': -1.296043841, 'speed': 0.428290656, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 98429}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77438994,"lon":-58.4549934,"alt":-1.344207998,"speed":0.601717812,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":99735}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77438994, 'lon': -58.4549934, 'alt': -1.344207998, 'speed': 0.601717812, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 99735}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77439011,"lon":-58.4549915,"alt":-1.397247491,"speed":0.664466,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":101041}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77439011, 'lon': -58.4549915, 'alt': -1.397247491, 'speed': 0.664466, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 101041}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77439042,"lon":-58.45498954,"alt":-1.441390972,"speed":0.757689232,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":102342}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77439042, 'lon': -58.45498954, 'alt': -1.441390972, 'speed': 0.757689232, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 102342}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77439177,"lon":-58.45498798,"alt":-1.466072574,"speed":0.702610874,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":103648}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77439177, 'lon': -58.45498798, 'alt': -1.466072574, 'speed': 0.702610874, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 103648}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77439061,"lon":-58.45498497,"alt":-1.39786863,"speed":0.467362422,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":104954}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77439061, 'lon': -58.45498497, 'alt': -1.39786863, 'speed': 0.467362422, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 104954}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77438935,"lon":-58.45498123,"alt":-1.339025128,"speed":0.460666072,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":106260}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77438935, 'lon': -58.45498123, 'alt': -1.339025128, 'speed': 0.460666072, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 106260}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77438875,"lon":-58.45497896,"alt":-1.33247957,"speed":0.513882172,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":107566}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77438875, 'lon': -58.45497896, 'alt': -1.33247957, 'speed': 0.513882172, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 107566}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77438873,"lon":-58.45497741,"alt":-1.328653553,"speed":0.575713152,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":108872}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77438873, 'lon': -58.45497741, 'alt': -1.328653553, 'speed': 0.575713152, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 108872}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77438885,"lon":-58.4549751,"alt":-1.32199294,"speed":0.520162833,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":110178}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77438885, 'lon': -58.4549751, 'alt': -1.32199294, 'speed': 0.520162833, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 110178}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77438889,"lon":-58.45497256,"alt":-1.385791712,"speed":0.484488,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":111484}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77438889, 'lon': -58.45497256, 'alt': -1.385791712, 'speed': 0.484488, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 111484}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.7743888,"lon":-58.45496988,"alt":-1.423492766,"speed":0.50473761,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":112785}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.7743888, 'lon': -58.45496988, 'alt': -1.423492766, 'speed': 0.50473761, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 112785}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77438846,"lon":-58.45496763,"alt":-1.405081842,"speed":0.509871894,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":114091}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77438846, 'lon': -58.45496763, 'alt': -1.405081842, 'speed': 0.509871894, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 114091}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77438812,"lon":-58.45496576,"alt":-1.401212219,"speed":0.60947578,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":115397}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77438812, 'lon': -58.45496576, 'alt': -1.401212219, 'speed': 0.60947578, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 115397}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77438796,"lon":-58.4549649,"alt":-1.355497975,"speed":0.757296234,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":116703}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77438796, 'lon': -58.4549649, 'alt': -1.355497975, 'speed': 0.757296234, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 116703}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77438882,"lon":-58.45496501,"alt":-1.336439152,"speed":0.996302569,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":118009}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77438882, 'lon': -58.45496501, 'alt': -1.336439152, 'speed': 0.996302569, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 118009}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.7743897,"lon":-58.45496594,"alt":-1.314426548,"speed":1.192987883,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":119315}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.7743897, 'lon': -58.45496594, 'alt': -1.314426548, 'speed': 1.192987883, 'heading': 265, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'STABILIZE'}, 'ts': 119315}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77439084,"lon":-58.45496704,"alt":-1.313952628,"speed":1.121260035,"heading":265,"battery":-1,"voltage":0,"armed":false,"mode":"STABILIZE"},"ts":120621}#END
# ...
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77439115, 'lon': -58.45498901, 'alt': 0.856156976, 'speed': 0.895568401, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 379274}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77439165,"lon":-58.45499239,"alt":0.875262802,"speed":0.789857286,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":380574}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77439165, 'lon': -58.45499239, 'alt': 0.875262802, 'speed': 0.789857286, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 380574}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77439185,"lon":-58.45499526,"alt":0.920754196,"speed":0.723272359,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":381874}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77439185, 'lon': -58.45499526, 'alt': 0.920754196, 'speed': 0.723272359, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 381874}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77439214,"lon":-58.45499761,"alt":0.918940627,"speed":0.708038861,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":383175}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77439214, 'lon': -58.45499761, 'alt': 0.918940627, 'speed': 0.708038861, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 383175}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77439289,"lon":-58.45500074,"alt":0.942971384,"speed":0.502565074,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":384494}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77439289, 'lon': -58.45500074, 'alt': 0.942971384, 'speed': 0.502565074, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 384494}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77439304,"lon":-58.4550024,"alt":0.992951206,"speed":0.252789295,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":385795}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77439304, 'lon': -58.4550024, 'alt': 0.992951206, 'speed': 0.252789295, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 385795}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77439226,"lon":-58.45500234,"alt":1.110939654,"speed":0.110873301,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":387095}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77439226, 'lon': -58.45500234, 'alt': 1.110939654, 'speed': 0.110873301, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 387095}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77439242,"lon":-58.45500237,"alt":1.174589846,"speed":0.025326343,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":388395}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77439242, 'lon': -58.45500237, 'alt': 1.174589846, 'speed': 0.025326343, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 388395}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77439347,"lon":-58.45500506,"alt":1.155987304,"speed":0.505544096,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":389696}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77439347, 'lon': -58.45500506, 'alt': 1.155987304, 'speed': 0.505544096, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 389696}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77439535,"lon":-58.45500995,"alt":1.08039276,"speed":0.85941866,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":390996}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77439535, 'lon': -58.45500995, 'alt': 1.08039276, 'speed': 0.85941866, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 390996}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.7743972,"lon":-58.45501435,"alt":1.012115599,"speed":0.817578,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":392297}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.7743972, 'lon': -58.45501435, 'alt': 1.012115599, 'speed': 0.817578, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 392297}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77439818,"lon":-58.45501728,"alt":1.00229743,"speed":0.989672041,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":393617}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77439818, 'lon': -58.45501728, 'alt': 1.00229743, 'speed': 0.989672041, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 393617}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77440023,"lon":-58.45502244,"alt":0.956153472,"speed":1.2791664,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":394918}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77440023, 'lon': -58.45502244, 'alt': 0.956153472, 'speed': 1.2791664, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 394918}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77440262,"lon":-58.45502933,"alt":0.913132974,"speed":1.488938856,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":396219}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77440262, 'lon': -58.45502933, 'alt': 0.913132974, 'speed': 1.488938856, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 396219}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77440409,"lon":-58.45503404,"alt":0.884289291,"speed":1.368505418,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":397520}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77440409, 'lon': -58.45503404, 'alt': 0.884289291, 'speed': 1.368505418, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 397520}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77440581,"lon":-58.45503807,"alt":0.870739849,"speed":1.049846005,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":398820}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77440581, 'lon': -58.45503807, 'alt': 0.870739849, 'speed': 1.049846005, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 398820}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77440668,"lon":-58.45503989,"alt":0.897439538,"speed":0.832962424,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":400120}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77440668, 'lon': -58.45503989, 'alt': 0.897439538, 'speed': 0.832962424, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 400120}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.7744079,"lon":-58.45504095,"alt":0.935026933,"speed":0.477524614,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":401420}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.7744079, 'lon': -58.45504095, 'alt': 0.935026933, 'speed': 0.477524614, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 401420}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77440841,"lon":-58.45504093,"alt":0.974521395,"speed":0.199019869,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":402741}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77440841, 'lon': -58.45504093, 'alt': 0.974521395, 'speed': 0.199019869, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 402741}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77440902,"lon":-58.45504063,"alt":1.027356036,"speed":0.197247787,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":404042}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77440902, 'lon': -58.45504063, 'alt': 1.027356036, 'speed': 0.197247787, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 404042}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77440954,"lon":-58.45504099,"alt":1.049932507,"speed":0.146526209,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":405342}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77440954, 'lon': -58.45504099, 'alt': 1.049932507, 'speed': 0.146526209, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 405342}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77441056,"lon":-58.45504318,"alt":1.017620324,"speed":0.568709153,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":406643}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77441056, 'lon': -58.45504318, 'alt': 1.017620324, 'speed': 0.568709153, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 406643}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77441233,"lon":-58.45504698,"alt":0.897334037,"speed":0.903767967,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":407944}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77441233, 'lon': -58.45504698, 'alt': 0.897334037, 'speed': 0.903767967, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 407944}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77441405,"lon":-58.45505057,"alt":0.806626742,"speed":0.997990644,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":409245}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77441405, 'lon': -58.45505057, 'alt': 0.806626742, 'speed': 0.997990644, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 409245}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77441525,"lon":-58.45505297,"alt":0.769635717,"speed":0.929109585,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":410545}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77441525, 'lon': -58.45505297, 'alt': 0.769635717, 'speed': 0.929109585, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 410545}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77441613,"lon":-58.45505457,"alt":0.770817463,"speed":0.886076814,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":411864}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77441613, 'lon': -58.45505457, 'alt': 0.770817463, 'speed': 0.886076814, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 411864}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77441696,"lon":-58.45505606,"alt":0.780317854,"speed":0.785639,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":413165}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77441696, 'lon': -58.45505606, 'alt': 0.780317854, 'speed': 0.785639, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 413165}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77441827,"lon":-58.45505887,"alt":0.742122507,"speed":1.416464067,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":414460}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77441827, 'lon': -58.45505887, 'alt': 0.742122507, 'speed': 1.416464067, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 414460}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77442038,"lon":-58.45506634,"alt":0.625907546,"speed":1.88388,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":415761}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77442038, 'lon': -58.45506634, 'alt': 0.625907546, 'speed': 1.88388, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 415761}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77442191,"lon":-58.4550736,"alt":0.588465015,"speed":1.80132823,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":417056}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77442191, 'lon': -58.4550736, 'alt': 0.588465015, 'speed': 1.80132823, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 417056}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77442268,"lon":-58.4550774,"alt":0.603210692,"speed":1.480579805,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":418356}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77442268, 'lon': -58.4550774, 'alt': 0.603210692, 'speed': 1.480579805, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 418356}
# [RX ← LoRa/receive_data] Frame recibido ← UAV#{"t":"TELEMETRY","d":{"lat":-34.77442286,"lon":-58.45508017,"alt":0.676330675,"speed":1.249107635,"heading":215,"battery":-1,"voltage":0,"armed":false,"mode":"GUIDED"},"ts":419657}#END
# [RX ← LoRa/process_received_message] Mensaje recibido tipo 'TELEMETRY' → {'t': 'TELEMETRY', 'd': {'lat': -34.77442286, 'lon': -58.45508017, 'alt': 0.676330675, 'speed': 1.249107635, 'heading': 215, 'battery': -1, 'voltage': 0, 'armed': False, 'mode': 'GUIDED'}, 'ts': 419657}
# [SERIAL] ✅ Puerto cerrado correctamente
